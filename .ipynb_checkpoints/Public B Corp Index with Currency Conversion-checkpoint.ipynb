# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
from datetime import timedelta
import random

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
import yfinance as yf
import requests

# %%
s = '2022-01-04'
e = '2024-04-22'

download = False

# %%
df = pd.read_csv("https://query.data.world/s/pzd7uazpmpyortmg6fsuxiaoizllgu?dws=00000", encoding='ISO-8859-1')
display(df.head())
# Out:
#   Public Company Name (As Listed on Exchange) B Corp Impact Data ID  \
# 0                              Allbirds, Inc.    001C000001SGhnyIAD
# 1                       Amalgamated Financial    001C000001K16JSIAZ
# 2                            AppHarvest, Inc.    0013b00001o41JFAAY
# 3                                   Arezzo&Co    0013b00001qHFddAAG
# 4                       Arowana International    001C000001ZzPK4IAN
#
#         Ticker 1 Ticker 2 Ticker 3  IPO Year  Year Delisted  Year Certified  \
# 0  NASDAQGS:BIRD      NaN      NaN    2021.0            NaN          2016.0
# 1  NASDAQGM:AMAL      NaN      NaN    2018.0            NaN          2017.0
# 2  NASDAQGS:APPH      NaN      NaN    2020.0            NaN          2019.0
# 3  BOVESPA:ARZZ3      NaN      NaN    2011.0            NaN          2022.0
# 4       ASX: AWN      NaN      NaN    2013.0         2021.0          2018.0
#
#   Public Listing Status  Year Decertified
# 0                active               NaN
# 1                active               NaN
# 2              delisted            2023.0
# 3                active               NaN
# 4              delisted               NaN

# %%
df.drop(['B Corp Impact Data ID', 'Ticker 2', 'Ticker 3'], axis=1, inplace = True)
print(len(df))
df.dropna(axis=0, subset=['Public Company Name (As Listed on Exchange)'], inplace=True)
print(len(df))
# Out:
# 999
# 68

# %%
display(df[df['Public Listing Status'] == 'delisted'])
# Out:
#    Public Company Name (As Listed on Exchange)       Ticker 1  IPO Year  \
# 2                             AppHarvest, Inc.  NASDAQGS:APPH    2020.0
# 4                        Arowana International       ASX: AWN    2013.0
# 14                        Freshlocal Solutions      TSE: LOCL    2019.0
#
#     Year Delisted  Year Certified Public Listing Status  Year Decertified
# 2             NaN          2019.0              delisted            2023.0
# 4          2021.0          2018.0              delisted               NaN
# 14         2021.0          2013.0              delisted               NaN

# %%
temp = df.copy()
temp = temp[temp['Public Listing Status'] == 'active']

temp['Ticker 1'].replace(": ", ":", regex=True, inplace=True)


print(len(temp))
temp['Exchange'] = temp['Ticker 1'].str.split(":").str[0]
temp['Ticker2'] = temp['Ticker 1'].str.split(":").str[1]
temp.dropna(subset=["Ticker2"], inplace=True) # Remove any NaN tickers

display(temp.head())
# Out:
# 65
#   Public Company Name (As Listed on Exchange)       Ticker 1  IPO Year  \
# 0                              Allbirds, Inc.  NASDAQGS:BIRD    2021.0
# 1                       Amalgamated Financial  NASDAQGM:AMAL    2018.0
# 3                                   Arezzo&Co  BOVESPA:ARZZ3    2011.0
# 5          Australian Ethical Investment Ltd.        ASX:AEF    2002.0
# 6                        Benefit Systems S.A.        WSE:BFT    2013.0
#
#    Year Delisted  Year Certified Public Listing Status  Year Decertified  \
# 0            NaN          2016.0                active               NaN
# 1            NaN          2017.0                active               NaN
# 3            NaN          2022.0                active               NaN
# 5            NaN          2014.0                active               NaN
# 6            NaN          2018.0                active               NaN
#
#    Exchange Ticker2
# 0  NASDAQGS    BIRD
# 1  NASDAQGM    AMAL
# 3   BOVESPA   ARZZ3
# 5       ASX     AEF
# 6       WSE     BFT

# %%
display(temp.loc[40:,:])
# Out:
#      Public Company Name (As Listed on Exchange)                Ticker 1  \
# 41                              Urb-it AB (publ)                OM:URBIT
# 42                           Vantea SMART S.p.A.                 BIT:VNT
# 43                       Viña Concha y Toro S.A.         SNSE:CONCHATORO
# 44                             Vital Farms, Inc.           NASDAQGM:VITL
# 45                   VivoPower International PLC           NASDAQCM:VVPR
# 46           Volpara Health Technologies Limited                 ASX:VHT
# 47                             Warby Parker Inc.               NYSE:WRBY
# 48                               Weleda AG Group  OTC-X:BEKB:Weleda N-PS
# 49                                     Zevia PBC               NYSE:ZVIA
# 51                          Aussie Broadband Ltd                 ASX:ABB
# 52                    Brooks Macdonald Group plc                 BRK:LSE
# 53  Compagnia dei Caraibi S.p.A. Società Benefit               XMIL:TIME
# 54                   Comvita New Zealand Limited                 NZE:CVT
# 55                                     Doxee SpA                 BIT:DOX
# 56                         Vinedos Emiliana S.A.           XSGO:EMILIANA
# 57                         Grupo de Moda SOMA SA              BVMF:SOMA3
# 58      Health And Happines(H&H)Intrntnl Hds Ltd                HKG:1112
# 59                                Homebiogas Ltd               TASE:HMGS
# 60                              Lever Style Corp                HKG:1346
# 61                              LOCCITANE Group                HKG:0973
# 62                               MoneyMe Limited                 ASX:MME
# 63  MPOWER FINANCING, PUBLIC BENEFIT CORPORATION                 ASX:MPR
# 64                       Ten Lifestyle Group PLC                LON:TENG
# 65                        Tpximpact Holdings PLC                 LON:TPX
# 66                    XEROS TECHNOLOGY GROUP PLC                 LON:XSG
# 67                     XENIA HOTELLERIE SOLUTION                 MIL:XHS
#
#     IPO Year  Year Delisted  Year Certified Public Listing Status  \
# 41    2017.0            NaN          2020.0                active
# 42    2021.0            NaN          2022.0                active
# 43       NaN            NaN          2021.0                active
# 44    2020.0            NaN          2015.0                active
# 45    2016.0            NaN          2018.0                active
# 46    2016.0            NaN          2022.0                active
# 47    2021.0            NaN          2011.0                active
# 48       NaN            NaN          2021.0                active
# 49    2021.0            NaN          2021.0                active
# 51    2020.0            NaN          2023.0                active
# 52    2005.0            NaN          2023.0                active
# 53    2021.0            NaN          2023.0                active
# 54    2003.0            NaN          2023.0                active
# 55    2019.0            NaN          2023.0                active
# 56    1996.0            NaN          2023.0                active
# 57    2020.0            NaN          2023.0                active
# 58    2010.0            NaN          2023.0                active
# 59    2021.0            NaN          2023.0                active
# 60    2019.0            NaN          2023.0                active
# 61    2010.0            NaN          2023.0                active
# 62    2019.0            NaN          2023.0                active
# 63    1988.0            NaN          2023.0                active
# 64    2017.0            NaN          2023.0                active
# 65    2018.0            NaN          2023.0                active
# 66    2014.0            NaN          2023.0                active
# 67    2023.0            NaN          2023.0                active
#
#     Year Decertified  Exchange     Ticker2
# 41               NaN        OM       URBIT
# 42               NaN       BIT         VNT
# 43               NaN      SNSE  CONCHATORO
# 44               NaN  NASDAQGM        VITL
# 45               NaN  NASDAQCM        VVPR
# 46               NaN       ASX         VHT
# 47               NaN      NYSE        WRBY
# 48               NaN     OTC-X        BEKB
# 49               NaN      NYSE        ZVIA
# 51               NaN       ASX         ABB
# 52               NaN       BRK         LSE
# 53               NaN      XMIL        TIME
# 54               NaN       NZE         CVT
# 55               NaN       BIT         DOX
# 56               NaN      XSGO    EMILIANA
# 57               NaN      BVMF       SOMA3
# 58               NaN       HKG        1112
# 59               NaN      TASE        HMGS
# 60               NaN       HKG        1346
# 61               NaN       HKG        0973
# 62               NaN       ASX         MME
# 63               NaN       ASX         MPR
# 64               NaN       LON        TENG
# 65               NaN       LON         TPX
# 66               NaN       LON         XSG
# 67               NaN       MIL         XHS

# %% [markdown]
# ### Stocks are from Global Exchanges - build and maintain an exchange conversion dictionary to interface with Yahoo Finance

# %%
exchange_dict = {'ASX': '.AX', 
                 'WSE': '.WA',
                 'BOVESPA': '.SA',
                 'ETHEX': '',
                 'TSX': '.TO',
                 'ENXTPA': '.PA',
                 'BME': '.MC',
                 'ENXTBR': '.BR',
                 'KLSE': '.KL',
                 'LSE': '.L',
                 'TWSE': '.TW',
                 'NZSE': '.NZ',
                 'SGX': '.SI',
                 'BIT': '.MI',
                 'TASE': '.TA',
                 'XMIL': '.MI',
                 'NZE': '.NZ',
                 'BVMF': '.SA',
                 'HKG': '.HK',
                 'LON': '.L',
                 'MIL': '.MI',
                 'MOVI3': '.SA',
                 'TSE': '.T',
                 'BRK': '.L',
                 'SNSE': '.SN',
                 'MOVIDA B3': '.SA',
                 'NYSE': '',
                 'NASDAQGS': '',
                 'NASDAQGM': '',
                 'NASDAQCM': ''
                }

exchange_map = {exchanges: extention
                 for exchanges, extention in exchange_dict.items()
                 for exchange in exchanges}

temp['Intl Extention'] = temp['Exchange'].map(exchange_map)

# %%
temp['Ticker'] = temp['Ticker2'] + temp['Intl Extention'] 
mask = temp['Ticker'].isna()

# Check to see if we missed any:
temp[mask]
# Out:
#          Public Company Name (As Listed on Exchange)                Ticker 1  \
# 19  Heidelberg District Community Enterprise Limited                 NSX:EIC
# 36                                         SIDERPERU             BVL:SIDERC1
# 41                                  Urb-it AB (publ)                OM:URBIT
# 48                                   Weleda AG Group  OTC-X:BEKB:Weleda N-PS
# 56                             Vinedos Emiliana S.A.           XSGO:EMILIANA
#
#     IPO Year  Year Delisted  Year Certified Public Listing Status  \
# 19    2019.0            NaN          2019.0                active
# 36    2006.0            NaN          2022.0                active
# 41    2017.0            NaN          2020.0                active
# 48       NaN            NaN          2021.0                active
# 56    1996.0            NaN          2023.0                active
#
#     Year Decertified Exchange   Ticker2 Intl Extention Ticker
# 19               NaN      NSX       EIC            NaN    NaN
# 36               NaN      BVL   SIDERC1            NaN    NaN
# 41               NaN       OM     URBIT            NaN    NaN
# 48               NaN    OTC-X      BEKB            NaN    NaN
# 56               NaN     XSGO  EMILIANA            NaN    NaN

# %%
#Find datafeed issues
tickers = temp['Ticker'].to_list()

count = 0
for t in tickers:
    try:
        ticker = yf.Ticker(t)
        info = None
    except:
        count +=1
        print(f"Cannot get info of {t}, it probably does not exist")

print("Total nans =", count, "which is", round(count/temp.shape[0],2)*100, '% of the total')
# Out:
# Cannot get info of nan, it probably does not exist
# Cannot get info of nan, it probably does not exist
# Cannot get info of nan, it probably does not exist
# Cannot get info of nan, it probably does not exist
# Cannot get info of nan, it probably does not exist
# Total nans = 5 which is 8.0 % of the total

# %%
# Remove Nans from stock universe:

b_corp_df = temp[-mask].copy()
display(b_corp_df.head())
# Out:
#   Public Company Name (As Listed on Exchange)       Ticker 1  IPO Year  \
# 0                              Allbirds, Inc.  NASDAQGS:BIRD    2021.0
# 1                       Amalgamated Financial  NASDAQGM:AMAL    2018.0
# 3                                   Arezzo&Co  BOVESPA:ARZZ3    2011.0
# 5          Australian Ethical Investment Ltd.        ASX:AEF    2002.0
# 6                        Benefit Systems S.A.        WSE:BFT    2013.0
#
#    Year Delisted  Year Certified Public Listing Status  Year Decertified  \
# 0            NaN          2016.0                active               NaN
# 1            NaN          2017.0                active               NaN
# 3            NaN          2022.0                active               NaN
# 5            NaN          2014.0                active               NaN
# 6            NaN          2018.0                active               NaN
#
#    Exchange Ticker2 Intl Extention    Ticker
# 0  NASDAQGS    BIRD                     BIRD
# 1  NASDAQGM    AMAL                     AMAL
# 3   BOVESPA   ARZZ3            .SA  ARZZ3.SA
# 5       ASX     AEF            .AX    AEF.AX
# 6       WSE     BFT            .WA    BFT.WA

# %%
isolate_us = False
if isolate_us:

    exchanges = set(temp['Exchange'])
    print(exchanges)
    us_ex = ['NYSE', 'NASDAQGS','NASDAQGM', 'NASDAQCM']
    us = temp[temp['Exchange'].isin(us_ex)]
    print("Isolating US Companies")
    display(us.head())

# %% [markdown]
# ### List of Companies with B-Corp Subsidiaries
# Unilever (NYSE: UN): (Pukka (UK), Mãe Terra (Brazil), Sir Kensington’s (US), Ben & Jerry’s (US), Olly Nutrition (US), Seventh Generation (US), Sundial (US), T2 Tea (Australia), Graze (UK))
#
# B2W (B3: BTOW3): Courrieros (Brazil)
#
# Grupo Soma (B3: SOMA3): Companhia Hering (Brazil)
#
# Arezzo&Co (B3: ARZZ3): Reserva (Brazil)
#
# Procter & Gamble (NYSE: PG): (New Chapter (US))
#
# AB Inbev: (4 Pines Brewing Company)
#
# Banco Estado: (Banco Estado Microempresas, Caja Vecina)
#
# Coca-Cola: (Innocent Drinks)
#
# Fairfax Financial: (The Redwoods Group)
#
# Gap: (Athleta, Hill City)
#
# Kikkoman: (Country Life)
#
# Lactalis: (Stonyfield Farm)
#
# Land O’ Lakes: (Vermonta Creamery)
#
# Nestle: (Essential Living Foods, Garden of Life, Lily's Kitchen)
#
# Oppenheimer Funds Inc.: (SNW Asset Management)
#
# Rakuten: (OverDrive)
#
# The Hain Celestial Group: (Ella’s Kitchen)
#
# Vina Concha y Toro: (Fetzer Vineyards)
#
#
# Hortfruti S.A.: Hortifruti Chile
#
# Danone SA: (Danone North America, Alpro, Danone Waters of America, Danone Canada, -Aguas Danone Argentina, Bledina, Danone Aqua Indonesia, Danone Egypt, Danone Iberia, Danone Manifesto Ventures, Danone UK, Grameen Danone Foods, Happy Family, Les 2 Vaches, Danone Waters Germany, Danone Dairy Ireland, Danone Waters Spain, Danone Netherlands, Danone Dairy Belgium, Nutricia Bago, Danone ELN Greater China, Danone Japan, Volvic, Danone Brazil)
#
# Caixabank (Imagin Ban)
#
# Banco Sabadell (Sogeviso)
#
# iSun (SunCommon)

# %%
add_subs = False
public_subs = ['UL', 'SOMA3.SA', 'ABI.BR', 'PG', 'FFH.TO', 'KO', 'GPS', 'KIK.F', 'NESN.SW',
               'OPY', '4755.T', 'HAIN', 'DANOY', 'CABK.MC', 'ISUN']

# %%
def get_stock_data (df):
    tickers_list = df['Ticker'].tolist()
    if add_subs:
        tickers_list = tickers_list + public_subs
    tickers_data= {}
    
    for ticker in tickers_list:
        ticker_object = yf.Ticker(ticker)
        
        #convert info() output from dictionary to dataframe
        temp = pd.DataFrame.from_dict(ticker_object.info, orient="index")
        temp.reset_index(inplace=True)
        temp.columns = ["Attribute", "Recent"]

        # add (ticker, dataframe) to main dictionary
        tickers_data[ticker] = temp

    return tickers_data

# %%
if isolate_us:
    load_stock_data = get_stock_data (us)
else:
    load_stock_data = get_stock_data (b_corp_df)
    
print("Number of Stock Records Loaded", len(load_stock_data))
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SZL.AX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SZL.AX&crumb=NB.zG8HhBks
# Number of Stock Records Loaded 57

# %%
# Clean df:
stock_data = pd.concat(load_stock_data) #turn from dict to df
stock_data = stock_data.reset_index()

del stock_data["level_1"] # clean up unnecessary column
stock_data.columns = ["Ticker", "Attribute", "Recent"] # update column names


attr_to_keep = ['shortName', 'longName', 'industry', 'sector','previousClose', 'sharesOutstanding', 'impliedSharesOutstanding',
               'marketCap',  'currency', 'country', 'website', 'enterpriseValue',
                'trailingEps', 'forwardEps', 'enterprisetoEbitda', 'ebitda', 'grossMargins', 'ebitdaMargins', 'operatingMargins']


stock_data = stock_data[stock_data["Attribute"].isin(attr_to_keep)].reset_index()
del stock_data["index"] # clean up unnecessary column



display(stock_data.head(15))
# Out:
#    Ticker                 Attribute                    Recent
# 0    BIRD                   country             United States
# 1    BIRD                   website  https://www.allbirds.com
# 2    BIRD                  industry            Apparel Retail
# 3    BIRD                    sector         Consumer Cyclical
# 4    BIRD             previousClose                    0.6126
# 5    BIRD                 marketCap                  98467416
# 6    BIRD                  currency                       USD
# 7    BIRD           enterpriseValue                  58985908
# 8    BIRD         sharesOutstanding                 102641000
# 9    BIRD  impliedSharesOutstanding                 155188992
# 10   BIRD               trailingEps                     -1.01
# 11   BIRD                forwardEps                     -0.58
# 12   BIRD                 shortName            Allbirds, Inc.
# 13   BIRD                  longName            Allbirds, Inc.
# 14   BIRD                    ebitda                 -97849000

# %%
print("Number of Stocks:", len(stock_data['Ticker'].unique()))
display(stock_data['Ticker'].unique())
# Out:
# Number of Stocks: 54
# array(['BIRD', 'AMAL', 'ARZZ3.SA', 'AEF.AX', 'BFT.WA', 'BIO.AX',
#        'CWEB.TO', 'CLSA3.SA', 'MLMFI.PA', 'COUR', 'FLOW.TO', 'FREY.PA',
#        'GFI.NZ', 'GROV', 'HAN.MC', 'HLZ.MC', 'INCLU.BR', 'IBAB.BR',
#        'KPG.AX', 'KCT.L', 'KMD.NZ', 'LMND', 'LFG.AX', 'MOVI3.SA',
#        'NTCO3.SA', '2897.TW', '1H2.SI', 'ALQP.PA', 'RETI.MI', '6088.T',
#        'SML.NZ', 'COCO', 'VNT.MI', 'CONCHATORO.SN', 'VITL', 'VVPR',
#        'VHT.AX', 'WRBY', 'ZVIA', 'ABB.AX', 'TIME.MI', 'CVT.NZ', 'DOX.MI',
#        'SOMA3.SA', '1112.HK', 'HMGS.TA', '1346.HK', '0973.HK', 'MME.AX',
#        'MPR.AX', 'TENG.L', 'TPX.L', 'XSG.L', 'XHS.MI'], dtype=object)

# %%
stock_data_filtered = stock_data.pivot(columns = 'Attribute', index='Ticker', values='Recent')
stock_data_filtered.columns

# More info:
#stock_data_filtered = stock_data_filtered[['shortName', 'longName','country', 'currency', 'previousClose',
#                                           'sharesOutstanding', 'impliedSharesOutstanding','marketCap', 'enterpriseValue',
#                                           'ebitda', 'forwardEps',  'trailingEps', 'grossMargins', 'operatingMargins', 'ebitdaMargins',
#                                             'industry', 'sector', 'website']]
# Only essential info:
stock_data_filtered = stock_data_filtered[['shortName', 'longName','country', 'currency', 'previousClose',
                                           'impliedSharesOutstanding','marketCap','industry', 'sector', 'website']]

display(stock_data_filtered.head(10))
# Out:
# Attribute                    shortName  \
# Ticker
# 0973.HK                     L'OCCITANE
# 1112.HK                  H&H INTL HLDG
# 1346.HK                    LEVER STYLE
# 1H2.SI                    $ Olive Tree
# 2897.TW                  O-BANK CO LTD
# 6088.T           SIGMAXYZ HOLDINGS INC
# ABB.AX            AUSSIEBAND FPO [ABB]
# AEF.AX             A ETHICAL FPO [AEF]
# ALQP.PA                       QUADPACK
# AMAL       Amalgamated Financial Corp.
#
# Attribute                                           longName        country  \
# Ticker
# 0973.HK                        L'Occitane International S.A.     Luxembourg
# 1112.HK    Health and Happiness (H&H) International Holdi...      Hong Kong
# 1346.HK                              Lever Style Corporation      Hong Kong
# 1H2.SI                            Olive Tree Estates Limited      Singapore
# 2897.TW                                     O-Bank Co., Ltd.         Taiwan
# 6088.T                                SIGMAXYZ Holdings Inc.          Japan
# ABB.AX                              Aussie Broadband Limited      Australia
# AEF.AX                 Australian Ethical Investment Limited      Australia
# ALQP.PA                            Quadpack Industries, S.A.          Spain
# AMAL                             Amalgamated Financial Corp.  United States
#
# Attribute currency previousClose impliedSharesOutstanding    marketCap  \
# Ticker
# 0973.HK        HKD          30.6               1472169984  43429015552
# 1112.HK        HKD         10.22                645561024   6636367360
# 1346.HK        HKD          0.87                645899008    556017024
# 1H2.SI         SGD          0.08                115845000      9267600
# 2897.TW        TWD          9.88               2716470016  27164700672
# 6088.T         JPY        1583.0                 43201300  66776170496
# ABB.AX         AUD          3.61                295184992   1083328896
# AEF.AX         AUD          4.89                112782000    551503936
# ALQP.PA        EUR          13.9                  4382130     61038320
# AMAL           USD          24.6                 30615100    751776256
#
# Attribute                       industry                  sector  \
# Ticker
# 0973.HK    Household & Personal Products      Consumer Defensive
# 1112.HK                   Packaged Foods      Consumer Defensive
# 1346.HK            Apparel Manufacturing       Consumer Cyclical
# 1H2.SI         Real Estate - Diversified             Real Estate
# 2897.TW                 Banks - Regional      Financial Services
# 6088.T       Specialty Business Services             Industrials
# ABB.AX                  Telecom Services  Communication Services
# AEF.AX                  Asset Management      Financial Services
# ALQP.PA           Packaging & Containers       Consumer Cyclical
# AMAL                    Banks - Regional      Financial Services
#
# Attribute                               website
# Ticker
# 0973.HK             https://group.loccitane.com
# 1112.HK                   https://www.hh.global
# 1346.HK              https://www.leverstyle.com
# 1H2.SI         https://www.olivetreeestates.com
# 2897.TW                  https://www.o-bank.com
# 6088.T                 https://www.sigmaxyz.com
# ABB.AX       https://www.aussiebroadband.com.au
# AEF.AX     https://www.australianethical.com.au
# ALQP.PA                https://www.quadpack.com
# AMAL            https://www.amalgamatedbank.com

# %% [markdown]
# ## Add in stock price as of beginning of index:

# %%
def get_starting_price(df, start = s):
    tickers_list = df.index.tolist()
    tickers_data= {}
    first_object = yf.Ticker(tickers_list[0])
    
    prices = pd.DataFrame.from_dict(first_object.history(start=start, interval = "1d"))
    prices.drop(['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'], axis=1, inplace=True)
    prices.columns = [tickers_list[0]]

    
    for ticker in tickers_list[1:]:
        ticker_object = yf.Ticker(ticker)
        try:
            temp = pd.DataFrame.from_dict(ticker_object.history(start=start, interval = "1d"))
            temp.drop(['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'], axis=1, inplace=True)
            temp.columns = [ticker]
            prices = prices.merge(temp, how="outer", left_index=True, right_index=True)
        except:
            continue
    
    
    # Collapse date across international zones:
    prices.index = pd.to_datetime(prices.index).date
      
        
    prices = prices.groupby(prices.index).ffill() 
    prices = prices.groupby(prices.index).bfill()
    prices = prices.groupby(prices.index).last()
    
    
    return prices

# %%
data = get_starting_price(stock_data_filtered, start=s)
starting_px = data.filter(like='2022-01-04', axis=0).T
#data.to_csv('QC_starting_price.csv')

# %% [markdown]
# ### Incorporate exchange rates to translate price and market cap into USD

# %%
# Get avaialable currencies
currency_dict = {}

url = "https://currency-conversion-and-exchange-rates.p.rapidapi.com/symbols"

    #headers = {"X-RapidAPI-Key": "af4b092441msh3f4304a0bce0366p1680a3jsn93d4c3a0659f",
headers = {"X-RapidAPI-Key": "884638c782msh3dc9c5784730cc0p1a0f42jsnf54c2327e84c",
    "X-RapidAPI-Host": "currency-conversion-and-exchange-rates.p.rapidapi.com"
          }

response = requests.get(url, headers=headers)

api_data = response.json()

    
for symbol, curr in api_data['symbols'].items():
    currency_dict[symbol] = [curr, 0]

# %%
## Access Exchange Rates at Start of Measurement:
def get_rates(date):
    url = "https://currency-conversion-and-exchange-rates.p.rapidapi.com/" + str(date)

    #querystring = {"from":"USD","to":"EUR,GBP"}
    querystring = {'base':'USD'}

        #headers = {"X-RapidAPI-Key": "af4b092441msh3f4304a0bce0366p1680a3jsn93d4c3a0659f",
    headers = {"X-RapidAPI-Key": "884638c782msh3dc9c5784730cc0p1a0f42jsnf54c2327e84c",
        "X-RapidAPI-Host": "currency-conversion-and-exchange-rates.p.rapidapi.com"
              }

    response = requests.get(url, headers=headers, params=querystring)

    return response.json()

    #for key in exch_data: 
    #    print(key,":", exch_data[key])

# %%
## Combine date from exch_data with names / symbols in currency_dict:
exch_data = get_rates(date='2024-01-02')

for symbol, rate in exch_data['rates'].items():
    for key in currency_dict.keys():
        if symbol == key:
            currency_dict[key][1] = rate

# %%
currency_dict
# Out:
# {'ANG': ['Netherlands Antillean Guilder', 1.802754],
#  'SVC': ['Salvadoran Colón', 0],
#  'CAD': ['Canadian Dollar', 1.332265],
#  'XCD': ['East Caribbean Dollar', 2.70255],
#  'MVR': ['Maldivian Rufiyaa', 15.394981],
#  'HRK': ['Croatian Kuna', 6.98177],
#  'AUD': ['Australian Dollar', 1.478066],
#  'MWK': ['Malawian Kwacha', 1682.000329],
#  'XAG': ['Silver (troy ounce)', 0.042301],
#  'MAD': ['Moroccan Dirham', 9.929013],
#  'PHP': ['Philippine Peso', 55.580372],
#  'NAD': ['Namibian Dollar', 18.569884],
#  'GNF': ['Guinean Franc', 8600.000003],
#  'KES': ['Kenyan Shilling', 157.349704],
#  'MZN': ['Mozambican Metical', 63.24995],
#  'BTN': ['Bhutanese Ngultrum', 84.025935],
#  'MGA': ['Malagasy Ariary', 4589.99995],
#  'AZN': ['Azerbaijani Manat', 1.696139],
#  'XAU': ['Gold (troy ounce)', 0.000486],
#  'RON': ['Romanian Leu', 4.542902],
#  'CHF': ['Swiss Franc', 0.850195],
#  'EGP': ['Egyptian Pound', 30.925201],
#  'BSD': ['Bahamian Dollar', 1.000292],
#  'TWD': ['New Taiwan Dollar', 30.894018],
#  'GGP': ['Guernsey Pound', 0.786705],
#  'LVL': ['Latvian Lats', 0.60489],
#  'MMK': ['Myanma Kyat', 2100.602778],
#  'WST': ['Samoan Tala', 2.698297],
#  'ILS': ['Israeli New Sheqel', 3.639696],
#  'BHD': ['Bahraini Dinar', 0.376845],
#  'GBP': ['British Pound Sterling', 0.79224],
#  'TZS': ['Tanzanian Shilling', 2514.999877],
#  'SDG': ['South Sudanese Pound', 601.000196],
#  'LAK': ['Laotian Kip', 20562.465494],
#  'DJF': ['Djiboutian Franc', 177.719565],
#  'BYN': ['New Belarusian Ruble', 3.303209],
#  'LBP': ['Lebanese Pound', 15062.499188],
#  'RWF': ['Rwandan Franc', 1260.86],
#  'PEN': ['Peruvian Nuevo Sol', 3.713497],
#  'EUR': ['Euro', 0.91396],
#  'ZMK': ['Zambian Kwacha (pre-2013)', 9001.202091],
#  'RSD': ['Serbian Dinar', 107.091975],
#  'INR': ['Indian Rupee', 83.25725],
#  'MUR': ['Mauritian Rupee', 44.020085],
#  'BWP': ['Botswanan Pula', 13.364278],
#  'GEL': ['Georgian Lari', 2.680173],
#  'KMF': ['Comorian Franc', 450.513757],
#  'UZS': ['Uzbekistan Som', 12349.999723],
#  'RUB': ['Russian Ruble', 90.430359],
#  'CUC': ['Cuban Convertible Peso', 1],
#  'BGN': ['Bulgarian Lev', 1.787597],
#  'JOD': ['Jordanian Dinar', 0.709602],
#  'NGN': ['Nigerian Naira', 884.818945],
#  'BDT': ['Bangladeshi Taka', 109.786792],
#  'PKR': ['Pakistani Rupee', 281.950354],
#  'BRL': ['Brazilian Real', 4.923979],
#  'KZT': ['Kazakhstani Tenge', 455.620708],
#  'CVE': ['Cape Verdean Escudo', 100.149596],
#  'HNL': ['Honduran Lempira', 24.749457],
#  'NZD': ['New Zealand Dollar', 1.60014],
#  'ERN': ['Eritrean Nakfa', 15],
#  'NPR': ['Nepalese Rupee', 134.441314],
#  'ZMW': ['Zambian Kwacha', 25.731794],
#  'FKP': ['Falkland Islands Pound', 0.786705],
#  'DZD': ['Algerian Dinar', 134.679875],
#  'JMD': ['Jamaican Dollar', 154.316147],
#  'CRC': ['Costa Rican Colón', 519.788437],
#  'GMD': ['Gambian Dalasi', 67.225002],
#  'PLN': ['Polish Zloty', 3.991717],
#  'AMD': ['Armenian Dram', 404.880451],
#  'BMD': ['Bermudan Dollar', 1],
#  'BZD': ['Belize Dollar', 2.016378],
#  'BBD': ['Barbadian Dollar', 2.019734],
#  'SBD': ['Solomon Islands Dollar', 8.404697],
#  'IDR': ['Indonesian Rupiah', 15505],
#  'ALL': ['Albanian Lek', 94.18978],
#  'IQD': ['Iraqi Dinar', 1310],
#  'BIF': ['Burundian Franc', 2855],
#  'HKD': ['Hong Kong Dollar', 7.81532],
#  'GIP': ['Gibraltar Pound', 0.786705],
#  'BAM': ['Bosnia-Herzegovina Convertible Mark', 1.783545],
#  'LKR': ['Sri Lankan Rupee', 322.110562],
#  'QAR': ['Qatari Rial', 3.640497],
#  'SAR': ['Saudi Riyal', 3.750007],
#  'TOP': ['Tongan Paʻanga', 2.33115],
#  'SEK': ['Swedish Krona', 10.20999],
#  'ZAR': ['South African Rand', 18.56645],
#  'ARS': ['Argentine Peso', 810.561155],
#  'MYR': ['Malaysian Ringgit', 4.603498],
#  'BYR': ['Belarusian Ruble', 19600],
#  'KPW': ['North Korean Won', 900.008743],
#  'CZK': ['Czech Republic Koruna', 22.543297],
#  'STD': ['São Tomé and Príncipe Dobra', 20697.981008],
#  'BTC': ['Bitcoin', 2.2239327e-05],
#  'ZWL': ['Zimbabwean Dollar', 321.999592],
#  'LSL': ['Lesotho Loti', 18.570097],
#  'COP': ['Colombian Peso', 3889.23],
#  'PAB': ['Panamanian Balboa', 1.000301],
#  'IRR': ['Iranian Rial', 42047.496316],
#  'CNH': ['Chinese Yuan Offshore', 0],
#  'NOK': ['Norwegian Krone', 10.349175],
#  'XPF': ['CFP Franc', 109.374992],
#  'XOF': ['CFA Franc BCEAO', 594.504833],
#  'XDR': ['Special Drawing Rights', 0.745598],
#  'OMR': ['Omani Rial', 0.384895],
#  'CNY': ['Chinese Yuan', 7.099602],
#  'NIO': ['Nicaraguan Córdoba', 36.720003],
#  'AOA': ['Angolan Kwanza', 832.497707],
#  'SCR': ['Seychellois Rupee', 14.197264],
#  'MOP': ['Macanese Pataca', 8.050829],
#  'ISK': ['Icelandic Króna', 137.709983],
#  'VND': ['Vietnamese Dong', 24335],
#  'VES': ['Sovereign Bolivar', 35.822194],
#  'USD': ['United States Dollar', 1],
#  'UYU': ['Uruguayan Peso', 39.075858],
#  'VEF': ['Venezuelan Bolívar Fuerte', 3587972.932726],
#  'MRU': ['Mauritanian Ouguiya', 39.649989],
#  'UGX': ['Ugandan Shilling', 3789.053238],
#  'DOP': ['Dominican Peso', 57.919916],
#  'UAH': ['Ukrainian Hryvnia', 38.150158],
#  'BOB': ['Bolivian Boliviano', 6.912148],
#  'TTD': ['Trinidad and Tobago Dollar', 6.789167],
#  'KGS': ['Kyrgystani Som', 89.085304],
#  'TND': ['Tunisian Dinar', 3.093498],
#  'SGD': ['Singapore Dollar', 1.326405],
#  'TMT': ['Turkmenistani Manat', 3.51],
#  'GHS': ['Ghanaian Cedi', 11.949598],
#  'TJS': ['Tajikistani Somoni', 10.948303],
#  'KHR': ['Cambodian Riel', 4090.000036],
#  'ETB': ['Ethiopian Birr', 56.195264],
#  'PGK': ['Papua New Guinean Kina', 3.70803],
#  'THB': ['Thai Baht', 34.263001],
#  'AED': ['United Arab Emirates Dirham', 3.672796],
#  'GTQ': ['Guatemalan Quetzal', 7.825096],
#  'LRD': ['Liberian Dollar', 188.494157],
#  'SYP': ['Syrian Pound', 13001.797058],
#  'KYD': ['Cayman Islands Dollar', 0.833615],
#  'SRD': ['Surinamese Dollar', 36.745499],
#  'HTG': ['Haitian Gourde', 131.911323],
#  'LYD': ['Libyan Dinar', 4.775014],
#  'SLL': ['Sierra Leonean Leone', 19749.999899],
#  'SLE': ['Sierra Leonean Leone', 22.795066],
#  'SHP': ['Saint Helena Pound', 1.262304],
#  'IMP': ['Manx pound', 0.786705],
#  'FJD': ['Fijian Dollar', 2.228702],
#  'PYG': ['Paraguayan Guarani', 7287.202028],
#  'KRW': ['South Korean Won', 1308.849868],
#  'SZL': ['Swazi Lilangeni', 18.570217],
#  'GYD': ['Guyanaese Dollar', 209.270303],
#  'MDL': ['Moldovan Leu', 17.464573],
#  'MXN': ['Mexican Peso', 17.034397],
#  'CLP': ['Chilean Peso', 884.320491],
#  'LTL': ['Lithuanian Litas', 2.95274],
#  'SOS': ['Somali Shilling', 570.999787],
#  'MNT': ['Mongolian Tugrik', 3439.712623],
#  'AFN': ['Afghan Afghani', 69.999838],
#  'CUP': ['Cuban Peso', 26.5],
#  'CLF': ['Chilean Unit of Account (UF)', 0.032049],
#  'JPY': ['Japanese Yen', 142.156502],
#  'TRY': ['Turkish Lira', 29.753575],
#  'YER': ['Yemeni Rial', 250.250298],
#  'HUF': ['Hungarian Forint', 348.829813],
#  'BND': ['Brunei Dollar', 1.325497],
#  'JEP': ['Jersey Pound', 0.786705],
#  'MKD': ['Macedonian Denar', 56.219156],
#  'AWG': ['Aruban Florin', 1.8025],
#  'CDF': ['Congolese Franc', 2680.000256],
#  'VUV': ['Vanuatu Vatu', 117.373873],
#  'XAF': ['CFA Franc BEAC', 598.184355],
#  'KWD': ['Kuwaiti Dinar', 0.30748],
#  'DKK': ['Danish Krone', 6.81438]}

# %%
## Add exhange rates and calculate USD equivalents:

#exchange_map = {exchanges: extention
#                 for exchanges, extention in exchange_dict.items()
#                 for exchange in exchanges}


currency_map = {symbols: rate
                 for symbols, name in currency_dict.items()
                 for rate in name}



stock_data_filtered['beginningUSDExchangeRate'] = stock_data_filtered['currency'].map(currency_map)

# %%
stock_data_filtered = stock_data_filtered.join(starting_px)

# %%
# Check to see that exchange rates mapped correctly:
stock_data_filtered.head(15)
# Out:
#                             shortName  \
# Ticker
# 0973.HK                    L'OCCITANE
# 1112.HK                 H&H INTL HLDG
# 1346.HK                   LEVER STYLE
# 1H2.SI                   $ Olive Tree
# 2897.TW                 O-BANK CO LTD
# 6088.T          SIGMAXYZ HOLDINGS INC
# ABB.AX           AUSSIEBAND FPO [ABB]
# AEF.AX            A ETHICAL FPO [AEF]
# ALQP.PA                      QUADPACK
# AMAL      Amalgamated Financial Corp.
# ARZZ3.SA       AREZZO CO   ON      NM
# BFT.WA                        BENEFIT
# BIO.AX           BIOME AUST FPO [BIO]
# BIRD                   Allbirds, Inc.
# CLSA3.SA       CLEARSALE   ON      NM
#
#                                                    longName        country  \
# Ticker
# 0973.HK                       L'Occitane International S.A.     Luxembourg
# 1112.HK   Health and Happiness (H&H) International Holdi...      Hong Kong
# 1346.HK                             Lever Style Corporation      Hong Kong
# 1H2.SI                           Olive Tree Estates Limited      Singapore
# 2897.TW                                    O-Bank Co., Ltd.         Taiwan
# 6088.T                               SIGMAXYZ Holdings Inc.          Japan
# ABB.AX                             Aussie Broadband Limited      Australia
# AEF.AX                Australian Ethical Investment Limited      Australia
# ALQP.PA                           Quadpack Industries, S.A.          Spain
# AMAL                            Amalgamated Financial Corp.  United States
# ARZZ3.SA                   Arezzo Indústria e Comércio S.A.         Brazil
# BFT.WA                                 Benefit Systems S.A.         Poland
# BIO.AX                              Biome Australia Limited      Australia
# BIRD                                         Allbirds, Inc.  United States
# CLSA3.SA                                     ClearSale S.A.         Brazil
#
#          currency previousClose impliedSharesOutstanding    marketCap  \
# Ticker
# 0973.HK       HKD          30.6               1472169984  43429015552
# 1112.HK       HKD         10.22                645561024   6636367360
# 1346.HK       HKD          0.87                645899008    556017024
# 1H2.SI        SGD          0.08                115845000      9267600
# 2897.TW       TWD          9.88               2716470016  27164700672
# 6088.T        JPY        1583.0                 43201300  66776170496
# ABB.AX        AUD          3.61                295184992   1083328896
# AEF.AX        AUD          4.89                112782000    551503936
# ALQP.PA       EUR          13.9                  4382130     61038320
# AMAL          USD          24.6                 30615100    751776256
# ARZZ3.SA      BRL         52.03                112422000   5833061888
# BFT.WA        PLN        2730.0                  2999100   8155240960
# BIO.AX        AUD         0.325                212828000     68104960
# BIRD          USD        0.6126                155188992     98467416
# CLSA3.SA      BRL          7.65                200507008   1561949568
#
#                                industry                  sector  \
# Ticker
# 0973.HK   Household & Personal Products      Consumer Defensive
# 1112.HK                  Packaged Foods      Consumer Defensive
# 1346.HK           Apparel Manufacturing       Consumer Cyclical
# 1H2.SI        Real Estate - Diversified             Real Estate
# 2897.TW                Banks - Regional      Financial Services
# 6088.T      Specialty Business Services             Industrials
# ABB.AX                 Telecom Services  Communication Services
# AEF.AX                 Asset Management      Financial Services
# ALQP.PA          Packaging & Containers       Consumer Cyclical
# AMAL                   Banks - Regional      Financial Services
# ARZZ3.SA         Footwear & Accessories       Consumer Cyclical
# BFT.WA                          Leisure       Consumer Cyclical
# BIO.AX                   Packaged Foods      Consumer Defensive
# BIRD                     Apparel Retail       Consumer Cyclical
# CLSA3.SA      Software - Infrastructure              Technology
#
#                                        website  beginningUSDExchangeRate  \
# Ticker
# 0973.HK            https://group.loccitane.com                  7.815320
# 1112.HK                  https://www.hh.global                  7.815320
# 1346.HK             https://www.leverstyle.com                  7.815320
# 1H2.SI        https://www.olivetreeestates.com                  1.326405
# 2897.TW                 https://www.o-bank.com                 30.894018
# 6088.T                https://www.sigmaxyz.com                142.156502
# ABB.AX      https://www.aussiebroadband.com.au                  1.478066
# AEF.AX    https://www.australianethical.com.au                  1.478066
# ALQP.PA               https://www.quadpack.com                  0.913960
# AMAL           https://www.amalgamatedbank.com                  1.000000
# ARZZ3.SA            https://ri.arezzoco.com.br                  4.923979
# BFT.WA           https://www.benefitsystems.pl                  3.991717
# BIO.AX          https://www.biomeaustralia.com                  1.478066
# BIRD                  https://www.allbirds.com                  1.000000
# CLSA3.SA          https://www.clearsale.com.br                  4.923979
#
#            2022-01-04
# Ticker
# 0973.HK     31.003922
# 1112.HK     10.629018
# 1346.HK      0.305428
# 1H2.SI       0.110000
# 2897.TW      7.403813
# 6088.T    1166.818604
# ABB.AX       4.600000
# AEF.AX      13.177149
# ALQP.PA     23.799999
# AMAL        16.284925
# ARZZ3.SA    66.436813
# BFT.WA     629.166260
# BIO.AX       0.120000
# BIRD        15.590000
# CLSA3.SA     8.970000

# %%
# Calculate USD price and USD marketcap
s_d = dt.strptime(s, '%Y-%M-%d').date()
stock_data_filtered['beginningCloseUSD'] = stock_data_filtered[s_d] / stock_data_filtered['beginningUSDExchangeRate']
stock_data_filtered['beginningMarketCapUSD'] = stock_data_filtered['impliedSharesOutstanding']* stock_data_filtered['beginningCloseUSD']

stock_data_filtered.head(20)
# Out:
#                                      shortName  \
# Ticker
# 0973.HK                             L'OCCITANE
# 1112.HK                          H&H INTL HLDG
# 1346.HK                            LEVER STYLE
# 1H2.SI                            $ Olive Tree
# 2897.TW                          O-BANK CO LTD
# 6088.T                   SIGMAXYZ HOLDINGS INC
# ABB.AX                    AUSSIEBAND FPO [ABB]
# AEF.AX                     A ETHICAL FPO [AEF]
# ALQP.PA                               QUADPACK
# AMAL               Amalgamated Financial Corp.
# ARZZ3.SA                AREZZO CO   ON      NM
# BFT.WA                                 BENEFIT
# BIO.AX                    BIOME AUST FPO [BIO]
# BIRD                            Allbirds, Inc.
# CLSA3.SA                CLEARSALE   ON      NM
# COCO               The Vita Coco Company, Inc.
# CONCHATORO.SN               VINA CONCHA Y TORO
# COUR                            Coursera, Inc.
# CVT.NZ         Comvita Limited Ordinary Shares
# CWEB.TO            CHARLOTTES WEB HOLDINGS INC
#
#                                                         longName  \
# Ticker
# 0973.HK                            L'Occitane International S.A.
# 1112.HK        Health and Happiness (H&H) International Holdi...
# 1346.HK                                  Lever Style Corporation
# 1H2.SI                                Olive Tree Estates Limited
# 2897.TW                                         O-Bank Co., Ltd.
# 6088.T                                    SIGMAXYZ Holdings Inc.
# ABB.AX                                  Aussie Broadband Limited
# AEF.AX                     Australian Ethical Investment Limited
# ALQP.PA                                Quadpack Industries, S.A.
# AMAL                                 Amalgamated Financial Corp.
# ARZZ3.SA                        Arezzo Indústria e Comércio S.A.
# BFT.WA                                      Benefit Systems S.A.
# BIO.AX                                   Biome Australia Limited
# BIRD                                              Allbirds, Inc.
# CLSA3.SA                                          ClearSale S.A.
# COCO                                 The Vita Coco Company, Inc.
# CONCHATORO.SN                            Viña Concha y Toro S.A.
# COUR                                              Coursera, Inc.
# CVT.NZ                                           Comvita Limited
# CWEB.TO                           Charlotte's Web Holdings, Inc.
#
#                      country currency previousClose impliedSharesOutstanding  \
# Ticker
# 0973.HK           Luxembourg      HKD          30.6               1472169984
# 1112.HK            Hong Kong      HKD         10.22                645561024
# 1346.HK            Hong Kong      HKD          0.87                645899008
# 1H2.SI             Singapore      SGD          0.08                115845000
# 2897.TW               Taiwan      TWD          9.88               2716470016
# 6088.T                 Japan      JPY        1583.0                 43201300
# ABB.AX             Australia      AUD          3.61                295184992
# AEF.AX             Australia      AUD          4.89                112782000
# ALQP.PA                Spain      EUR          13.9                  4382130
# AMAL           United States      USD          24.6                 30615100
# ARZZ3.SA              Brazil      BRL         52.03                112422000
# BFT.WA                Poland      PLN        2730.0                  2999100
# BIO.AX             Australia      AUD         0.325                212828000
# BIRD           United States      USD        0.6126                155188992
# CLSA3.SA              Brazil      BRL          7.65                200507008
# COCO           United States      USD         24.75                 56929300
# CONCHATORO.SN          Chile      CLP        1241.2                744057984
# COUR           United States      USD         11.97                157324000
# CVT.NZ           New Zealand      NZD          2.07                 70225400
# CWEB.TO        United States      CAD          0.26                156960992
#
#                   marketCap                                  industry  \
# Ticker
# 0973.HK         43429015552             Household & Personal Products
# 1112.HK          6636367360                            Packaged Foods
# 1346.HK           556017024                     Apparel Manufacturing
# 1H2.SI              9267600                 Real Estate - Diversified
# 2897.TW         27164700672                          Banks - Regional
# 6088.T          66776170496               Specialty Business Services
# ABB.AX           1083328896                          Telecom Services
# AEF.AX            551503936                          Asset Management
# ALQP.PA            61038320                    Packaging & Containers
# ALQP.PA             114112970.65156
# AMAL                498564621.47541
# ARZZ3.SA          1516854444.533318
# BFT.WA              472712000.79141
# BIO.AX              17278903.262203
# BIRD              2419396408.959961
# CLSA3.SA           365263116.536676
# COCO                    683151600.0
# CONCHATORO.SN     1012725356.718075
# COUR                   3933100000.0
# CVT.NZ             155268703.279696
# CWEB.TO            160228596.687104

# %%
if download:
    stock_data_filtered.to_csv("mkt_cap_details.csv")

# %% [markdown]
# ## Filter Universe of Stocks by USD MarketCap

# %%
def filter_index(df, size=True, num=True, size_thresh = 1000000000, num_thresh = 20, col='beginningMarketCapUSD'):
    temp = df.copy()
    if size == True:
        temp = temp[temp[col] >= size_thresh]
    
    if num == True:
        temp.sort_values(by=[col], ascending=False, inplace = True)
        temp = temp.iloc[0:num_thresh,:]
            
    if 'ABI.BR' in temp.index:
        temp.loc['ABI.BR','impliedSharesOutstanding'] = 1982790000
    
    return temp

# %%
stock_index_top20 = filter_index(stock_data_filtered, size = False, num_thresh=20)
stock_index_top30 = filter_index(stock_data_filtered, size = False, num_thresh=30)
stock_index_over1b = filter_index(stock_data_filtered, size = True, num=False, size_thresh=1000000000)
stock_index_cutoff = filter_index(stock_data_filtered, size = False, num_thresh=40)

df_list = [stock_index_top20, stock_index_top30, stock_index_over1b, stock_index_cutoff]

print(stock_index_top20.shape, stock_index_top30.shape, stock_index_over1b.shape, stock_index_cutoff.shape)
# Out:
# (20, 14) (30, 14) (14, 14) (40, 14)

# %% [markdown]
# # Construct Index as of Start Date

# %%
stock_data_filtered.shape
# Out:
# (54, 14)

# %%
# QC Market Cap cutoffs:
stock_data_filtered.to_csv('Initial_MCs.csv')

# %%
stock_index_top20
# Out:
#                                      shortName  \
# Ticker
# NTCO3.SA                GRUPO NATURAON      NM
# 0973.HK                             L'OCCITANE
# WRBY                         Warby Parker Inc.
# COUR                            Coursera, Inc.
# LMND                            Lemonade, Inc.
# BIRD                            Allbirds, Inc.
# GROV           Grove Collaborative Holdings, I
# SOMA3.SA                GRUPO SOMA  ON      NM
# ARZZ3.SA                AREZZO CO   ON      NM
# MME.AX                       MONEYME FPO [MME]
# CONCHATORO.SN               VINA CONCHA Y TORO
# FREY.PA                                   FREY
# AEF.AX                     A ETHICAL FPO [AEF]
# MOVI3.SA                MOVIDA      ON      NM
# LFG.AX                LIBERTY FG STAPLED [LFG]
# ABB.AX                    AUSSIEBAND FPO [ABB]
# 1112.HK                          H&H INTL HLDG
# VITL                         Vital Farms, Inc.
# COCO               The Vita Coco Company, Inc.
# 2897.TW                          O-BANK CO LTD
#
#                                                         longName  \
# Ticker
# NTCO3.SA                                 Natura &Co Holding S.A.
# 0973.HK                            L'Occitane International S.A.
# WRBY                                           Warby Parker Inc.
# COUR                                              Coursera, Inc.
# LMND                                              Lemonade, Inc.
# BIRD                                              Allbirds, Inc.
# GROV                          Grove Collaborative Holdings, Inc.
# SOMA3.SA                                 Grupo de Moda Soma S.A.
# ARZZ3.SA                        Arezzo Indústria e Comércio S.A.
# FREY.PA                   Real Estate                   https://www.frey.fr
# AEF.AX             Financial Services  https://www.australianethical.com.au
# MOVI3.SA                  Industrials              https://ri.movida.com.br
# LFG.AX             Financial Services            https://www.liberty.com.au
# ABB.AX         Communication Services    https://www.aussiebroadband.com.au
# 1112.HK            Consumer Defensive                 https://www.hh.global
# VITL               Consumer Defensive                https://vitalfarms.com
# COCO               Consumer Defensive        https://thevitacococompany.com
# 2897.TW            Financial Services                https://www.o-bank.com
#
#                beginningUSDExchangeRate   2022-01-04  beginningCloseUSD  \
# Ticker
# NTCO3.SA                       4.923979    22.226015           4.513832
# 0973.HK                        7.815320    31.003922           3.967070
# WRBY                           1.000000    44.080002          44.080002
# COUR                           1.000000    25.000000          25.000000
# LMND                           1.000000    39.029999          39.029999
# BIRD                           1.000000    15.590000          15.590000
# GROV                           1.000000    49.450001          49.450001
# SOMA3.SA                       4.923979    11.305203           2.295949
# ARZZ3.SA                       4.923979    66.436813          13.492505
# MME.AX                         1.478066     2.120000           1.434307
# CONCHATORO.SN                884.320491  1203.634399           1.361084
# FREY.PA                        0.913960    29.164482          31.910020
# AEF.AX                         1.478066    13.177149           8.915129
# MOVI3.SA                       4.923979    13.564058           2.754695
# LFG.AX                         1.478066     4.481904           3.032276
# ABB.AX                         1.478066     4.600000           3.112175
# 1112.HK                        7.815320    10.629018           1.360023
# VITL                           1.000000    18.180000          18.180000
# COCO                           1.000000    12.000000          12.000000
# 2897.TW                       30.894018     7.403813           0.239652
#
#               beginningMarketCapUSD
# Ticker
# NTCO3.SA          6245699374.638916
# 0973.HK           5840201377.746689
# WRBY              5208625256.362915
# COUR                   3933100000.0
# LMND               2753453383.00293
# BIRD              2419396408.959961
# GROV               1888104874.13063
# SOMA3.SA          1822416264.507435
# ARZZ3.SA          1516854444.533318
# MME.AX            1147557214.872906
# CONCHATORO.SN     1012725356.718075
# FREY.PA           1010389308.502045
# AEF.AX            1005466060.447263
# MOVI3.SA          1000929253.334753
# LFG.AX             921217474.062969
# ABB.AX             918667322.737256
# 1112.HK            877978078.233685
# VITL               759847656.755066
# COCO                    683151600.0
# 2897.TW            651007444.449265

# %% [markdown]
# ## Manual Adjustments (if needed)
# ### Adjust Methodology Here:

# %%
for df in df_list:
    if 'MLMFI.PA' in df.index:
        df.drop('MLMFI.PA', axis=0, inplace=True)
        
        
'''
    
    ## Eliminate if market cap < 100M:
    
    if '1346.HK' in df.index:
        df.drop('1346.HK', axis=0, inplace=True)
    if 'BIO.AX' in df.index:
        df.drop('BIO.AX', axis=0, inplace=True)
    if 'RETI.MI' in df.index:
        df.drop('RETI.MI', axis=0, inplace=True)
        
    ## Eliminate if price < $1.00:
   
    if '2897.TW' in df.index:
        df.drop('2897.TW', axis=0, inplace=True)
    if 'KMD.NZ' in df.index:
        df.drop('KMD.NZ', axis=0, inplace=True)
    if 'VHT.AX' in df.index:
        df.drop('VHT.AX', axis=0, inplace=True)    
'''
# Out:
# "\n    \n    ## Eliminate if market cap < 100M:\n    \n    if '1346.HK' in df.index:\n        df.drop('1346.HK', axis=0, inplace=True)\n    if 'BIO.AX' in df.index:\n        df.drop('BIO.AX', axis=0, inplace=True)\n    if 'RETI.MI' in df.index:\n        df.drop('RETI.MI', axis=0, inplace=True)\n        \n    ## Eliminate if price < $1.00:\n   \n    if '2897.TW' in df.index:\n        df.drop('2897.TW', axis=0, inplace=True)\n    if 'KMD.NZ' in df.index:\n        df.drop('KMD.NZ', axis=0, inplace=True)\n    if 'VHT.AX' in df.index:\n        df.drop('VHT.AX', axis=0, inplace=True)    \n"

# %%
assert stock_index_top20.shape[0] == 20
assert stock_index_top30.shape[0] == 30

# %% [markdown]
# # DECISION:
# # Set Index and Get Price History

# %%
stock_index = stock_index_top20.copy()
start_date = s
end_date = '2022-12-31'

# %%
def get_price_history (df, start = start_date, end=end_date):
    tickers_list = df.index.tolist()
    tickers_data= {}
    first_object = yf.Ticker(tickers_list[0])
    
    prices = pd.DataFrame.from_dict(first_object.history(start=start, end=end, interval = "1d"))
    prices.drop(['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'], axis=1, inplace=True)
    prices.columns = [tickers_list[0]]

    
    for ticker in tickers_list[1:]:
        ticker_object = yf.Ticker(ticker)
        try:
            temp = pd.DataFrame.from_dict(ticker_object.history(start=start, end=end, interval = "1d"))
            temp.drop(['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'], axis=1, inplace=True)
            temp.columns = [ticker]
            prices = prices.merge(temp, how="outer", left_index=True, right_index=True)
        except:
            continue
    
    
    # Collapse date across international zones:
    prices.index = pd.to_datetime(prices.index).date
      
    prices = prices.groupby(prices.index).ffill() 
    prices = prices.groupby(prices.index).bfill()
    prices = prices.groupby(prices.index).last()
    
    
    return prices

# %%
price_history_df = get_price_history (stock_index)

stock_universe = list(price_history_df.columns)
print ("Number of stocks", len(stock_universe))
# Out:
# Number of stocks 20

# %%
display(price_history_df.head())
# Out:
#              NTCO3.SA    0973.HK       WRBY       COUR       LMND   BIRD  \
# 2022-01-03        NaN  31.100807        NaN        NaN        NaN    NaN
# 2022-01-04  22.226017  31.003922  44.080002  25.000000  39.029999  15.59
# 2022-01-05  21.198648  30.907034  41.660000  24.010000  36.790001  13.57
# 2022-01-06  20.960150  31.439913  42.389999  23.410000  35.330002  15.23
# 2022-01-07  20.281355        NaN  39.709999  23.219999  37.139999  13.94
#
#                  GROV   SOMA3.SA   ARZZ3.SA  MME.AX  CONCHATORO.SN    FREY.PA  \
# 2022-01-03        NaN        NaN        NaN    2.12            NaN  29.694746
# 2022-01-04  49.450001  11.305203  66.436813    2.12    1203.634277  29.164482
# 2022-01-05  49.700001  10.226650  63.242928    2.10    1234.558594  29.164482
# 2022-01-06  49.599998  10.540411  64.399170    2.07    1249.928223  29.164482
# 2022-01-07  49.700001  10.295285  63.887394     NaN    1240.669189        NaN
#
#                AEF.AX   MOVI3.SA    LFG.AX  ABB.AX    1112.HK       VITL  \
# 2022-01-03  13.060878        NaN  4.465664    4.74  10.558157        NaN
# 2022-01-04  13.177148  13.564058  4.481903    4.60  10.629018  18.180000
# 2022-01-05  12.382644  12.642316  4.465664    4.21  11.107324  17.570000
# 2022-01-06  12.266375  12.597133  4.465664    4.46  10.877028  18.290001
# 2022-01-07        NaN  12.353143       NaN     NaN        NaN  18.510000
#
#              COCO   2897.TW
# 2022-01-03    NaN  7.403813
# 2022-01-04  12.00  7.403813
# 2022-01-05  11.49  7.431647
# 2022-01-06  10.96  7.440926
# 2022-01-07  10.91       NaN

# %%
def get_country_info(price_df, info_df):
    tickers_list = price_df.columns
    
    #access currency, impliedSharesOutstanding (local currency): ## HAVE TO REVIEW FOR STOCK CHANGES
    currencies = []
    implied_SO = []
    for col in price_df.columns:
        idx = np.where(info_df.index == col)
        currencies.append(info_df.iloc[idx]['currency'].values[0])
        implied_SO.append(info_df.iloc[idx]['impliedSharesOutstanding'].values[0])
        
    for i in range(len(price_df.columns)):
        col = price_df.columns[i]
        price_df[col+'_currency'] = currencies[i]
        price_df[col+'_SO'] = implied_SO[i]
    
    return price_df, currencies

# %%
price_and_info_df, index_currencies = get_country_info(price_history_df, stock_index)

# %% [markdown]
# ### Get historical exchange rates

# %%
def get_historical_exchange (price_df, currencies):
    #currencies = list(set(currencies))
    
    querystring = {"base":"USD"}

    #headers = {"X-RapidAPI-Key": "af4b092441msh3f4304a0bce0366p1680a3jsn93d4c3a0659f",
    headers = {"X-RapidAPI-Key": "884638c782msh3dc9c5784730cc0p1a0f42jsnf54c2327e84c",
        "X-RapidAPI-Host": "currency-conversion-and-exchange-rates.p.rapidapi.com"
              }
    daily_rate_df = pd.DataFrame()
    
    for idx in price_df.index:
        loc = np.where(price_df.index == idx)
        url = "https://currency-conversion-and-exchange-rates.p.rapidapi.com/" + str(idx)
        response = requests.get(url, headers=headers, params=querystring)
        response = response.json()
        
        daily_df = pd.DataFrame(response)
        daily_df = daily_df[['date', 'rates']].reset_index()
        daily_df = daily_df.pivot(columns='index', index='date', values='rates')

        daily_rate_df = pd.concat([daily_rate_df, daily_df], axis=0)

        
    daily_rate_df.index = pd.to_datetime(daily_rate_df.index).date
    return daily_rate_df

# %% [markdown]
# # Decision:
# ### Run API to get all of the exchange rates? Or upload stored data?

# %%
display(price_and_info_df.head())
display(price_and_info_df.tail())
# Out:
#              NTCO3.SA    0973.HK       WRBY       COUR       LMND   BIRD  \
# 2022-01-03        NaN  31.100807        NaN        NaN        NaN    NaN
# 2022-01-04  22.226017  31.003922  44.080002  25.000000  39.029999  15.59
# 2022-01-05  21.198648  30.907034  41.660000  24.010000  36.790001  13.57
# 2022-01-06  20.960150  31.439913  42.389999  23.410000  35.330002  15.23
# 2022-01-07  20.281355        NaN  39.709999  23.219999  37.139999  13.94
#
#                  GROV   SOMA3.SA   ARZZ3.SA  MME.AX  ...  ABB.AX_currency  \
# 2022-01-03        NaN        NaN        NaN    2.12  ...              AUD
# 2022-01-04  49.450001  11.305203  66.436813    2.12  ...              AUD
# 2022-01-05  49.700001  10.226650  63.242928    2.10  ...              AUD
# 2022-01-06  49.599998  10.540411  64.399170    2.07  ...              AUD
# 2022-01-07  49.700001  10.295285  63.887394     NaN  ...              AUD
#
#             ABB.AX_SO  1112.HK_currency  1112.HK_SO  VITL_currency   VITL_SO  \
# 2022-01-03  295184992               HKD   645561024            USD  41795800
# 2022-01-04  295184992               HKD   645561024            USD  41795800
# 2022-01-05  295184992               HKD   645561024            USD  41795800
# 2022-01-06  295184992               HKD   645561024            USD  41795800
# 2022-01-07  295184992               HKD   645561024            USD  41795800
#
#             COCO_currency   COCO_SO  2897.TW_currency  2897.TW_SO
# 2022-01-03            USD  56929300               TWD  2716470016
# 2022-01-04            USD  56929300               TWD  2716470016
# 2022-01-05            USD  56929300               TWD  2716470016
# 2022-01-06            USD  56929300               TWD  2716470016
# 2022-01-07            USD  56929300               TWD  2716470016
#
# [5 rows x 60 columns]
#              NTCO3.SA    0973.HK   WRBY   COUR   LMND   BIRD   GROV  \
# 2022-12-26  10.374391        NaN    NaN    NaN    NaN    NaN    NaN
# 2022-12-27   9.857518  23.837166  12.99  11.39  13.41  2.270  1.385
# 2022-12-28  10.568219  23.837166  13.01  11.22  12.91  2.245  1.385
# 2022-12-29  10.715898  24.084440  13.75  11.76  13.84  2.370  1.490
# 2022-12-30        NaN        NaN  13.49  11.83  13.68  2.420  1.995
#
#              SOMA3.SA   ARZZ3.SA  MME.AX  ...  ABB.AX_currency  ABB.AX_SO  \
# 2022-12-26  10.076818  76.290283     NaN  ...              AUD  295184992
# 2022-12-27   9.661891  74.357780   0.255  ...              AUD  295184992
# 2022-12-28  10.106457  76.406822   0.245  ...              AUD  295184992
# 2022-12-29  10.017544  75.989243   0.245  ...              AUD  295184992
# 2022-12-30        NaN        NaN     NaN  ...              AUD  295184992
#
#             1112.HK_currency  1112.HK_SO  VITL_currency   VITL_SO  \
# 2022-12-26               HKD   645561024            USD  41795800
# 2022-12-27               HKD   645561024            USD  41795800
# 2022-12-28               HKD   645561024            USD  41795800
# 2022-12-29               HKD   645561024            USD  41795800
# 2022-12-30               HKD   645561024            USD  41795800
#
#             COCO_currency   COCO_SO  2897.TW_currency  2897.TW_SO
# 2022-12-26            USD  56929300               TWD  2716470016
# 2022-12-27            USD  56929300               TWD  2716470016
# 2022-12-28            USD  56929300               TWD  2716470016
# 2022-12-29            USD  56929300               TWD  2716470016
# 2022-12-30            USD  56929300               TWD  2716470016
#
# [5 rows x 60 columns]

# %%
run_api = False

# %%
# Load stored rates:
def load_rates(filename = "daily_rates_df_2022_2024_4_19.csv"):
    daily_rates_df = pd.read_csv(filename)
    daily_rates_df.set_index("Date", inplace=True)
    daily_rates_df.index = pd.to_datetime(daily_rates_df.index).date
    
    last_date = daily_rates_df.index[-1]
    return daily_rates_df, last_date

# %%
df_dates, ed = load_rates()

currency_start = ed+timedelta(days=1)
currency_end = e
# Out:
# /var/folders/p5/k8h2_yjj0nncvy0f82hy1xvc0000gn/T/ipykernel_20022/2230597786.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   daily_rates_df.index = pd.to_datetime(daily_rates_df.index).date

# %%
import warnings
warnings.filterwarnings("ignore")

ext = str(dt.today().year) + "_" + str(dt.today().month) + "_" + str(dt.today().day)+ "_" + str(dt.today().hour)
filename = "daily_rates_df" + ext + ".csv"

if run_api:
    # adjust dates to only get currency data after stored file
    hist_currency_df = price_and_info_df.copy()
    hist_currency_df = hist_currency_df.loc[currency_start:,:]
    
    daily_rates_df = get_historical_exchange(hist_currency_df, index_currencies)
    display(daily_rates_df.head())
    display(daily_rates_df.tail())
    daily_rates_df.to_csv(filename)

else:
    daily_rates_df = df_dates.copy()

# %%
daily_rates_df.head()
# Out:
#                  AED         AFN         ALL         AMD       ANG  \
# 2022-01-02  3.672980  103.749983  106.650326  480.234325  1.802591
# 2022-01-03  3.673103  103.750299  106.249880  481.590005  1.802973
# 2022-01-04  3.673096  104.899369  105.874950  482.301630  1.801500
# 2022-01-05  3.673102  105.250158  106.902530  483.164239  1.802797
# 2022-01-06  3.673102  104.999962  107.350118  483.038449  1.802366
#
#                    AOA         ARS       AUD     AWG       AZN  ...       XAU  \
# 2022-01-02  550.590435  102.664691  1.376179  1.8000  1.698647  ...  0.000547
# 2022-01-03  554.203977  102.958502  1.389502  1.8005  1.701522  ...  0.000554
# 2022-01-04  553.427992  103.104100  1.381105  1.8000  1.698131  ...  0.000551
# 2022-01-05  552.652983  103.102801  1.384754  1.8005  1.691373  ...  0.000552
# 2022-01-06  551.700853  103.228600  1.395982  1.8000  1.700773  ...  0.000558
#
#                 XCD       XDR         XOF         XPF         YER        ZAR  \
# 2022-01-02  2.70255  0.714652  579.499504  105.850128  250.249584  15.964896
# 2022-01-03  2.70255  0.714795  578.495079  106.250557  250.250269  15.874497
# 2022-01-04  2.70255  0.713539  580.492727  106.125034  250.249886  16.037760
# 2022-01-05  2.70255  0.716268  579.501261  105.550109  250.249682  15.893898
# 2022-01-06  2.70255  0.714658  580.493234  105.879870  249.999702  15.721510
#
#                     ZMK        ZMW         ZWL
# 2022-01-02  9001.202654  16.663427  321.999592
# 2022-01-03  9001.202677  16.674184  321.999592
# 2022-01-04  9001.200930  16.718437  321.999592
# 2022-01-05  9001.187415  16.770433  321.999592
# 2022-01-06  9001.191881  16.776058  321.999592
#
# [5 rows x 167 columns]

# %%
daily_rates_df.tail()
# Out:
#                  AED        AFN        ALL         AMD       ANG         AOA  \
# 2024-04-15  3.672500  71.999838  95.201353  395.760311  1.801369  832.824047
# 2024-04-16  3.672502  72.212319  95.150069  395.239784  1.801387  837.497174
# 2024-04-17  3.672499  71.631438  95.179988  395.097576  1.797381  837.490979
# 2024-04-18  3.672725  72.000107  95.110057  394.069736  1.801845  837.503789
# 2024-04-19  3.672604  72.000368  94.920403  392.603986  1.802376  837.000367
#
#                    ARS       AUD     AWG       AZN  ...       XAU      XCD  \
# 2024-04-15  868.249953  1.552277  1.8025  1.699549  ...  0.000420  2.70255
# 2024-04-16  868.770498  1.559385  1.8000  1.699877  ...  0.000420  2.70255
# 2024-04-17  869.255103  1.552925  1.8000  1.691994  ...  0.000422  2.70255
# 2022-12-29  10.715898  24.084440  13.75  11.76  13.84  2.370  1.490
# 2022-12-30        NaN        NaN  13.49  11.83  13.68  2.420  1.995
#
#              SOMA3.SA   ARZZ3.SA  MME.AX  ...       XAU      XCD       XDR  \
# 2022-12-26  10.076818  76.290283     NaN  ...  0.000555  2.70255  0.750694
# 2022-12-27   9.661891  74.357780   0.255  ...  0.000552  2.70255  0.751705
# 2022-12-28  10.106457  76.406822   0.245  ...  0.000554  2.70255  0.751910
# 2022-12-29  10.017544  75.989243   0.245  ...  0.000551  2.70255  0.751425
# 2022-12-30        NaN        NaN     NaN  ...  0.000548  2.70255  0.751548
#
#                    XOF         XPF         YER        ZAR          ZMK  \
# 2022-12-26  617.501917  112.649647  250.349884  17.035520  9001.195377
# 2022-12-27  615.510014  112.650044  250.350158  17.208498  9001.202829
# 2022-12-28  615.000030  112.650533  250.350128  17.105199  9001.182860
# 2022-12-29  616.999993  112.300971  250.249575  16.936410  9001.186468
# 2022-12-30  615.503597  111.950364  250.303593  17.023015  9001.203589
#
#                   ZMW         ZWL
# 2022-12-26  17.900278  321.999592
# 2022-12-27  17.971823  321.999592
# 2022-12-28  17.997538  321.999592
# 2022-12-29  18.079183  321.999592
# 2022-12-30  18.111180  321.999592
#
# [5 rows x 227 columns]

# %%
def convert_price_mktcap_USD (px_info_df, stock_list):
    
    for stock in stock_list:
        col_name = stock+"_currency"
        col2_name = stock+"_SO"
        curr = px_info_df[col_name][0]
        shares_out = px_info_df[col2_name][0]
        new_col = stock + "_px_USD"
        new_col2 = stock + "_MktCap_USD"
        px_info_df[new_col] = px_info_df[stock] / px_info_df[curr]
        px_info_df[new_col2] = px_info_df[new_col] * shares_out
    
    return px_info_df

# %%
daily_price_MC_usd_all = convert_price_mktcap_USD(daily_price_and_info_df, stock_universe)

# %%
#if download:
#    daily_price_MC_usd_all.to_csv('price_MC_USD.csv')
display(daily_price_MC_usd_all.head())
display(daily_price_MC_usd_all.tail())
# Out:
#              NTCO3.SA    0973.HK       WRBY       COUR       LMND   BIRD  \
# 2022-01-03        NaN  31.100807        NaN        NaN        NaN    NaN
# 2022-01-04  22.226017  31.003922  44.080002  25.000000  39.029999  15.59
# 2022-01-05  21.198648  30.907034  41.660000  24.010000  36.790001  13.57
# 2022-01-06  20.960150  31.439913  42.389999  23.410000  35.330002  15.23
# 2022-01-07  20.281355        NaN  39.709999  23.219999  37.139999  13.94
#
#                  GROV   SOMA3.SA   ARZZ3.SA  MME.AX  ...  ABB.AX_px_USD  \
# 2022-01-03        NaN        NaN        NaN    2.12  ...       3.411294
# 2022-01-04  49.450001  11.305203  66.436813    2.12  ...       3.330666
# 2022-01-05  49.700001  10.226650  63.242928    2.10  ...       3.040251
# 2022-01-06  49.599998  10.540411  64.399170    2.07  ...       3.194884
# 2022-01-07  49.700001  10.295285  63.887394     NaN  ...            NaN
#
#             ABB.AX_MktCap_USD  1112.HK_px_USD  1112.HK_MktCap_USD  \
# 2022-01-03       1.006963e+09        1.353983        8.740787e+08
    cols_to_keep.remove('USD')
    df_USD = df_all[cols_to_keep]
    
    px = []
    MC = []
    
    for col in cols_to_keep:
        if "_px" in col:
            px.append(col)
        if "_MktCap" in col:
            MC.append(col)

    df_USD_px = df_USD[px]
    df_MC_px = df_USD[MC]
    
    return df_USD, df_USD_px, df_MC_px

# %%
daily_info_usd, daily_px_USD, daily_MC_USD = get_df_in_USD(daily_price_MC_usd_all)

#QC:
#daily_px_USD.to_csv('daily_px_test.csv')

# %%
daily_px_USD.head()
#QC:
#daily_px_USD.to_csv('daily_px_test.csv')
# Out:
#             NTCO3.SA_px_USD  0973.HK_px_USD  WRBY_px_USD  COUR_px_USD  \
# 2022-01-03              NaN        3.988382          NaN          NaN
# 2022-01-04         3.914689        3.977998    44.080002    25.000000
# 2022-01-05         3.713087        3.964855    41.660000    24.010000
# 2022-01-06         3.687638        4.030334    42.389999    23.410000
# 2022-01-07         3.598662             NaN    39.709999    23.219999
#
#             LMND_px_USD  BIRD_px_USD  GROV_px_USD  SOMA3.SA_px_USD  \
# 2022-01-03          NaN          NaN          NaN              NaN
# 2022-01-04    39.029999        15.59    49.450001         1.991196
# 2022-01-05    36.790001        13.57    49.700001         1.791267
# 2022-01-06    35.330002        15.23    49.599998         1.854434
# 2022-01-07    37.139999        13.94    49.700001         1.826764
#
#             ARZZ3.SA_px_USD  MME.AX_px_USD  CONCHATORO.SN_px_USD  \
# 2022-01-03              NaN       1.525726                   NaN
# 2022-01-04        11.701577       1.535003              1.420335
# 2022-01-05        11.077427       1.516515              1.472307
# 2022-01-06        11.330111       1.482827              1.492238
# 2022-01-07        11.335986            NaN              1.497831
#
#             FREY.PA_px_USD  AEF.AX_px_USD  MOVI3.SA_px_USD  LFG.AX_px_USD  \
# 2022-01-03       33.554523       9.399683              NaN       3.213859
# 2022-01-04       32.907552       9.541018         2.389050       3.245157
# 2022-01-05       32.995116       8.942125         2.214387       3.224879
# 2022-01-06       32.946883       8.786915         2.216285       3.198941
# 2022-01-07             NaN            NaN         2.191904            NaN
#
#             ABB.AX_px_USD  1112.HK_px_USD  VITL_px_USD  COCO_px_USD  \
# 2022-01-03       3.411294        1.353983          NaN          NaN
# 2022-01-04       3.330666        1.363770    18.180000        12.00
# 2022-01-05       3.040251        1.424884    17.570000        11.49
# 2022-01-06       3.194884        1.394344    18.290001        10.96
# 2022-01-07            NaN             NaN    18.510000        10.91
#
#             2897.TW_px_USD
# 2022-01-03        0.268322
# 2022-01-04        0.268931
# 2022-01-05        0.269151
# 2022-01-06        0.269355
# 2022-01-07             NaN

# %%
def calc_px_weighted_index(df, divisor = 0, show_chart = True):
    # Fill in missing days:
    pw_index = df.ffill()
    
    n, m = pw_index.shape
    if divisor == 0:
        divisor = m
    pw_index['Index'] = (pw_index.iloc[:,0:m].sum(axis=1)) / divisor

    # Remove NaN rows:
    #QC:
    #pw_index.to_csv('PW_index_test.csv')
    pw_index.dropna(inplace=True)
    #pw_index.sort_index(axis=0, level=0, inplace=True)
    
    if show_chart:
        
        fig, ax = plt.subplots(figsize = (12,6))
        ax.plot(pw_index['Index'], color = 'seagreen', linewidth=2)
        plt.title('Price Weighted Index | '+ str(m) + ' stocks')
        plt.annotate("Stocks in Index:", (0,0), (0, -20), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.annotate(stock_universe[0:int(m/2)], (0,0), (0, -30), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.annotate(stock_universe[int(m/2):], (0,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.show()
        
    return pw_index

def calc_MC_weighted_index(df, divisor = 1000000000, show_chart = True):
    # Fill in missing days:
    mcw_index = df.ffill()
    n, m = mcw_index.shape
    mcw_index['Index'] = (mcw_index.iloc[:,0:m].sum(axis=1)) / divisor
    
    # Remove NaN rows:
    mcw_index.dropna(inplace=True)
    
    if show_chart:
        
        fig, ax = plt.subplots(figsize = (12,6))
        ax.plot(mcw_index['Index'], color = 'royalblue', linewidth=2)
        plt.title('MktCap Weighted Index | '+ str(m) + ' stocks')
        plt.annotate("Stocks in Index:", (0,0), (0, -20), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.annotate(stock_universe[0:int(m/2)], (0,0), (0, -30), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.annotate(stock_universe[int(m/2):], (0,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.show()    
        
    return mcw_index

# %%
price_wgt_index = calc_px_weighted_index(daily_px_USD, divisor = 1, show_chart=True)
mktcap_wgt_index = calc_MC_weighted_index (daily_MC_USD, divisor = 1000000000, show_chart=True)

display(price_wgt_index.head())
display(mktcap_wgt_index.head())
# Out:
#             NTCO3.SA_px_USD  0973.HK_px_USD  WRBY_px_USD  COUR_px_USD  \
# 2022-01-04         3.914689        3.977998    44.080002    25.000000
# 2022-01-05         3.713087        3.964855    41.660000    24.010000
# 2022-01-06         3.687638        4.030334    42.389999    23.410000
# 2022-01-07         3.598662        4.030334    39.709999    23.219999
# 2022-01-09         3.598662        4.168364    39.709999    23.219999
#
#             LMND_px_USD  BIRD_px_USD  GROV_px_USD  SOMA3.SA_px_USD  \
# 2022-01-04    39.029999        15.59    49.450001         1.991196
# 2022-01-05    36.790001        13.57    49.700001         1.791267
# 2022-01-06    35.330002        15.23    49.599998         1.854434
# 2022-01-07    37.139999        13.94    49.700001         1.826764
# 2022-01-09    37.139999        13.94    49.700001         1.826764
#
#             ARZZ3.SA_px_USD  MME.AX_px_USD  ...  FREY.PA_px_USD  \
# 2022-01-04        11.701577       1.535003  ...       32.907552
# 2022-01-05        11.077427       1.516515  ...       32.995116
# 2022-01-06        11.330111       1.482827  ...       32.946883
# 2022-01-07        11.335986       1.482827  ...       32.946883
# 2022-01-09        11.335986       1.457235  ...       32.910492
#
#             AEF.AX_px_USD  MOVI3.SA_px_USD  LFG.AX_px_USD  ABB.AX_px_USD  \
#             1112.HK_MktCap_USD  VITL_MktCap_USD  COCO_MktCap_USD  \
# 2022-01-04        8.803967e+08     7.598477e+08     6.831516e+08
# 2022-01-05        9.198493e+08     7.343522e+08     6.541176e+08
# 2022-01-06        9.001342e+08     7.644452e+08     6.239451e+08
# 2022-01-07        9.001342e+08     7.736403e+08     6.210987e+08
# 2022-01-09        9.165699e+08     7.736403e+08     6.210987e+08
#
#             2897.TW_MktCap_USD      Index
# 2022-01-04        7.305438e+08  40.665707
# 2022-01-05        7.311417e+08  39.024153
# 2022-01-06        7.316935e+08  39.294600
# 2022-01-07        7.316935e+08  38.736581
# 2022-01-09        7.345980e+08  38.923363
#
# [5 rows x 21 columns]

# %%
if download:
    price_wgt_index.to_csv("PriceWgt_Index.csv")
    mktcap_wgt_index.to_csv("MarketCap_of_Index.csv")

# %%
def combine_norm_and_benchmark(px_df, mc_df):
    
    combined_df = pd.concat([px_df['Index'],mc_df['Index']], axis=1)
    combined_df.columns = ['Price Weighted Index', "Mkt Cap Weighted Index"]
    
    # Add S&P
    spx_object = yf.Ticker("^GSPC")
    spx = pd.DataFrame.from_dict(spx_object.history(start=s, end=e, interval = "1d"))
    spx = spx[['Close']]
    spx.columns = ['SPX']
    spx.index = pd.to_datetime(spx.index).date
    
    # Add Russell 2000
    ru2000_object = yf.Ticker("^RUT")
    ru2000 = pd.DataFrame.from_dict(ru2000_object.history(start=s, end=e, interval = "1d"))
    ru2000 = ru2000[['Close']]
    ru2000.columns = ['RU2000']
    ru2000.index = pd.to_datetime(ru2000.index).date
    
    # Add DJ Sustainability
    #DJsus_object = pd.read_csv("DJSus_history.csv")
    #display(DJsus_object.head())
    #DJsus_object.index = pd.to_datetime(DJsus_object['Date'])
    #DJsus_object.drop(['Date'], axis=1, inplace=True)
    #DJsus_object.index = pd.to_datetime(DJsus_object.index).date
    #DJ_Sus = DJsus_object.copy()

    combined_df = pd.concat([combined_df, spx, ru2000], axis=1)
    
    combined_df = combined_df.ffill()
    display(combined_df.head())

    combined_df = combined_df.div(combined_df.iloc[0])
    return combined_df

# %%
## Contain SPX, RU2000, DJ Sus separately for graphing

spx_object = yf.Ticker("^GSPC")
spx = pd.DataFrame.from_dict(spx_object.history(start=s, end=e, interval = "1d"))
spx = spx[['Close']]
spx.columns = ['SPX']
spx.index = pd.to_datetime(spx.index).date


ru2000_object = yf.Ticker("^RUT")
ru2000 = pd.DataFrame.from_dict(ru2000_object.history(start=s, end=e, interval = "1d"))
ru2000 = ru2000[['Close']]
ru2000.columns = ['RU2000']
ru2000.index = pd.to_datetime(ru2000.index).date

'''
DJsus_object = pd.read_csv("DJSus_history.csv")
#display(DJsus_object.head())
DJsus_object.index = pd.to_datetime(DJsus_object['Date'])
DJsus_object.drop(['Date'], axis=1, inplace=True)
DJsus_object.index = pd.to_datetime(DJsus_object.index).date
#display(DJsus_object.head())
'''
# Out:
# '\nDJsus_object = pd.read_csv("DJSus_history.csv")\n#display(DJsus_object.head())\nDJsus_object.index = pd.to_datetime(DJsus_object[\'Date\'])\nDJsus_object.drop([\'Date\'], axis=1, inplace=True)\nDJsus_object.index = pd.to_datetime(DJsus_object.index).date\n#display(DJsus_object.head())\n'

# %%
index_comparison_df = combine_norm_and_benchmark(price_wgt_index, mktcap_wgt_index)
# Out:
#             Price Weighted Index  Mkt Cap Weighted Index          SPX  \
# 2022-01-04            280.916943               40.665707  4793.540039
# 2022-01-05            270.436253               39.024153  4700.580078
# 2022-01-06            271.095188               39.294600  4696.049805
# 2022-01-07            268.885628               38.736581  4677.029785
# 2022-01-09            268.826069               38.923363  4677.029785
#
#                  RU2000
# 2022-01-04  2268.870117
# 2022-01-05  2194.000000
# 2022-01-06  2206.370117
# 2022-01-07  2179.810059
# 2022-01-09  2179.810059

# %%
index_comparison_df.head(5)
# Out:
#             Price Weighted Index  Mkt Cap Weighted Index       SPX    RU2000
# 2022-01-04              1.000000                1.000000  1.000000  1.000000
# 2022-01-05              0.962691                0.959633  0.980607  0.967001
# 2022-01-06              0.965037                0.966283  0.979662  0.972453
# 2022-01-07              0.957171                0.952561  0.975694  0.960747
# 2022-01-09              0.956959                0.957154  0.975694  0.960747

# %%
index_comparison_df.sort_index(inplace=True)

# %% [markdown]
# ## Preview and adjust dates if needed

# %%
display(index_comparison_df.head(5))
# Out:
#             Price Weighted Index  Mkt Cap Weighted Index       SPX    RU2000
# 2022-01-04              1.000000                1.000000  1.000000  1.000000
# 2022-01-05              0.962691                0.959633  0.980607  0.967001
# 2022-01-06              0.965037                0.966283  0.979662  0.972453
# 2022-01-07              0.957171                0.952561  0.975694  0.960747
# 2022-01-09              0.956959                0.957154  0.975694  0.960747

# %%
adjust = 0

# %%
if adjust > 0:
    index_comparison_df = index_comparison_df.iloc[adjust:,:]
display(index_comparison_df.head(5))

if download:
    index_comparison_df.to_csv("Index_Comparison.csv")
# Out:
#             Price Weighted Index  Mkt Cap Weighted Index       SPX    RU2000
# 2022-01-04              1.000000                1.000000  1.000000  1.000000
# 2022-01-05              0.962691                0.959633  0.980607  0.967001
# 2022-01-06              0.965037                0.966283  0.979662  0.972453
# 2022-01-07              0.957171                0.952561  0.975694  0.960747
# 2022-01-09              0.956959                0.957154  0.975694  0.960747

# %% [markdown]
# ### Graph Indices

# %%
## Graph Separately
fig, (ax0, ax1, ax2) = plt.subplots(3, 1, figsize = (20,18))
ax0.plot(price_wgt_index['Index'], color = 'seagreen', linewidth=2, label = 'Price Weighted')
ax0.legend(loc=2)
ax1.plot(mktcap_wgt_index['Index'], color = 'royalblue', linewidth=2,label='Market Cap Weighted')
ax1.legend(loc=2)
ax2.plot(spx, color='darkorange', linewidth=2, label = 'SPX')
ax2.legend(loc=2)
plt.show()

# %%
## Graph Together
#fig, ax = plt.subplots(figsize = (12,6))
index_comparison_df.plot(figsize = (12,6),
                         color = ['seagreen', 'royalblue', 'darkorange', 'firebrick', 'goldenrod'])

plt.show()

# %%
# Export Index:
#index_comparison_df.to_csv("Index_Comparison.csv")

# %% [markdown]
# ### Visualize Characteristics

# %%
classify_all = stock_data_filtered.copy()
classify_index = stock_index.copy()
print(classify_all.shape, classify_index.shape)
# Out:
# (54, 14) (20, 14)

# %%
classify_index['country'].value_counts()
# Out:
# country
# United States    7
# Brazil           4
# Australia        4
# Luxembourg       1
# Chile            1
# France           1
# Hong Kong        1
# Taiwan           1
# Name: count, dtype: int64

# %%
classify_index
# Out:
#                                      shortName  \
# Ticker
# NTCO3.SA                GRUPO NATURAON      NM
# 0973.HK                             L'OCCITANE
# WRBY                         Warby Parker Inc.
# COUR                            Coursera, Inc.
# LMND                            Lemonade, Inc.
# BIRD                            Allbirds, Inc.
# GROV           Grove Collaborative Holdings, I
# SOMA3.SA                GRUPO SOMA  ON      NM
# ARZZ3.SA                AREZZO CO   ON      NM
# MME.AX                       MONEYME FPO [MME]
# CONCHATORO.SN               VINA CONCHA Y TORO
# FREY.PA                                   FREY
# AEF.AX                     A ETHICAL FPO [AEF]
# MOVI3.SA                MOVIDA      ON      NM
# LFG.AX                LIBERTY FG STAPLED [LFG]
# ABB.AX                    AUSSIEBAND FPO [ABB]
# 1112.HK                          H&H INTL HLDG
# VITL                         Vital Farms, Inc.
# COCO               The Vita Coco Company, Inc.
# 2897.TW                          O-BANK CO LTD
#
#                                                         longName  \
# Ticker
# NTCO3.SA                                 Natura &Co Holding S.A.
# 0973.HK                            L'Occitane International S.A.
# WRBY                                           Warby Parker Inc.
# COUR                                              Coursera, Inc.
# LMND                                              Lemonade, Inc.
# BIRD                                              Allbirds, Inc.
# GROV                          Grove Collaborative Holdings, Inc.
# SOMA3.SA                                 Grupo de Moda Soma S.A.
# ARZZ3.SA                        Arezzo Indústria e Comércio S.A.
# MME.AX                                           MoneyMe Limited
# CONCHATORO.SN                            Viña Concha y Toro S.A.
# FREY.PA                                                  Frey SA
# AEF.AX                     Australian Ethical Investment Limited
# MOVI3.SA                               Movida Participações S.A.
# LFG.AX                           Liberty Financial Group Limited
# ABB.AX                                  Aussie Broadband Limited
# 1112.HK        Health and Happiness (H&H) International Holdi...
# VITL                                           Vital Farms, Inc.
# COCO                                 The Vita Coco Company, Inc.
# 2897.TW                                         O-Bank Co., Ltd.
#
#                      country currency previousClose impliedSharesOutstanding  \
# Ticker
# NTCO3.SA              Brazil      BRL         16.88               1383680000
# 0973.HK           Luxembourg      HKD          30.6               1472169984
# WRBY           United States      USD         12.92                118163000
# COUR           United States      USD         11.97                157324000
# LMND           United States      USD         17.95                 70547104
# BIRD           United States      USD        0.6126                155188992
# GROV           United States      USD          1.57                 38182100
# SOMA3.SA              Brazil      BRL          6.11                793753024
# ARZZ3.SA              Brazil      BRL         52.03                112422000
# MME.AX             Australia      AUD          0.07                800078016
# CONCHATORO.SN          Chile      CLP        1241.2                744057984
# FREY.PA               France      EUR          28.0                 31663700
# AEF.AX             Australia      AUD          4.89                112782000
# MOVI3.SA              Brazil      BRL          7.32                363353984
# LFG.AX             Australia      AUD          3.97                303804000
# ABB.AX             Australia      AUD          3.61                295184992
# 1112.HK            Hong Kong      HKD         10.22                645561024
# 1112.HK                        7.815320    10.629018           1.360023
# VITL                           1.000000    18.180000          18.180000
# COCO                           1.000000    12.000000          12.000000
# 2897.TW                       30.894018     7.403813           0.239652
#
#               beginningMarketCapUSD
# Ticker
# NTCO3.SA          6245699374.638916
# 0973.HK           5840201377.746689
# WRBY              5208625256.362915
# COUR                   3933100000.0
# LMND               2753453383.00293
# BIRD              2419396408.959961
# GROV               1888104874.13063
# SOMA3.SA          1822416264.507435
# ARZZ3.SA          1516854444.533318
# MME.AX            1147557214.872906
# CONCHATORO.SN     1012725356.718075
# FREY.PA           1010389308.502045
# AEF.AX            1005466060.447263
# MOVI3.SA          1000929253.334753
# LFG.AX             921217474.062969
# ABB.AX             918667322.737256
# 1112.HK            877978078.233685
# VITL               759847656.755066
# COCO                    683151600.0
# 2897.TW            651007444.449265

# %%
def visualize_groups (df_all, df_some):
    # by sector:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_all['sector'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("steelblue", n_slices, reverse=True)
    
    ax.pie(df_all['sector'].value_counts(), labels=df_all['sector'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Sectors in Public B-Corp Universe')
    plt.show()
    

    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_some['sector'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("steelblue", n_slices, reverse=True)
    
    ax.pie(df_some['sector'].value_counts(), labels=df_some['sector'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Sectors in Top 20 Index')
    plt.show()  
    

    # by industry:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_all['industry'].value_counts().index))
    cmap = sns.light_palette("maroon", n_slices, reverse=True)
    
    ax.pie(df_all['industry'].value_counts(), labels=df_all['industry'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'xx-small'}, colors = cmap)
    plt.title('Industries in Public B-Corp Universe')
    plt.show()
    


    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_some['industry'].value_counts().index))
    cmap = sns.light_palette("maroon", n_slices, reverse=True)
    
    ax.pie(df_some['industry'].value_counts(), labels=df_some['industry'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'xx-small'}, colors = cmap)
    plt.title('Industries in Top 20 Index')
    plt.show()   
  
    
    # by country:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_all['country'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("seagreen", n_slices, reverse=True)
    
    ax.pie(df_all['country'].value_counts(), labels=df_all['country'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Countries in Public B-Corp Universe')
    plt.show()
    
    # by country:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_some['country'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("seagreen", n_slices, reverse=True)
    
    ax.pie(df_some['country'].value_counts(), labels=df_some['country'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Countries in Top 20 Index')
    plt.show()


    
    # by currency:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_all['currency'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("goldenrod", n_slices, reverse=True)
    
    ax.pie(df_all['currency'].value_counts(), labels=df_all['currency'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Currencies in Public B-Corp Universe')
    plt.show()
    
    # by currency:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_some['currency'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("goldenrod", n_slices, reverse=True)
    
    ax.pie(df_some['currency'].value_counts(), labels=df_some['currency'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Currencies in Top 20 Index')
    plt.show()

# %%
visualize_groups(classify_all, classify_index)

# %%
print(stock_index.shape)
# Out:
# (20, 14)

# %%
print(price_wgt_index.shape)
display(price_wgt_index)
# Out:
# (309, 21)
#             NTCO3.SA_px_USD  0973.HK_px_USD  WRBY_px_USD  COUR_px_USD  \
# 2022-01-04         3.914689        3.977998    44.080002    25.000000
# 2022-01-05         3.713087        3.964855    41.660000    24.010000
# 2022-01-06         3.687638        4.030334    42.389999    23.410000
# 2022-01-07         3.598662        4.030334    39.709999    23.219999
# 2022-01-09         3.598662        4.168364    39.709999    23.219999
# ...                     ...             ...          ...          ...
# 2022-12-26         1.987802        3.007040    13.530000    12.050000
# 2022-12-27         1.862088        3.055792    12.990000    11.390000
# 2022-12-28         2.006002        3.058085    13.010000    11.220000
# 2022-12-29         2.027185        3.089908    13.750000    11.760000
# 2022-12-30         2.027185        3.089908    13.490000    11.830000
#
#             LMND_px_USD  BIRD_px_USD  GROV_px_USD  SOMA3.SA_px_USD  \
# 2022-01-04    39.029999       15.590    49.450001         1.991196
# 2022-01-05    36.790001       13.570    49.700001         1.791267
# 2022-01-06    35.330002       15.230    49.599998         1.854434
# 2022-01-07    37.139999       13.940    49.700001         1.826764
# 2022-01-09    37.139999       13.940    49.700001         1.826764
# ...                 ...          ...          ...              ...
# 2022-12-26    14.400000        2.390     1.200000         1.930785
# 2022-12-27    13.410000        2.270     1.385000         1.825134
# 2022-12-28    12.910000        2.245     1.385000         1.918353
# 2022-12-29    13.840000        2.370     1.490000         1.895074
# 2022-12-30    13.680000        2.420     1.995000         1.895074
#
#             ARZZ3.SA_px_USD  MME.AX_px_USD  ...  FREY.PA_px_USD  \
# 2022-12-26         5.422903e+08       7.066206e+08       5.123703e+08
# 2022-12-27         4.968465e+08       7.326727e+08       5.103949e+08
# 2022-12-28         5.359809e+08       7.216308e+08       5.078597e+08
# 2022-12-29         5.179069e+08       7.498693e+08       5.211976e+08
# 2022-12-30         5.179069e+08       7.498693e+08       5.211976e+08
#
#             1112.HK_MktCap_USD  VITL_MktCap_USD  COCO_MktCap_USD  \
# 2022-01-04        8.803967e+08     7.598477e+08     6.831516e+08
# 2022-01-05        9.198493e+08     7.343522e+08     6.541176e+08
# 2022-01-06        9.001342e+08     7.644452e+08     6.239451e+08
# 2022-01-07        9.001342e+08     7.736403e+08     6.210987e+08
# 2022-01-09        9.165699e+08     7.736403e+08     6.210987e+08
# ...                        ...              ...              ...
# 2022-12-26        1.381215e+09     6.469990e+08     7.782235e+08
# 2022-12-27        1.167130e+09     6.566120e+08     7.941637e+08
# 2022-12-28        1.247817e+09     6.649712e+08     7.719613e+08
# 2022-12-29        1.278555e+09     6.382219e+08     7.953023e+08
# 2022-12-30        1.278555e+09     6.235933e+08     7.867629e+08
#
#             2897.TW_MktCap_USD      Index
# 2022-01-04        7.305438e+08  40.665707
# 2022-01-05        7.311417e+08  39.024153
# 2022-01-06        7.316935e+08  39.294600
# 2022-01-07        7.316935e+08  38.736581
# 2022-01-09        7.345980e+08  38.923363
# ...                        ...        ...
# 2022-12-26        7.115168e+08  22.933035
# 2022-12-27        7.080414e+08  22.226659
# 2022-12-28        7.055817e+08  22.578886
# 2022-12-29        7.149754e+08  22.937447
# 2022-12-30        7.149754e+08  22.922750
#
# [309 rows x 21 columns]

# %% [markdown]
# ## Reconstitute:

# %%
df22 = stock_data_filtered.copy()

# %%
def reconstitute(df, recon_date):

    # Confirm Implied Shares Outstanding for Mkt Cap calculation:    
    df['impliedSharesOutstanding'] = df['marketCap'] / df['previousClose']
    
    reprice = get_starting_price(df, start = recon_date)
    
    recon_px = reprice.filter(like=recon_date, axis=0).T
    recon_px.columns = [str(recon_date)]
    
    exch_data_recast = get_rates(date=recon_date)
    currency_dict_recast = currency_dict.copy()
    
    # Revise currency translation:
    for symbol, rate in exch_data_recast['rates'].items():
        for key in currency_dict_recast.keys():
            if symbol == key:
                currency_dict_recast[key][1] = rate
                
    # Revise currency map:
    currency_map_rev = {symbol:rate
                       for symbol, name in currency_dict_recast.items()
                       for rate in name}
    
    col = 'USDExchRate'+str(recon_date)
    df[col] = df['currency'].map(currency_map_rev)
    df = df.join(recon_px)
    
    
    col2 = 'CloseUSD'+str(recon_date)
    df[col2] = df[recon_date] / df[col]
    
    col3='MarketCapUSD'+str(recon_date)
    df[col3] = df[col2] * df['impliedSharesOutstanding']
    
    
    return df

# %%
df23 = reconstitute(df22, recon_date = '2023-01-03') 
display(df23.head(20))

df24 = reconstitute(df23, recon_date = '2024-01-02') 
display(df24.head(20))
# Out:
#                                      shortName  \
# Ticker
# 0973.HK                             L'OCCITANE
# 1112.HK                          H&H INTL HLDG
# 1346.HK                            LEVER STYLE
# 1H2.SI                            $ Olive Tree
# 2897.TW                          O-BANK CO LTD
# 6088.T                   SIGMAXYZ HOLDINGS INC
# ABB.AX                    AUSSIEBAND FPO [ABB]
# AEF.AX                     A ETHICAL FPO [AEF]
# ALQP.PA                               QUADPACK
# AMAL               Amalgamated Financial Corp.
# ARZZ3.SA                AREZZO CO   ON      NM
# BFT.WA                                 BENEFIT
# BIO.AX                    BIOME AUST FPO [BIO]
# BIRD                            Allbirds, Inc.
# CLSA3.SA                CLEARSALE   ON      NM
# COCO               The Vita Coco Company, Inc.
# CONCHATORO.SN               VINA CONCHA Y TORO
# COUR                            Coursera, Inc.
# CVT.NZ         Comvita Limited Ordinary Shares
# CWEB.TO            CHARLOTTES WEB HOLDINGS INC
#
#                                                         longName  \
# Ticker
# 0973.HK                            L'Occitane International S.A.
# 1112.HK        Health and Happiness (H&H) International Holdi...
# 1346.HK                                  Lever Style Corporation
# 1H2.SI                                Olive Tree Estates Limited
# 2897.TW                                         O-Bank Co., Ltd.
# 6088.T                                    SIGMAXYZ Holdings Inc.
# ABB.AX                                  Aussie Broadband Limited
# AEF.AX                     Australian Ethical Investment Limited
# ALQP.PA                                Quadpack Industries, S.A.
# AMAL                                 Amalgamated Financial Corp.
# ARZZ3.SA                        Arezzo Indústria e Comércio S.A.
# BFT.WA                                      Benefit Systems S.A.
# BIO.AX                                   Biome Australia Limited
# BIRD                                              Allbirds, Inc.
# CLSA3.SA                                          ClearSale S.A.
# COCO                                 The Vita Coco Company, Inc.
# CONCHATORO.SN                            Viña Concha y Toro S.A.
# COUR                                              Coursera, Inc.
# CVT.NZ                                           Comvita Limited
# CWEB.TO                           Charlotte's Web Holdings, Inc.
#
#                      country currency previousClose impliedSharesOutstanding  \
# Ticker
# 0973.HK           Luxembourg      HKD          30.6        1419248874.248366
# 1112.HK            Hong Kong      HKD         10.22          649351013.69863
# 1346.HK            Hong Kong      HKD          0.87         639100027.586207
# 1H2.SI             Singapore      SGD          0.08              115845000.0
# 2897.TW               Taiwan      TWD          9.88         2749463630.76923
# 6088.T                 Japan      JPY        1583.0          42183304.166772
# ABB.AX             Australia      AUD          3.61         300091106.925208
# AEF.AX             Australia      AUD          4.89         112781991.002045
# ALQP.PA                Spain      EUR          13.9           4391246.043165
# AMAL           United States      USD          24.6          30560010.406504
# ARZZ3.SA              Brazil      BRL         52.03         112109588.468191
# BFT.WA                Poland      PLN        2730.0           2987267.750916
# BIO.AX             Australia      AUD         0.325         209553723.076923
# BIRD           United States      USD        0.6126         160736885.406464
# CLSA3.SA              Brazil      BRL          7.65         204176414.117647
# COCO           United States      USD         24.75          57531397.171717
# CONCHATORO.SN          Chile      CLP        1241.2         738235953.335482
# COUR           United States      USD         11.97         155779678.529657
# CVT.NZ           New Zealand      NZD          2.07          69886144.927536
# CWEB.TO        United States      CAD          0.26         156960984.615385
#
#                   marketCap                                  industry  \
# Ticker
# 0973.HK         43429015552             Household & Personal Products
# 1112.HK          6636367360                            Packaged Foods
# 1346.HK           556017024                     Apparel Manufacturing
#               beginningMarketCapUSD  USDExchRate2023-01-03   2023-01-03  \
# Ticker
# 0973.HK           5840201377.746689               7.813450    25.320807
# 1112.HK            877978078.233685               7.813450    15.252042
# 1346.HK             25242197.742691               7.813450     0.292466
# 1H2.SI               9607133.515744               1.345415     0.159000
# 2897.TW            651007444.449265              30.665300     8.040440
# 6088.T             354595673.267619             131.253499  1169.781372
# ABB.AX             918667322.737256               1.486768     2.690000
# AEF.AX            1005466060.447263               1.486768     4.086268
# ALQP.PA             114112970.65156               0.948180    19.100000
# AMAL                498564621.47541               1.000000    22.574814
# ARZZ3.SA          1516854444.533318               5.480118    69.735306
# BFT.WA              472712000.79141               4.430857   767.895508
# BIO.AX              17278903.262203               1.486768     0.071000
# BIRD              2419396408.959961               1.000000     2.240000
# CLSA3.SA           365263116.536676               5.480118     4.890000
# COCO                    683151600.0               1.000000    13.500000
# CONCHATORO.SN     1012725356.718075             862.849697  1014.402100
# COUR                   3933100000.0               1.000000    12.350000
# CVT.NZ             155268703.279696               1.600930     3.227505
# CWEB.TO            160228596.687104               1.367520     0.720000
#
#                CloseUSD2023-01-03 MarketCapUSD2023-01-03
# Ticker
# 0973.HK                  3.240669      4599316067.148751
# 1112.HK                  1.952024       1267548754.34737
# 1346.HK                  0.037431        23922254.927163
# 1H2.SI                   0.118179        13690463.054849
# 2897.TW                  0.262200        720909179.79945
# 6088.T                   8.912382        375953736.87269
# ABB.AX                   1.809294       542952965.627562
# AEF.AX                   2.748423       309972662.150564
# ALQP.PA                 20.143855        88456623.320032
# AMAL                    22.574814       689886545.960048
# ARZZ3.SA                12.725147      1426610965.929354
# BFT.WA                 173.306317       517712371.796552
# BIO.AX                   0.047755        10007152.982568
# BIRD                     2.240000       360050624.843386
# CLSA3.SA                 0.892317       182189988.933596
# COCO                    13.500000       776673861.818182
# CONCHATORO.SN            1.175642       867900984.000278
# COUR                    12.350000      1923879089.266501
# CVT.NZ                   2.016019       140891781.647506
# CWEB.TO                  0.526501        82640044.323861
#                                      shortName  \
# Ticker
# 0973.HK                             L'OCCITANE
# 1112.HK                          H&H INTL HLDG
# 1346.HK                            LEVER STYLE
# 1H2.SI                            $ Olive Tree
# 2897.TW                          O-BANK CO LTD
# 6088.T                   SIGMAXYZ HOLDINGS INC
# ABB.AX                    AUSSIEBAND FPO [ABB]
# AEF.AX                     A ETHICAL FPO [AEF]
# ALQP.PA                               QUADPACK
# AMAL               Amalgamated Financial Corp.
# ARZZ3.SA                AREZZO CO   ON      NM
# BFT.WA                                 BENEFIT
# BIO.AX                    BIOME AUST FPO [BIO]
# BIRD                            Allbirds, Inc.
# CLSA3.SA                CLEARSALE   ON      NM
# COCO               The Vita Coco Company, Inc.
# CONCHATORO.SN               VINA CONCHA Y TORO
# COUR                            Coursera, Inc.
# CVT.NZ         Comvita Limited Ordinary Shares
# CWEB.TO            CHARLOTTES WEB HOLDINGS INC
#
#                                                         longName  \
# Ticker
# 0973.HK                            L'Occitane International S.A.
# 1112.HK        Health and Happiness (H&H) International Holdi...
# CVT.NZ                      1.600930     3.227505            2.016019
# CWEB.TO                     1.367520     0.720000            0.526501
#
#                MarketCapUSD2023-01-03  USDExchRate2024-01-02   2024-01-02  \
# Ticker
# 0973.HK             4599316067.148751               7.815320    21.850000
# 1112.HK              1267548754.34737               7.815320    12.240000
# 1346.HK               23922254.927163               7.815320     0.806804
# 1H2.SI                13690463.054849               1.326405     0.076000
# 2897.TW               720909179.79945              30.894018     9.920000
# 6088.T                375953736.87269             142.156502          NaN
# ABB.AX               542952965.627562               1.478066     3.790000
# AEF.AX               309972662.150564               1.478066     5.189354
# ALQP.PA               88456623.320032               0.913960    19.900000
# AMAL                 689886545.960048               1.000000    26.446409
# ARZZ3.SA            1426610965.929354               4.923979    62.270000
# BFT.WA               517712371.796552               3.991717  2020.000000
# BIO.AX                10007152.982568               1.478066     0.250000
# BIRD                 360050624.843386               1.000000     1.300000
# CLSA3.SA             182189988.933596               4.923979     3.550000
# COCO                 776673861.818182               1.000000    26.180000
# CONCHATORO.SN        867900984.000278             884.320491  1027.868530
# COUR                1923879089.266501               1.000000    19.290001
# CVT.NZ               140891781.647506               1.600140     2.289252
# CWEB.TO               82640044.323861               1.332265     0.270000
#
#                CloseUSD2024-01-02  MarketCapUSD2024-01-02
# Ticker
# 0973.HK                  2.795791        3967923059.28961
# 1112.HK                  1.566155        1016984110.57341
# 1346.HK                  0.103234         65976637.641731
# 1H2.SI                   0.057298          6637655.706137
# 2897.TW                  0.321098        882846621.860523
# 6088.T                        NaN                     NaN
# ABB.AX                   2.564162        769482069.000282
# AEF.AX                   3.510908        395967209.645114
# ALQP.PA                 21.773381         95612274.698964
# AMAL                    26.446409        808202541.144841
# ARZZ3.SA                12.646277       1417768866.446014
# BFT.WA                 506.047899        1511700568.16398
# BIO.AX                   0.169140         35443904.919828
# BIRD                     1.300000        208957943.363872
# CLSA3.SA                 0.720962        147203361.424116
# COCO                    26.180000       1506171995.512745
# CONCHATORO.SN            1.162326        858070701.824268
# COUR                    19.290001       3004990141.457648
# CVT.NZ                   1.430657         99983136.912311
# CWEB.TO                  0.202662         31810088.481017
#
# [20 rows x 22 columns]

# %%
df23.shape
# Out:
# (53, 19)

# %%
#df24.to_csv('reconst_test.csv')

# %%
def construct_index_with_recon (df, cutoff=20, start_date = '2022-01-04', end_date = '2022-12-31', pw_divisor = 1, mw_divisor=1000000000):
    today = str(dt.today())
    if today >'2024-12-31':
        print("Add a Year!")
    
    # Clean up errant stock:
    if 'MLMFI.PA' in df.index:
        df.drop('MLMFI.PA', axis=0, inplace=True)

    
    if str(start_date[0:4]) == "2022":
        col = 'beginningMarketCapUSD'
    else:
        col = 'MarketCapUSD' + start_date
    index = filter_index(df, size=False, num=True, num_thresh=cutoff, col = col)
    
    #display(index.head())
    
    assert index.shape[0] == cutoff
    
    prices = get_price_history(index, start_date, end= end_date)
    price_and_info, index_currencies = get_country_info(prices, index)
    
    
    # Set stock universe
    stock_universe = list(index.T.columns)
    
    #Get historical exchange rates
    filename = "daily_rates_" + str(start_date[0:4] + ".csv")
    daily_rates_df, _ = load_rates(filename)

    daily_price_and_info_df = price_and_info.join(daily_rates_df)
    
    # Add marketcap:
    daily_price_MC_usd_all = convert_price_mktcap_USD(daily_price_and_info_df, stock_universe) 
    
    # Refine DF INTO USD and calculate PW and MW indicies:
    daily_info_usd, daily_px_USD, daily_MC_USD = get_df_in_USD(daily_price_MC_usd_all)
    
  
    price_wgt_index = calc_px_weighted_index(daily_px_USD, divisor = pw_divisor, show_chart=False)
    
    #display(price_wgt_index.head())
    #display(price_wgt_index.tail())
    
    
    mktcap_wgt_index = calc_MC_weighted_index (daily_MC_USD, divisor = mw_divisor, show_chart=False)
    

    #filename2 = 'px_weighted_idx_details'+ str(start_date[0:4]) + ".csv"
    #price_wgt_index.to_csv(filename2)

    ending_index_pw = price_wgt_index.iloc[-1,-1]
    ending_index_mkt = mktcap_wgt_index.iloc[-1,-1]
    
    return price_wgt_index, ending_index_pw, mktcap_wgt_index, ending_index_mkt

# %%
def set_divisor (df0, df1, s0 = '2022-01-04', e0 = '2022-12-31', s1 = '2023-01-03', e1='2023-12-31', divisor=1):
    _, end0_pw, _, end0_mkt = construct_index_with_recon(df0, start_date = s0, end_date = e0, pw_divisor = divisor, mw_divisor = divisor)
    print("end year 0", end0_pw)
    px_wgt_1, _, mkt_cap1, _ = construct_index_with_recon(df1, start_date = s1, end_date = e1, pw_divisor = divisor, mw_divisor = divisor)
        
    
    beg1_pw = px_wgt_1.iloc[0,-1]
    print("beg year 1", beg1_pw)
    
    divisor1_pw = divisor * (beg1_pw/end0_pw)
    print("PW Divisor = ", divisor1_pw)
    
    beg1_mkt = mkt_cap1.iloc[0,-1]
    print("beg year 1", beg1_mkt)
    
    divisor1_mkt = divisor * (beg1_mkt/end0_mkt)
    print("Mkt Divisor = ", divisor1_mkt)
    
    return divisor1_pw, divisor1_mkt

# %% [markdown]
# ### COMPILE PX WEIGHTED INDEX and GRAPH PERFORMANCE

# %%
price_wgt_index_22, _, _, _ = construct_index_with_recon(df22, pw_divisor = 1)
div1, _ = set_divisor(df22, df23, s0 = '2022-01-04', e0 = '2022-12-31', s1 = '2023-01-03', e1='2023-12-31', divisor=1)

price_wgt_index_23, _, _, _ = construct_index_with_recon(df23, start_date = '2023-01-03', end_date = '2023-12-31', pw_divisor = div1)
div2, _ = set_divisor(df23, df24, s0 = '2023-01-03', e0 = '2023-12-31', s1 = '2024-01-02', e1='2024-04-15', divisor = div1)

price_wgt_index_24, _, _, _ = construct_index_with_recon(df24, start_date = '2024-01-02', end_date = '2024-04-15', pw_divisor = div2)
# Out:
# end year 0 139.20564224317732
# beg year 1 345.93662273774225
# PW Divisor =  2.4850761590067454
# beg year 1 23399125694.787884
# Mkt Divisor =  1.0320122800414107
# end year 0 277.44671134068966
# beg year 1 281.8325442407114
# PW Divisor =  2.5243598424375717
# beg year 1 11279280156.533945
# Mkt Divisor =  2.482250587709366

# %%
index_df = pd.concat([price_wgt_index_22.iloc[:,-1], price_wgt_index_23.iloc[:,-1]])
index_df = pd.concat([index_df, price_wgt_index_24.iloc[:,-1]])

#index_df

m = 20
fig, ax = plt.subplots(figsize = (12,6))
ax.plot(index_df, color = 'seagreen', linewidth=2)
plt.title('Price Weighted Index | '+ str(m) + ' stocks')
plt.annotate("Stocks in Index:", (0,0), (0, -20), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
#plt.annotate(stock_universe[0:int(m/2)], (0,0), (0, -30), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
#plt.annotate(stock_universe[int(m/2):], (0,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
plt.show()

# %%
dfs = [df22, df23, df24]
px_indexs = [price_wgt_index_22, price_wgt_index_23, price_wgt_index_24]

for i in range(len(dfs)):
    tickers = [col[:-7] for col in px_indexs[i].columns][:-1]
    info = dfs[i].loc[dfs[i].index.isin(tickers)]

    visualize_groups(classify_all, info)

# %% [markdown]
# ### COMPILE Market WEIGHTED INDEX and GRAPH PERFORMANCE

# %%
_,_,mkt_wgt_index_22,_ = construct_index_with_recon(df22, mw_divisor = 1000000000)
_, div1 = set_divisor(df22, df23, s0 = '2022-01-04', e0 = '2022-12-31', s1 = '2023-01-03', e1='2023-12-31', divisor=1000000000)

_, _, mkt_wgt_index_23, _ = construct_index_with_recon(df23, start_date = '2023-01-03', end_date = '2023-12-31', pw_divisor = div1)
_, div2 = set_divisor(df23, df24, s0 = '2023-01-03', e0 = '2023-12-31', s1 = '2024-01-02', e1='2024-04-15', divisor = div1)

_, _, mkt_wgt_index_24, _ = construct_index_with_recon(df24, start_date = '2024-01-02', end_date = '2024-04-15', pw_divisor = div2)
# Out:
# end year 0 1.3920564224317732e-07
# beg year 1 3.4593662273774226e-07
# PW Divisor =  2485076159.006746
# beg year 1 23.399125694787884
# Mkt Divisor =  1032012280.0414107
# end year 0 6.680891507607916e-07
# beg year 1 6.786501963878785e-07
# PW Divisor =  1048326163.8469176
# beg year 1 27.160403756664262
# Mkt Divisor =  1030838865.5903246

# %%
mkt_index_df = pd.concat([mkt_wgt_index_22.iloc[:,-1], mkt_wgt_index_23.iloc[:,-1]])
mkt_index_df = pd.concat([mkt_index_df, mkt_wgt_index_24.iloc[:,-1]])

#index_df

m = 20
fig, ax = plt.subplots(figsize = (12,6))
ax.plot(mkt_index_df, color = 'royalblue', linewidth=2)
plt.title('Market Weighted Index | '+ str(m) + ' stocks')
plt.annotate("Stocks in Index:", (0,0), (0, -20), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
#plt.annotate(stock_universe[0:int(m/2)], (0,0), (0, -30), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
#plt.annotate(stock_universe[int(m/2):], (0,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
plt.show()

# %%
download = True

# %%
if download == True:
    price_wgt_index_22.to_csv("px_weighted_idx_details_2022.csv")
    price_wgt_index_23.to_csv("px_weighted_idx_details_2023.csv")
    price_wgt_index_24.to_csv("px_weighted_idx_details_2024.csv")
    
    mkt_wgt_index_22.to_csv("mkt_weighted_idx_details_2022.csv")
    mkt_wgt_index_23.to_csv("mkt_weighted_idx_details_2023.csv")
    mkt_wgt_index_24.to_csv("mkt_weighted_idx_details_2024.csv")

# %% [markdown]
# Attributes = ['address1',
#  'city',
#  'state',
#  'zip',
#  'country',
#  'phone',
#  'website',
#  'industry',
#  'industryKey',
#  'industryDisp',
#  'sector',
#  'sectorKey',
#  'sectorDisp',
#  'longBusinessSummary',
#  'fullTimeEmployees',
#  'companyOfficers',
#  'auditRisk',
#  'boardRisk',
#  'compensationRisk',
#  'shareHolderRightsRisk',
#  'overallRisk',
#  'governanceEpochDate',
#  'compensationAsOfEpochDate',
#  'maxAge',
#  'priceHint',
#  'previousClose',
#  'open',
#  'dayLow',
#  'dayHigh',
#  'regularMarketPreviousClose',
#  'regularMarketOpen',
#  'regularMarketDayLow',
#  'regularMarketDayHigh',
#  'beta',
#  'forwardPE',
#  'volume',
#  'regularMarketVolume',
#  'averageVolume',
#  'averageVolume10days',
#  'averageDailyVolume10Day',
#  'bid',
#  'ask',
#  'bidSize',
#  'askSize',
#  'marketCap',
#  'fiftyTwoWeekLow',
#  'fiftyTwoWeekHigh',
#  'priceToSalesTrailing12Months',
#  'fiftyDayAverage',
#  'twoHundredDayAverage',
#  'currency',
#  'enterpriseValue',
#  'profitMargins',
#  'floatShares',
#  'sharesOutstanding',
#  'sharesShort',
#  'sharesShortPriorMonth',
#  'sharesShortPreviousMonthDate',
#  'dateShortInterest',
#  'sharesPercentSharesOut',
#  'heldPercentInsiders',
#  'heldPercentInstitutions',
#  'shortRatio',
#  'shortPercentOfFloat',
#  'impliedSharesOutstanding',
#  'bookValue',
#  'priceToBook',
#  'lastFiscalYearEnd',
#  'nextFiscalYearEnd',
#  'mostRecentQuarter',
#  'netIncomeToCommon',
#  'trailingEps',
#  'forwardEps',
#  'pegRatio',
#  'enterpriseToRevenue',
#  'enterpriseToEbitda',
#  '52WeekChange',
#  'SandP52WeekChange',
#  'exchange',
#  'quoteType',
#  'symbol',
#  'underlyingSymbol',
#  'shortName',
#  'longName',
#  'firstTradeDateEpochUtc',
#  'timeZoneFullName',
#  'timeZoneShortName',
#  'uuid',
#  'messageBoardId',
#  'gmtOffSetMilliseconds',
#  'currentPrice',
#  'targetHighPrice',
#  'targetLowPrice',
#  'targetMeanPrice',
#  'targetMedianPrice',
#  'recommendationMean',
#  'recommendationKey',
#  'numberOfAnalystOpinions',
#  'totalCash',
#  'totalCashPerShare',
#  'ebitda',
#  'totalDebt',
#  'quickRatio',
#  'currentRatio',
#  'totalRevenue',
#  'debtToEquity',
#  'revenuePerShare',
#  'returnOnAssets',
#  'returnOnEquity',
#  'freeCashflow',
#  'operatingCashflow',
#  'revenueGrowth',
#  'grossMargins',
#  'ebitdaMargins',
#  'operatingMargins',
#  'financialCurrency',
#  'trailingPegRatio']
