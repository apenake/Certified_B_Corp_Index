# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
from datetime import timedelta
import random

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
import yfinance as yf
import requests
import json

# %%
s = '2022-01-04'
e = str(dt.today())[0:10]

download = False

# %%
def load_B_corp():
    df = pd.read_csv("https://query.data.world/s/pzd7uazpmpyortmg6fsuxiaoizllgu?dws=00000", encoding='ISO-8859-1')
    display(df.head(10))
    
    df.drop(['B Corp Impact Data ID', 'Ticker 2', 'Ticker 3'], axis=1, inplace = True)

    df.dropna(axis=0, subset=['Public Company Name (As Listed on Exchange)'], inplace=True)
    print("Initial load =", len(df), "companies")
    
    temp = df.copy()
    temp = temp[temp['Public Listing Status'] == 'active']

    temp['Ticker 1'].replace(": ", ":", regex=True, inplace=True)

    temp['Exchange'] = temp['Ticker 1'].str.split(":").str[0]
    temp['Ticker2'] = temp['Ticker 1'].str.split(":").str[1]
    temp.dropna(subset=["Ticker2"], inplace=True) # Remove any NaN tickers
    print("There are", len(temp), "companies after cleaning")
    
    return temp

# %% [markdown]
# ### Stocks are from Global Exchanges - build and maintain an exchange conversion dictionary to interface with Yahoo Finance

# %%
exchange_dict = {'ASX': '.AX', 
                 'WSE': '.WA',
                 'BOVESPA': '.SA',
                 'ETHEX': '',
                 'TSX': '.TO',
                 'ENXTPA': '.PA',
                 'BME': '.MC',
                 'ENXTBR': '.BR',
                 'KLSE': '.KL',
                 'LSE': '.L',
                 'TWSE': '.TW',
                 'NZSE': '.NZ',
                 'SGX': '.SI',
                 'BIT': '.MI',
                 'TASE': '.TA',
                 'XMIL': '.MI',
                 'NZE': '.NZ',
                 'BVMF': '.SA',
                 'HKG': '.HK',
                 'LON': '.L',
                 'MIL': '.MI',
                 'MOVI3': '.SA',
                 'TSE': '.T',
                 'BRK': '.L',
                 'SNSE': '.SN',
                 'MOVIDA B3': '.SA',
                 'NYSE': '',
                 'NASDAQGS': '',
                 'NASDAQGM': '',
                 'NASDAQCM': ''
                }

exchange_map = {exchanges: extention
                 for exchanges, extention in exchange_dict.items()
                 for exchange in exchanges}

# %%
def map_exchange (df):
    df['Intl Extention'] = df['Exchange'].map(exchange_map)
    
    # Check to see if we missed any:
    df['Ticker'] = df['Ticker2'] + df['Intl Extention'] 
    mask = df['Ticker'].isna()
    
    print("Add exchanges to map:")
    display(df[mask])
    
    return df

# %%
def check_nans(df):
    tickers = df['Ticker'].to_list()

    count = 0
    for t in tickers:
        try:
            ticker = yf.Ticker(t)
            info = None
        except:
            count +=1
            print(f"Cannot get info of {t}, it probably does not exist")

    print("Total nans =", count, "which is", round(count/df.shape[0],2)*100, '% of the total')
    
    mask = df['Ticker'].isna()
    
    # Remove NaNs:
    return df[-mask], count

# %%
data = load_B_corp()

data = map_exchange(data)

b_corp_df, nans = check_nans(data)

assert b_corp_df.shape[0] == data.shape[0] - nans
# Out:
#   Public Company Name (As Listed on Exchange) B Corp Impact Data ID  \
# 0                              Allbirds, Inc.    001C000001SGhnyIAD
# 1                       Amalgamated Financial    001C000001K16JSIAZ
# 2                            AppHarvest, Inc.    0013b00001o41JFAAY
# 3                                   Arezzo&Co    0013b00001qHFddAAG
# 4                       Arowana International    001C000001ZzPK4IAN
# 5          Australian Ethical Investment Ltd.    001C0000014QBrxIAG
# 6                        Benefit Systems S.A.    001C000001TZiM4IAL
# 7                             Biome Australia    0013b00001vKRdWAAW
# 8                                 Cafe Direct    001C000001a2QxxIAE
# 9              Charlotte's Web Holdings, Inc.    001C000001XtSSRIA3
#
#         Ticker 1      Ticker 2 Ticker 3  IPO Year  Year Delisted  \
# 0  NASDAQGS:BIRD           NaN      NaN    2021.0            NaN
# 1  NASDAQGM:AMAL           NaN      NaN    2018.0            NaN
# 2  NASDAQGS:APPH           NaN      NaN    2020.0            NaN
# 3  BOVESPA:ARZZ3           NaN      NaN    2011.0            NaN
# 4       ASX: AWN           NaN      NaN    2013.0         2021.0
# 5        ASX:AEF           NaN      NaN    2002.0            NaN
# 6        WSE:BFT           NaN      NaN    2013.0            NaN
# 7        ASX:BIO           NaN      NaN    2021.0            NaN
# 8          ETHEX           NaN      NaN       NaN            NaN
# 9       TSX:CWEB  OTCPK:CWBH.F      NaN    2018.0            NaN
#
#    Year Certified Public Listing Status  Year Decertified
# 0          2016.0                active               NaN
# 1          2017.0                active               NaN
# 2          2019.0              delisted            2023.0
# 3          2022.0                active               NaN
# 4          2018.0              delisted               NaN
# 5          2014.0                active               NaN
# 6          2018.0                active               NaN
# 7          2021.0                active               NaN
# 8          2018.0                active               NaN
# 9          2020.0                active               NaN
# Initial load = 68 companies
# There are 62 companies after cleaning
# Add exchanges to map:
#          Public Company Name (As Listed on Exchange)                Ticker 1  \
# 19  Heidelberg District Community Enterprise Limited                 NSX:EIC
# 36                                         SIDERPERU             BVL:SIDERC1
# 41                                  Urb-it AB (publ)                OM:URBIT
# 48                                   Weleda AG Group  OTC-X:BEKB:Weleda N-PS
# 56                             Vinedos Emiliana S.A.           XSGO:EMILIANA
#
#     IPO Year  Year Delisted  Year Certified Public Listing Status  \
# 19    2019.0            NaN          2019.0                active
# 36    2006.0            NaN          2022.0                active
# 41    2017.0            NaN          2020.0                active
# 48       NaN            NaN          2021.0                active
# 56    1996.0            NaN          2023.0                active
#
#     Year Decertified Exchange   Ticker2 Intl Extention Ticker
# 19               NaN      NSX       EIC            NaN    NaN
# 36               NaN      BVL   SIDERC1            NaN    NaN
# 41               NaN       OM     URBIT            NaN    NaN
# 48               NaN    OTC-X      BEKB            NaN    NaN
# 56               NaN     XSGO  EMILIANA            NaN    NaN
# Cannot get info of nan, it probably does not exist
# Cannot get info of nan, it probably does not exist
# Cannot get info of nan, it probably does not exist
# Cannot get info of nan, it probably does not exist
# Cannot get info of nan, it probably does not exist
# Total nans = 5 which is 8.0 % of the total

# %%
isolate_us = False

# %%
if isolate_us:

    exchanges = set(b_corp_df['Exchange'])
    us_ex = ['NYSE', 'NASDAQGS','NASDAQGM', 'NASDAQCM']
    us = b_corp_df[b_corp_df['Exchange'].isin(us_ex)]
    print("Isolating US Companies")
    display(us.head())

# %%
public_subs = ['UL', 'SOMA3.SA', 'ABI.BR', 'PG', 'FFH.TO', 'KO', 'GPS', 'KIK.F', 'NESN.SW',
               'OPY', '4755.T', 'HAIN', 'DANOY', 'CABK.MC', 'ISUN']

# %%
def get_stock_data (df, add_subs = False):
    tickers_list = df['Ticker'].tolist()
    if add_subs:
        tickers_list = tickers_list + public_subs
    tickers_data= {}
    
    for ticker in tickers_list:
        ticker_object = yf.Ticker(ticker)
        
        #convert info() output from dictionary to dataframe
        temp = pd.DataFrame.from_dict(ticker_object.info, orient="index")
        temp.reset_index(inplace=True)
        temp.columns = ["Attribute", "Recent"]

        # add (ticker, dataframe) to main dictionary
        tickers_data[ticker] = temp

    return tickers_data

# %%
msft = yf.Ticker("MSFT")
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and power automate; and on-premises ERP and CRM applications. The Intelligent Cloud segment offers server products and cloud services, such as azure and other cloud services; SQL and windows server, visual studio, system center, and related client access licenses, as well as nuance and GitHub; and enterprise services including enterprise support services, industry solutions, and nuance professional services. The More Personal Computing segment offers Windows, including windows OEM licensing and other non-volume licensing of the Windows operating system; Windows commercial comprising volume licensing of the Windows operating system, windows cloud services, and other Windows commercial offerings; patent licensing; and windows Internet of Things; and devices, such as surface, HoloLens, and PC accessories. Additionally, this segment provides gaming, which includes Xbox hardware and content, and first- and third-party content; Xbox game pass and other subscriptions, cloud gaming, advertising, third-party disc royalties, and other cloud services; and search and news advertising, which includes Bing, Microsoft News and Edge, and third-party affiliates. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online, and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.',
#  'fullTimeEmployees': 221000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Satya  Nadella',
#    'age': 56,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'totalPay': 9276400,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bradford L. Smith LCA',
#    'age': 64,
#    'title': 'President & Vice Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2023,
#    'totalPay': 3591277,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Amy E. Hood',
#    'age': 51,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'totalPay': 3452196,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Judson B. Althoff',
#    'age': 49,
#    'title': 'Executive VP & Chief Commercial Officer',
#    'yearBorn': 1974,
#    'fiscalYear': 2023,
#    'totalPay': 3355797,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Christopher David Young',
#    'age': 51,
#    'title': 'Executive Vice President of Business Development, Strategy & Ventures',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'totalPay': 2460507,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alice L. Jolla',
#    'age': 56,
#    'title': 'Corporate VP & Chief Accounting Officer',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James Kevin Scott',
#    'age': 51,
#    'title': 'Executive VP of AI & CTO',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Brett  Iversen',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hossein  Nowbar',
#    'title': 'Chief Legal Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frank X. Shaw',
#    'title': 'Chief Communications Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 6,
#  'boardRisk': 4,
#  'compensationRisk': 2,
#  'shareHolderRightsRisk': 2,
#  'overallRisk': 2,
#  'governanceEpochDate': 1716940800,
#  'compensationAsOfEpochDate': 1703980800,
#  'irWebsite': 'http://www.microsoft.com/investor/default.aspx',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 429.17,
#  'open': 424.042,
#  'dayLow': 414.87,
#  'dayHigh': 424.19,
#  'regularMarketPreviousClose': 429.17,
#  'regularMarketOpen': 424.042,
#  'regularMarketDayLow': 414.87,
#  'regularMarketDayHigh': 424.19,
#  'dividendRate': 3.0,
#  'dividendYield': 0.0069999998,
#  'exDividendDate': 1715731200,
#  'payoutRatio': 0.24780001,
#  'fiveYearAvgDividendYield': 0.94,
#  'beta': 0.893,
#  'trailingPE': 35.92424,
#  'forwardPE': 31.291477,
#  'volume': 19815177,
#  'regularMarketVolume': 19815177,
#  'averageVolume': 19426850,
#  'averageVolume10days': 17117020,
#  'averageDailyVolume10Day': 17117020,
#  'bid': 414.45,
#  'ask': 415.63,
#  'bidSize': 200,
#  'askSize': 100,
#  'marketCap': 3083851005952,
#  'fiftyTwoWeekLow': 309.45,
#  'fiftyTwoWeekHigh': 433.6,
#  'priceToSalesTrailing12Months': 13.03491,
#  'fiftyDayAverage': 416.7848,
#  'twoHundredDayAverage': 378.045,
#  'trailingAnnualDividendRate': 2.93,
#  'trailingAnnualDividendYield': 0.0068271314,
#  'currency': 'USD',
#  'enterpriseValue': 3215938551808,
#  'profitMargins': 0.36426997,
#  'floatShares': 7421528951,
#  'sharesOutstanding': 7432309760,
#  'sharesShort': 43764126,
#  'sharesShortPriorMonth': 56321541,
#  'sharesShortPreviousMonthDate': 1713139200,
#  'dateShortInterest': 1715731200,
#  'sharesPercentSharesOut': 0.0058999998,
#  'heldPercentInsiders': 0.00054000004,
#  'heldPercentInstitutions': 0.73665,
#  'shortRatio': 2.18,
#  'shortPercentOfFloat': 0.0058999998,
#  'impliedSharesOutstanding': 7432309760,
#  'bookValue': 34.058,
#  'priceToBook': 12.182894,
#  'lastFiscalYearEnd': 1688083200,
#  'nextFiscalYearEnd': 1719705600,
#  'mostRecentQuarter': 1711843200,
#  'earningsQuarterlyGrowth': 0.199,
#  'netIncomeToCommon': 86181003264,
#  'trailingEps': 11.55,
#  'forwardEps': 13.26,
#  'pegRatio': 2.24,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1045526400,
#  'enterpriseToRevenue': 13.593,
#  'enterpriseToEbitda': 25.69,
#  '52WeekChange': 0.29042637,
#  'SandP52WeekChange': 0.24779081,
#  'lastDividendValue': 0.75,
#  'lastDividendDate': 1715731200,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'underlyingSymbol': 'MSFT',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'firstTradeDateEpochUtc': 511108200,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': 'b004b3ec-de24-385e-b2c1-923f10d3fb62',
#  'messageBoardId': 'finmb_21835',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 414.925,
#  'targetHighPrice': 600.0,
#  'targetLowPrice': 436.0,
#  'targetMeanPrice': 483.33,
#  'targetMedianPrice': 477.33,
#  'recommendationMean': 1.7,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 47,
#  'totalCash': 80013000704,
#  'totalCashPerShare': 10.766,
#  'ebitda': 125182001152,
#  'totalDebt': 106228998144,
#  'quickRatio': 1.132,
#  'currentRatio': 1.242,
#  'totalRevenue': 236583993344,
#  'debtToEquity': 41.963,
#  'revenuePerShare': 31.834,
#  'returnOnAssets': 0.15295,
#  'returnOnEquity': 0.38487998,
#  'freeCashflow': 61497999360,
#  'operatingCashflow': 110122999808,
#  'earningsGrowth': 0.2,
#  'revenueGrowth': 0.17,
#  'grossMargins': 0.69894,
#  'ebitdaMargins': 0.52911997,
#  'operatingMargins': 0.44588003,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.1177}

# %%
if isolate_us:
    load_stock_data = get_stock_data (us)
else:
    load_stock_data = get_stock_data (b_corp_df)
    
print("Number of Stock Records Loaded", len(load_stock_data))
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SZL.AX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SZL.AX&crumb=UKT4pD.hxop
# Number of Stock Records Loaded 57

# %%
# Clean df:
stock_data = pd.concat(load_stock_data) #turn from dict to df
stock_data = stock_data.reset_index()

del stock_data["level_1"] # clean up unnecessary column
stock_data.columns = ["Ticker", "Attribute", "Recent"] # update column names



attr_to_keep = ['shortName', 'longName', 'industry', 'sector','previousClose', 'marketCap',  'currency', 'country',
                'firstTradeDateEpochUtc', 'enterpriseValue','trailingEps', 'forwardEps', 'enterprisetoEbitda', 'ebitda', 'grossMargins',
                'ebitdaMargins', 'operatingMargins']


stock_data = stock_data[stock_data["Attribute"].isin(attr_to_keep)].reset_index()
del stock_data["index"] # clean up unnecessary column



#display(stock_data.head(20))

# %%
print("Number of Stocks:", len(stock_data['Ticker'].unique()))
display(stock_data['Ticker'].unique())
# Out:
# Number of Stocks: 54
# array(['BIRD', 'AMAL', 'ARZZ3.SA', 'AEF.AX', 'BFT.WA', 'BIO.AX',
#        'CWEB.TO', 'CLSA3.SA', 'MLMFI.PA', 'COUR', 'FLOW.TO', 'FREY.PA',
#        'GFI.NZ', 'GROV', 'HAN.MC', 'HLZ.MC', 'INCLU.BR', 'IBAB.BR',
#        'KPG.AX', 'KCT.L', 'KMD.NZ', 'LMND', 'LFG.AX', 'MOVI3.SA',
#        'NTCO3.SA', '2897.TW', '1H2.SI', 'ALQP.PA', 'RETI.MI', '6088.T',
#        'SML.NZ', 'COCO', 'VNT.MI', 'CONCHATORO.SN', 'VITL', 'VVPR',
#        'VHT.AX', 'WRBY', 'ZVIA', 'ABB.AX', 'TIME.MI', 'CVT.NZ', 'DOX.MI',
#        'SOMA3.SA', '1112.HK', 'HMGS.TA', '1346.HK', '0973.HK', 'MME.AX',
#        'MPR.AX', 'TENG.L', 'TPX.L', 'XSG.L', 'XHS.MI'], dtype=object)

# %%
stock_data_filtered = stock_data.pivot(columns = 'Attribute', index='Ticker', values='Recent')

# Keep essential info:
stock_data_filtered = stock_data_filtered[['shortName','country', 'currency', 'industry',
                                           'firstTradeDateEpochUtc', 'sector', 'previousClose', 'marketCap']]

stock_data_filtered['marketCap'] = stock_data_filtered['marketCap'].astype(float)
stock_data_filtered['previousClose'] = stock_data_filtered['previousClose'].astype(float)
stock_data_filtered['impliedSharesOutstanding'] = round((stock_data_filtered['marketCap'] / stock_data_filtered['previousClose']),2)
#stock_data_filtered["marketCap"] = stock_data_filtered["marketCap"].map("{:,.0f}".format)
#stock_data_filtered["impliedSharesOutstanding"] = stock_data_filtered["impliedSharesOutstanding"].map("{:,.0f}".format)

display(stock_data_filtered.iloc[12:18,:])
# Out:
# Attribute                        shortName        country currency  \
# Ticker
# BIO.AX                BIOME AUST FPO [BIO]      Australia      AUD
# BIRD                        Allbirds, Inc.  United States      USD
# CLSA3.SA            CLEARSALE   ON      NM         Brazil      BRL
# COCO           The Vita Coco Company, Inc.  United States      USD
# CONCHATORO.SN           VINA CONCHA Y TORO          Chile      CLP
# COUR                        Coursera, Inc.  United States      USD
#
# Attribute                                 industry firstTradeDateEpochUtc  \
# Ticker
# BIO.AX                              Packaged Foods             1638226800
# BIRD                                Apparel Retail             1635946200
# CLSA3.SA                 Software - Infrastructure             1627909200
# COCO                     Beverages - Non-Alcoholic             1634823000
# CONCHATORO.SN  Beverages - Wineries & Distilleries              947075400
# COUR                 Education & Training Services             1617197400
#
# Attribute                  sector  previousClose     marketCap  \
# Ticker
# BIO.AX         Consumer Defensive         0.3650  7.129738e+07
# BIRD            Consumer Cyclical         0.5757  9.154159e+07
# CLSA3.SA               Technology         6.7500  1.386894e+09
# COCO           Consumer Defensive        27.1800  1.582351e+09
# CONCHATORO.SN  Consumer Defensive      1172.4000  8.625724e+11
# COUR           Consumer Defensive         7.6800  1.179426e+09
#
# Attribute      impliedSharesOutstanding
# Ticker
# BIO.AX                     1.953353e+08
# BIRD                       1.590092e+08
# CLSA3.SA                   2.054658e+08
# COCO                       5.821747e+07
# CONCHATORO.SN              7.357322e+08
# COUR                       1.535711e+08

# %%
#stock_data_filtered.to_csv("QC_mkt_cap.csv")

# %% [markdown]
# ## Add in stock price as of beginning of index:

# %%
def get_starting_price(df, start = s):
    tickers_list = df.index.tolist()
    tickers_data= {}
    first_object = yf.Ticker(tickers_list[0])
    
    prices = pd.DataFrame.from_dict(first_object.history(start=start, interval = "1d"))
    prices.drop(['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'], axis=1, inplace=True)
    prices.columns = [tickers_list[0]]

    
    for ticker in tickers_list[1:]:
        ticker_object = yf.Ticker(ticker)
        try:
            temp = pd.DataFrame.from_dict(ticker_object.history(start=start, interval = "1d"))
            temp.drop(['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'], axis=1, inplace=True)
            temp.columns = [ticker]
            prices = prices.merge(temp, how="outer", left_index=True, right_index=True)
        except:
            continue
    
    
    # Collapse date across international zones:
    prices.index = pd.to_datetime(prices.index).date
    #display(prices.head(20))
      
        
    prices = prices.groupby(prices.index).ffill() 
    prices = prices.groupby(prices.index).bfill()
    prices = prices.groupby(prices.index).last()
    
    
    return prices

# %%
def check_corporate_actions(df, start = s):
    tickers_list = df.index.tolist()
    tickers_data= {}
    first_object = yf.Ticker(tickers_list[0])
    
    info = pd.DataFrame.from_dict(first_object.history(start=start, interval = "1d"))
    info.drop(['Open', 'High', 'Low', 'Volume'], axis=1, inplace=True)
    info.columns = [tickers_list[0], str(tickers_list[0])+'_Dividends', str(tickers_list[0])+'_Stock Splits']

    
    for ticker in tickers_list[1:]:
        ticker_object = yf.Ticker(ticker)
        try:
            temp = pd.DataFrame.from_dict(ticker_object.history(start=start, interval = "1d"))
            temp.drop(['Open', 'High', 'Low', 'Volume'], axis=1, inplace=True)
            temp.columns = [ticker, str(ticker)+'_Dividends', str(ticker)+'_Stock Splits']
            info = info.merge(temp, how="outer", left_index=True, right_index=True)
        except:
            continue
    
    
    # Collapse date across international zones:
    info.index = pd.to_datetime(info.index).date
      
        
    info = info.groupby(info.index).ffill() 
    info = info.groupby(info.index).bfill()
    info = info.groupby(info.index).last()
    
    
    
    # Find and organize by corporate action
    
    cols = list(info.columns)
    div_cols = [i for i in cols if '_Dividends' in i]
    split_cols = [j for j in cols if '_Stock Splits' in j]
    
    div_dict = {}
    split_dict = {}
    
    for col in div_cols:
        if info[col].sum() > 0:
            div_dict[col] = info[col].sum()
     
    div_df = pd.DataFrame()
    
    if len(div_dict) > 0:
        print("Dividends Issued")
        for key in div_dict.keys():
            date = np.where(info[key] > 0)
            div_df = pd.concat([div_df, info.iloc[date]], axis=0)
        div_df.sort_index(axis=0, level=0, inplace=True)
        display(div_df)
        div_df.to_csv('Dividend_log.csv')
            
            #div_df[key] = info.loc[date]
            #display(div_df)
            
    else:
        print("No Dividends")
            
    for col in split_dict:
        if info[col].sum() > 0:
            split_dict[col] = info[col].sum()
    
    if len(split_dict) > 0:
        print("Split Happened")
    else:
        print("No Stock Splits")
       
    
    return info

# %%
data = get_starting_price(stock_data_filtered, start=s)
corp_actions = check_corporate_actions(stock_data_filtered, start=s)
starting_px = data.filter(like='2022-01-04', axis=0).T


#display(starting_px.head(20))
# Out:
# Dividends Issued
#               0973.HK  0973.HK_Dividends  0973.HK_Stock Splits    1112.HK  \
# 2022-01-18  29.695942                0.0                   0.0  10.995600
# 2022-01-20  30.277266                0.0                   0.0  11.396389
# 2022-02-14  27.564425                0.0                   0.0  11.326687
# 2022-02-16  27.515980                0.0                   0.0  11.744904
# 2022-03-01  24.512474                0.0                   0.0  10.263721
# ...               ...                ...                   ...        ...
# 2024-05-07  32.349998                0.0                   0.0  10.112087
# 2024-05-20             0.0                0.0
# 2024-05-21             0.0                0.0
#
# [112 rows x 162 columns]
# No Stock Splits

# %%
corp_actions.describe()
# Out:
#           0973.HK  0973.HK_Dividends  0973.HK_Stock Splits     1112.HK  \
# count  589.000000         589.000000                 589.0  589.000000
# mean    23.689198           0.001261                   0.0   10.104628
# std      3.750532           0.022661                   0.0    1.841674
# min     17.625654           0.000000                   0.0    6.152472
# 25%     20.721521           0.000000                   0.0    8.852995
# 50%     23.107611           0.000000                   0.0    9.994047
# 75%     25.384460           0.000000                   0.0   11.233466
# max     32.599998           0.487600                   0.0   16.406593
#
#        1112.HK_Dividends  1112.HK_Stock Splits     1346.HK  1346.HK_Dividends  \
# count         589.000000                 589.0  589.000000          589.00000
# mean            0.002411                   0.0    0.526362            0.00034
# std             0.027920                   0.0    0.239969            0.00457
# min             0.000000                   0.0    0.256409            0.00000
# 25%             0.000000                   0.0    0.297887            0.00000
# 50%             0.000000                   0.0    0.408652            0.00000
# 75%             0.000000                   0.0    0.778660            0.00000
# max             0.440000                   0.0    0.960000            0.08500
#
#        1346.HK_Stock Splits      1H2.SI  ...  WRBY_Stock Splits      XHS.MI  \
# count                 589.0  601.000000  ...              604.0  142.000000
# mean                    0.0    0.101369  ...                0.0    2.862137
# std                     0.0    0.021997  ...                0.0    0.098960
# min                     0.0    0.072000  ...                0.0    2.600000
# 25%                     0.0    0.088000  ...                0.0    2.838500
# 50%                     0.0    0.099000  ...                0.0    2.840000
# 75%                     0.0    0.104000  ...                0.0    2.915000
# max                     0.0    0.180000  ...                0.0    3.020000
#
#        XHS.MI_Dividends  XHS.MI_Stock Splits       XSG.L  XSG.L_Dividends  \
# count             142.0                142.0  605.000000            605.0
# mean                0.0                  0.0   19.224482              0.0
# std                 0.0                  0.0   28.820527              0.0
# min                 0.0                  0.0    1.300000              0.0
# 25%                 0.0                  0.0    3.100000              0.0
# 50%                 0.0                  0.0    4.050000              0.0
# 75%                 0.0                  0.0   30.186199              0.0
# max                 0.0                  0.0  111.783401              0.0
#
#        XSG.L_Stock Splits        ZVIA  ZVIA_Dividends  ZVIA_Stock Splits
# count               605.0  604.000000           604.0              604.0
# mean                  0.0    3.432381             0.0                0.0
# std                   0.0    1.731827             0.0                0.0
# min                   0.0    0.802000             0.0                0.0
# 25%                   0.0    2.077500             0.0                0.0
# 50%                   0.0    3.465000             0.0                0.0
# 75%                   0.0    4.320000             0.0                0.0
# max                   0.0   10.190000             0.0                0.0
#
# [8 rows x 162 columns]

# %% [markdown]
# ### Incorporate exchange rates to translate price and market cap into USD

# %%
# Get avaialable currencies
currency_dict = {}

url = "https://currency-conversion-and-exchange-rates.p.rapidapi.com/symbols"

headers = {}
try:
    with open('untitled.json') as file:
        headers = json.load(file)
        
except FileNotFoundError:
    print("Couldn't load credentials")

print("Running API 0")
response = requests.get(url, headers=headers)


api_data = response.json()
    
for symbol, curr in api_data['symbols'].items():
    currency_dict[symbol] = [curr, 0]
# Out:
# Running API 0

# %%
## Access Exchange Rates at Start of Measurement:
def get_rates(date):
    url = "https://currency-conversion-and-exchange-rates.p.rapidapi.com/" + str(date)

    querystring = {'base':'USD'}

    headers = {}
    try:
        with open('untitled.json') as file:
            headers = json.load(file)
    except FileNotFoundError:
        print("Couldn't load credentials")

    print("Running API 1")
    response = requests.get(url, headers=headers, params=querystring)

    return response.json()

# %%
## Combine date from exch_data with names / symbols in currency_dict:
exch_data = get_rates(date='2024-01-02')

for symbol, rate in exch_data['rates'].items():
    for key in currency_dict.keys():
        if symbol == key:
            currency_dict[key][1] = rate
# Out:
# Running API 1

# %%
currency_dict
# Out:
# {'ANG': ['Netherlands Antillean Guilder', 1.802754],
#  'SVC': ['Salvadoran Colón', 0],
#  'CAD': ['Canadian Dollar', 1.332265],
#  'XCD': ['East Caribbean Dollar', 2.70255],
#  'MVR': ['Maldivian Rufiyaa', 15.394981],
#  'HRK': ['Croatian Kuna', 6.98177],
#  'AUD': ['Australian Dollar', 1.478066],
#  'MWK': ['Malawian Kwacha', 1682.000329],
#  'XAG': ['Silver (troy ounce)', 0.042301],
#  'MAD': ['Moroccan Dirham', 9.929013],
#  'PHP': ['Philippine Peso', 55.580372],
#  'NAD': ['Namibian Dollar', 18.569884],
#  'GNF': ['Guinean Franc', 8600.000003],
#  'KES': ['Kenyan Shilling', 157.349704],
#  'MZN': ['Mozambican Metical', 63.24995],
#  'BTN': ['Bhutanese Ngultrum', 84.025935],
#  'MGA': ['Malagasy Ariary', 4589.99995],
#  'AZN': ['Azerbaijani Manat', 1.696139],
#  'XAU': ['Gold (troy ounce)', 0.000486],
#  'RON': ['Romanian Leu', 4.542902],
#  'CHF': ['Swiss Franc', 0.850195],
#  'EGP': ['Egyptian Pound', 30.925201],
#  'BSD': ['Bahamian Dollar', 1.000292],
#  'TWD': ['New Taiwan Dollar', 30.894018],
#  'GGP': ['Guernsey Pound', 0.786705],
#  'LVL': ['Latvian Lats', 0.60489],
#  'MMK': ['Myanma Kyat', 2100.602778],
#  'WST': ['Samoan Tala', 2.698297],
#  'ILS': ['Israeli New Sheqel', 3.639696],
#  'BHD': ['Bahraini Dinar', 0.376845],
#  'GBP': ['British Pound Sterling', 0.79224],
#  'TZS': ['Tanzanian Shilling', 2514.999877],
#  'SDG': ['South Sudanese Pound', 601.000196],
#  'LAK': ['Laotian Kip', 20562.465494],
#  'DJF': ['Djiboutian Franc', 177.719565],
#  'BYN': ['New Belarusian Ruble', 3.303209],
#  'LBP': ['Lebanese Pound', 15062.499188],
#  'RWF': ['Rwandan Franc', 1260.86],
#  'PEN': ['Peruvian Nuevo Sol', 3.713497],
#  'EUR': ['Euro', 0.91396],
#  'ZMK': ['Zambian Kwacha (pre-2013)', 9001.202091],
#  'RSD': ['Serbian Dinar', 107.091975],
#  'INR': ['Indian Rupee', 83.25725],
#  'MUR': ['Mauritian Rupee', 44.020085],
#  'BWP': ['Botswanan Pula', 13.364278],
#  'GEL': ['Georgian Lari', 2.680173],
#  'KMF': ['Comorian Franc', 450.513757],
#  'UZS': ['Uzbekistan Som', 12349.999723],
#  'RUB': ['Russian Ruble', 90.430359],
#  'CUC': ['Cuban Convertible Peso', 1],
#  'BGN': ['Bulgarian Lev', 1.787597],
#  'JOD': ['Jordanian Dinar', 0.709602],
#  'NGN': ['Nigerian Naira', 884.818945],
#  'BDT': ['Bangladeshi Taka', 109.786792],
#  'PKR': ['Pakistani Rupee', 281.950354],
#  'BRL': ['Brazilian Real', 4.923979],
#  'KZT': ['Kazakhstani Tenge', 455.620708],
#  'CVE': ['Cape Verdean Escudo', 100.149596],
#  'HNL': ['Honduran Lempira', 24.749457],
#  'NZD': ['New Zealand Dollar', 1.60014],
#  'ERN': ['Eritrean Nakfa', 15],
#  'NPR': ['Nepalese Rupee', 134.441314],
#  'ZMW': ['Zambian Kwacha', 25.731794],
#  'FKP': ['Falkland Islands Pound', 0.786705],
#  'DZD': ['Algerian Dinar', 134.679875],
#  'JMD': ['Jamaican Dollar', 154.316147],
#  'CRC': ['Costa Rican Colón', 519.788437],
#  'GMD': ['Gambian Dalasi', 67.225002],
#  'PLN': ['Polish Zloty', 3.991717],
#  'AMD': ['Armenian Dram', 404.880451],
#  'BMD': ['Bermudan Dollar', 1],
#  'BZD': ['Belize Dollar', 2.016378],
#  'BBD': ['Barbadian Dollar', 2.019734],
#  'SBD': ['Solomon Islands Dollar', 8.404697],
#  'IDR': ['Indonesian Rupiah', 15505],
#  'ALL': ['Albanian Lek', 94.18978],
#  'IQD': ['Iraqi Dinar', 1310],
#  'BIF': ['Burundian Franc', 2855],
#  'HKD': ['Hong Kong Dollar', 7.81532],
#  'GIP': ['Gibraltar Pound', 0.786705],
#  'BAM': ['Bosnia-Herzegovina Convertible Mark', 1.783545],
#  'LKR': ['Sri Lankan Rupee', 322.110562],
#  'QAR': ['Qatari Rial', 3.640497],
#  'SAR': ['Saudi Riyal', 3.750007],
#  'TOP': ['Tongan Paʻanga', 2.33115],
#  'SEK': ['Swedish Krona', 10.20999],
#  'ZAR': ['South African Rand', 18.56645],
#  'ARS': ['Argentine Peso', 810.561155],
#  'MYR': ['Malaysian Ringgit', 4.603498],
#  'BYR': ['Belarusian Ruble', 19600],
#  'KPW': ['North Korean Won', 900.008743],
#  'CZK': ['Czech Republic Koruna', 22.543297],
#  'STD': ['São Tomé and Príncipe Dobra', 20697.981008],
#  'BTC': ['Bitcoin', 2.2239327e-05],
#  'ZWL': ['Zimbabwean Dollar', 321.999592],
#  'LSL': ['Lesotho Loti', 18.570097],
#  'COP': ['Colombian Peso', 3889.23],
#  'PAB': ['Panamanian Balboa', 1.000301],
#  'IRR': ['Iranian Rial', 42047.496316],
#  'CNH': ['Chinese Yuan Offshore', 0],
#  'NOK': ['Norwegian Krone', 10.349175],
#  'XPF': ['CFP Franc', 109.374992],
#  'XOF': ['CFA Franc BCEAO', 594.504833],
#  'XDR': ['Special Drawing Rights', 0.745598],
#  'OMR': ['Omani Rial', 0.384895],
#  'CNY': ['Chinese Yuan', 7.099602],
#  'NIO': ['Nicaraguan Córdoba', 36.720003],
#  'AOA': ['Angolan Kwanza', 832.497707],
#  'SCR': ['Seychellois Rupee', 14.197264],
#  'MOP': ['Macanese Pataca', 8.050829],
#  'ISK': ['Icelandic Króna', 137.709983],
#  'VND': ['Vietnamese Dong', 24335],
#  'VES': ['Sovereign Bolivar', 35.822194],
#  'USD': ['United States Dollar', 1],
#  'UYU': ['Uruguayan Peso', 39.075858],
#  'VEF': ['Venezuelan Bolívar Fuerte', 3587972.932726],
#  'MRU': ['Mauritanian Ouguiya', 39.649989],
#  'UGX': ['Ugandan Shilling', 3789.053238],
#  'DOP': ['Dominican Peso', 57.919916],
#  'UAH': ['Ukrainian Hryvnia', 38.150158],
#  'BOB': ['Bolivian Boliviano', 6.912148],
#  'TTD': ['Trinidad and Tobago Dollar', 6.789167],
#  'KGS': ['Kyrgystani Som', 89.085304],
#  'TND': ['Tunisian Dinar', 3.093498],
#  'SGD': ['Singapore Dollar', 1.326405],
#  'TMT': ['Turkmenistani Manat', 3.51],
#  'GHS': ['Ghanaian Cedi', 11.949598],
#  'TJS': ['Tajikistani Somoni', 10.948303],
#  'KHR': ['Cambodian Riel', 4090.000036],
#  'ETB': ['Ethiopian Birr', 56.195264],
#  'PGK': ['Papua New Guinean Kina', 3.70803],
#  'THB': ['Thai Baht', 34.263001],
#  'AED': ['United Arab Emirates Dirham', 3.672796],
#  'GTQ': ['Guatemalan Quetzal', 7.825096],
#  'LRD': ['Liberian Dollar', 188.494157],
#  'SYP': ['Syrian Pound', 13001.797058],
#  'KYD': ['Cayman Islands Dollar', 0.833615],
#  'SRD': ['Surinamese Dollar', 36.745499],
#  'HTG': ['Haitian Gourde', 131.911323],
#  'LYD': ['Libyan Dinar', 4.775014],
#  'SLL': ['Sierra Leonean Leone', 19749.999899],
#  'SLE': ['Sierra Leonean Leone', 22.795066],
#  'SHP': ['Saint Helena Pound', 1.262304],
#  'IMP': ['Manx pound', 0.786705],
#  'FJD': ['Fijian Dollar', 2.228702],
#  'PYG': ['Paraguayan Guarani', 7287.202028],
#  'KRW': ['South Korean Won', 1308.849868],
#  'SZL': ['Swazi Lilangeni', 18.570217],
#  'GYD': ['Guyanaese Dollar', 209.270303],
#  'MDL': ['Moldovan Leu', 17.464573],
#  'MXN': ['Mexican Peso', 17.034397],
#  'CLP': ['Chilean Peso', 884.320491],
#  'LTL': ['Lithuanian Litas', 2.95274],
#  'SOS': ['Somali Shilling', 570.999787],
#  'MNT': ['Mongolian Tugrik', 3439.712623],
#  'AFN': ['Afghan Afghani', 69.999838],
#  'CUP': ['Cuban Peso', 26.5],
#  'CLF': ['Chilean Unit of Account (UF)', 0.032049],
#  'JPY': ['Japanese Yen', 142.156502],
#  'TRY': ['Turkish Lira', 29.753575],
#  'YER': ['Yemeni Rial', 250.250298],
#  'HUF': ['Hungarian Forint', 348.829813],
#  'BND': ['Brunei Dollar', 1.325497],
#  'JEP': ['Jersey Pound', 0.786705],
#  'MKD': ['Macedonian Denar', 56.219156],
#  'AWG': ['Aruban Florin', 1.8025],
#  'CDF': ['Congolese Franc', 2680.000256],
#  'VUV': ['Vanuatu Vatu', 117.373873],
#  'XAF': ['CFA Franc BEAC', 598.184355],
#  'KWD': ['Kuwaiti Dinar', 0.30748],
#  'DKK': ['Danish Krone', 6.81438]}

# %%
## Add exhange rates and calculate USD equivalents:

#exchange_map = {exchanges: extention
#                 for exchanges, extention in exchange_dict.items()
#                 for exchange in exchanges}


currency_map = {symbols: rate
                 for symbols, name in currency_dict.items()
                 for rate in name}



stock_data_filtered['beginningUSDExchangeRate'] = stock_data_filtered['currency'].map(currency_map)

# %%
stock_data_filtered = stock_data_filtered.join(starting_px)

# %%
# Check to see that exchange rates mapped correctly:
stock_data_filtered.head(15)
# Out:
#                             shortName        country currency  \
# Ticker
# 0973.HK                    L'OCCITANE     Luxembourg      HKD
# 1112.HK                 H&H INTL HLDG      Hong Kong      HKD
# 1346.HK                   LEVER STYLE      Hong Kong      HKD
# 1H2.SI                   $ Olive Tree      Singapore      SGD
# 2897.TW                 O-BANK CO LTD         Taiwan      TWD
# 6088.T          SIGMAXYZ HOLDINGS INC          Japan      JPY
# ABB.AX           AUSSIEBAND FPO [ABB]      Australia      AUD
# AEF.AX            A ETHICAL FPO [AEF]      Australia      AUD
# ALQP.PA                      QUADPACK          Spain      EUR
# AMAL      Amalgamated Financial Corp.  United States      USD
# ARZZ3.SA       AREZZO CO   ON      NM         Brazil      BRL
# BFT.WA                        BENEFIT         Poland      PLN
# BIO.AX           BIOME AUST FPO [BIO]      Australia      AUD
# BIRD                   Allbirds, Inc.  United States      USD
# CLSA3.SA       CLEARSALE   ON      NM         Brazil      BRL
#
#                                industry firstTradeDateEpochUtc  \
# Ticker
# 0973.HK   Household & Personal Products             1273195800
# 1112.HK                  Packaged Foods             1292549400
# 1346.HK           Apparel Manufacturing             1573608600
# 1H2.SI        Real Estate - Diversified              946861200
# 2897.TW                Banks - Regional             1199062800
# 6088.T      Specialty Business Services             1387324800
# ABB.AX                 Telecom Services             1602802800
# AEF.AX                 Asset Management             1039993200
# ALQP.PA          Packaging & Containers             1461135600
# AMAL                   Banks - Regional             1533821400
# ARZZ3.SA         Footwear & Accessories             1296648000
# BFT.WA                          Leisure             1303801200
# BIO.AX                   Packaged Foods             1638226800
# BIRD                     Apparel Retail             1635946200
# CLSA3.SA      Software - Infrastructure             1627909200
#
#                           sector  previousClose     marketCap  \
# Ticker
# 0973.HK       Consumer Defensive        32.0500  4.762470e+10
# 1112.HK       Consumer Defensive        10.4000  6.713834e+09
# 1346.HK        Consumer Cyclical         0.9400  6.135360e+08
# 1H2.SI               Real Estate         0.0840  9.730980e+06
# 2897.TW       Financial Services        10.4500  2.835092e+10
# 6088.T               Industrials      1342.0000  5.875585e+10
# ABB.AX    Communication Services         3.3900  9.899853e+08
# AEF.AX        Financial Services         4.5600  5.131581e+08
# ALQP.PA        Consumer Cyclical        13.8000  6.060233e+07
# AMAL          Financial Services        25.0200  7.714941e+08
# ARZZ3.SA       Consumer Cyclical        50.9900  5.567873e+09
# BFT.WA         Consumer Cyclical      2935.0000  8.431127e+09
# BIO.AX        Consumer Defensive         0.3650  7.129738e+07
# BIRD           Consumer Cyclical         0.5757  9.154159e+07
# CLSA3.SA              Technology         6.7500  1.386894e+09
#
#           impliedSharesOutstanding  beginningUSDExchangeRate   2022-01-04
# Ticker
# 0973.HK               1.485950e+09                  7.815320    31.003922
# 1112.HK               6.455610e+08                  7.815320    10.455404
# 1346.HK               6.526979e+08                  7.815320     0.305428
# 1H2.SI                1.158450e+08                  1.326405     0.110000
# 2897.TW               2.713007e+09                 30.894018     7.403813
# 6088.T                4.378230e+07                142.156502  1166.818604
# ABB.AX                2.920311e+08                  1.478066     4.600000
# AEF.AX                1.125347e+08                  1.478066    13.177148
# ALQP.PA               4.391473e+06                  0.913960    23.799999
# AMAL                  3.083510e+07                  1.000000    16.207987
# ARZZ3.SA              1.091954e+08                  4.923979    66.436813
# BFT.WA                2.872616e+06                  3.991717   629.166260
# BIO.AX                1.953353e+08                  1.478066     0.120000
# BIRD                  1.590092e+08                  1.000000    15.590000
# CLSA3.SA              2.054658e+08                  4.923979     8.970000

# %%
# Calculate USD price and USD marketcap
s_d = dt.strptime(s, '%Y-%M-%d').date()
stock_data_filtered['beginningCloseUSD'] = (stock_data_filtered[s_d] / stock_data_filtered['beginningUSDExchangeRate']).astype(float)


stock_data_filtered['beginningMarketCapUSD'] = stock_data_filtered['impliedSharesOutstanding']* stock_data_filtered['beginningCloseUSD']


display(stock_data_filtered.head(30))
# Out:
#                                      shortName        country currency  \
# Ticker
# 0973.HK                             L'OCCITANE     Luxembourg      HKD
# 1112.HK                          H&H INTL HLDG      Hong Kong      HKD
# 1346.HK                            LEVER STYLE      Hong Kong      HKD
# 1H2.SI                            $ Olive Tree      Singapore      SGD
# 2897.TW                          O-BANK CO LTD         Taiwan      TWD
# 6088.T                   SIGMAXYZ HOLDINGS INC          Japan      JPY
# ABB.AX                    AUSSIEBAND FPO [ABB]      Australia      AUD
# AEF.AX                     A ETHICAL FPO [AEF]      Australia      AUD
# ALQP.PA                               QUADPACK          Spain      EUR
# AMAL               Amalgamated Financial Corp.  United States      USD
# ARZZ3.SA                AREZZO CO   ON      NM         Brazil      BRL
# BFT.WA                                 BENEFIT         Poland      PLN
# BIO.AX                    BIOME AUST FPO [BIO]      Australia      AUD
# BIRD                            Allbirds, Inc.  United States      USD
# CLSA3.SA                CLEARSALE   ON      NM         Brazil      BRL
# COCO               The Vita Coco Company, Inc.  United States      USD
# CONCHATORO.SN               VINA CONCHA Y TORO          Chile      CLP
# COUR                            Coursera, Inc.  United States      USD
# CVT.NZ         Comvita Limited Ordinary Shares    New Zealand      NZD
# CWEB.TO            CHARLOTTES WEB HOLDINGS INC  United States      CAD
# DOX.MI                                   DOXEE          Italy      EUR
# FLOW.TO                     FLOW BEVERAGE CORP         Canada      CAD
# FREY.PA                                   FREY         France      EUR
# GFI.NZ         Greenfern Industries Limited Or    New Zealand      NZD
# GROV           Grove Collaborative Holdings, I  United States      USD
# HAN.MC                            HANNUN, S.A.          Spain      EUR
# INCLU.BR                       0.913960    16.603733          18.166805
#
#                beginningMarketCapUSD
# Ticker
# 0973.HK                 5.894867e+09
# 1112.HK                 8.636372e+08
# 1346.HK                 2.550790e+07
# 1H2.SI                  9.607134e+06
# 2897.TW                 6.501774e+08
# 6088.T                  3.593645e+08
# ABB.AX                  9.088518e+08
# AEF.AX                  1.003261e+09
# ALQP.PA                 1.143563e+08
# AMAL                    4.997748e+08
# ARZZ3.SA                1.473319e+09
# BFT.WA                  4.527758e+08
# BIO.AX                  1.585872e+07
# BIRD                    2.478953e+09
# CLSA3.SA                3.742965e+08
# COCO                    6.986096e+08
# CONCHATORO.SN           9.899831e+08
# COUR                    3.839278e+09
# CVT.NZ                  1.258935e+08
# CWEB.TO                 1.539501e+08
# DOX.MI                  1.186891e+08
# FLOW.TO                 9.166311e+07
# FREY.PA                 9.355612e+08
# GFI.NZ                  1.437037e+07
# GROV                    1.935900e+09
# HAN.MC                           NaN
# HLZ.MC                  3.199772e+08
# HMGS.TA                          NaN
# IBAB.BR                 4.698612e+08
# INCLU.BR                1.347721e+08

# %%
if download:
    stock_data_filtered.to_csv("mkt_cap_details.csv")

# %% [markdown]
# ## Filter Universe of Stocks by USD MarketCap

# %%
def filter_index(df, size=True, num=True, size_thresh = 1000000000, num_thresh = 20, history = False, start = s, col='beginningMarketCapUSD'):
    temp = df.copy()
     
    temp['firstTradeDateEpochUtc'] = pd.to_datetime(temp['firstTradeDateEpochUtc'],unit='s')
    temp['firstTradeDateEpochUtc'] = pd.to_datetime(temp['firstTradeDateEpochUtc'],format ='%Y-%m-%d')
    d1 = dt.strptime(start, '%Y-%m-%d')
    temp['trading_history'] = (d1 - temp['firstTradeDateEpochUtc']).dt.days

    if size == True:
        temp = temp[temp[col] >= size_thresh]
    
    if history == True:
        temp = temp[temp['trading_history'] >= 365]
        
    if num == True:
        temp.sort_values(by=[col], ascending=False, inplace = True)
        temp = temp.iloc[0:num_thresh,:]
            
    if 'ABI.BR' in temp.index:
        temp.loc['ABI.BR','impliedSharesOutstanding'] = 1982790000
    
    #display(temp.head())
    return temp

# %%
stock_index_top20 = filter_index(stock_data_filtered, size = False, history = True, num_thresh=20)
stock_index_top30 = filter_index(stock_data_filtered, size = False, num_thresh=30)
stock_index_over1b = filter_index(stock_data_filtered, size = True, num=False, size_thresh=1000000000)
stock_index_cutoff = filter_index(stock_data_filtered, size = False, num_thresh=40)

df_list = [stock_index_top20, stock_index_top30, stock_index_over1b, stock_index_cutoff]

print(stock_index_top20.shape, stock_index_top30.shape, stock_index_over1b.shape, stock_index_cutoff.shape)
# Out:
# (20, 14) (30, 14) (11, 14) (40, 14)

# %% [markdown]
# # Construct Index as of Start Date

# %%
stock_data_filtered.shape
# Out:
# (54, 13)

# %%
# QC Market Cap cutoffs:
#stock_data_filtered.to_csv('Initial_MCs.csv')

# %%
stock_index_top20
# Out:
#                                      shortName        country currency  \
# Ticker
# NTCO3.SA                GRUPO NATURAON      NM         Brazil      BRL
# 0973.HK                             L'OCCITANE     Luxembourg      HKD
# SML.NZ                    3087
# IBAB.BR                   8035
# BFT.WA                    3905

# %% [markdown]
# ## Manual Adjustments (if needed)
# ### Adjust Methodology Here:

# %%
for df in df_list:
    if 'MLMFI.PA' in df.index:
        df.drop('MLMFI.PA', axis=0, inplace=True)
        
        
'''
    
    ## Eliminate if market cap < 100M:
    
    if '1346.HK' in df.index:
        df.drop('1346.HK', axis=0, inplace=True)
    if 'BIO.AX' in df.index:
        df.drop('BIO.AX', axis=0, inplace=True)
    if 'RETI.MI' in df.index:
        df.drop('RETI.MI', axis=0, inplace=True)
        
    ## Eliminate if price < $1.00:
   
    if '2897.TW' in df.index:
        df.drop('2897.TW', axis=0, inplace=True)
    if 'KMD.NZ' in df.index:
        df.drop('KMD.NZ', axis=0, inplace=True)
    if 'VHT.AX' in df.index:
        df.drop('VHT.AX', axis=0, inplace=True)    
'''
# Out:
# "\n    \n    ## Eliminate if market cap < 100M:\n    \n    if '1346.HK' in df.index:\n        df.drop('1346.HK', axis=0, inplace=True)\n    if 'BIO.AX' in df.index:\n        df.drop('BIO.AX', axis=0, inplace=True)\n    if 'RETI.MI' in df.index:\n        df.drop('RETI.MI', axis=0, inplace=True)\n        \n    ## Eliminate if price < $1.00:\n   \n    if '2897.TW' in df.index:\n        df.drop('2897.TW', axis=0, inplace=True)\n    if 'KMD.NZ' in df.index:\n        df.drop('KMD.NZ', axis=0, inplace=True)\n    if 'VHT.AX' in df.index:\n        df.drop('VHT.AX', axis=0, inplace=True)    \n"

# %%
stock_index_top20.shape
# Out:
# (20, 14)

# %%
assert stock_index_top20.shape[0] == 20
assert stock_index_top30.shape[0] == 30

# %% [markdown]
# # DECISION:
# # Set Index and Get Price History

# %%
stock_index = stock_index_top20.copy()
start_date = s

#### CHANGED THIS LINE FROM

#   end_date = '2022-12-31' to:
end_date = e

# %%
def get_price_history (df, start = start_date, end=end_date):
    tickers_list = df.index.tolist()
    tickers_data= {}
    first_object = yf.Ticker(tickers_list[0])
    
    prices = pd.DataFrame.from_dict(first_object.history(start=start, end=end, interval = "1d"))
    prices.drop(['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'], axis=1, inplace=True)
    prices.columns = [tickers_list[0]]

    
    for ticker in tickers_list[1:]:
        ticker_object = yf.Ticker(ticker)
        try:
            temp = pd.DataFrame.from_dict(ticker_object.history(start=start, end=end, interval = "1d"))
            temp.drop(['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'], axis=1, inplace=True)
            temp.columns = [ticker]
            prices = prices.merge(temp, how="outer", left_index=True, right_index=True)
        except:
            continue
    
    
    # Collapse date across international zones:
    prices.index = pd.to_datetime(prices.index).date
      
    prices = prices.groupby(prices.index).ffill() 
    prices = prices.groupby(prices.index).bfill()
    prices = prices.groupby(prices.index).last()
    
    
    return prices

# %%
price_history_df = get_price_history (stock_index)
price_history_df.index = pd.to_datetime(price_history_df.index)

stock_universe = list(price_history_df.columns)
print ("Number of stocks", len(stock_universe))
# Out:
# Number of stocks 20

# %%
def get_country_info(price_df, info_df):
    tickers_list = price_df.columns
    
    #access currency, impliedSharesOutstanding (local currency): ## HAVE TO REVIEW FOR STOCK CHANGES
    currencies = []
    implied_SO = []
    for col in price_df.columns:
        idx = np.where(info_df.index == col)
        currencies.append(info_df.iloc[idx]['currency'].values[0])
        implied_SO.append(info_df.iloc[idx]['impliedSharesOutstanding'].values[0])
        
    for i in range(len(price_df.columns)):
        col = price_df.columns[i]
        price_df[col+'_currency'] = currencies[i]
        price_df[col+'_SO'] = implied_SO[i]
    
    return price_df, currencies

# %%
price_and_info_df, index_currencies = get_country_info(price_history_df, stock_index)
display(price_and_info_df.head())
display(price_and_info_df.tail())
#######price_and_info_df = price_and_info_df.loc[DATE RANGE]
# Out:
#              NTCO3.SA    0973.HK       LMND   SOMA3.SA   ARZZ3.SA  MME.AX  \
# 2022-01-03        NaN  31.100807        NaN        NaN        NaN    2.12
# 2022-01-04  23.117048  31.003922  39.029999  11.305203  66.436813    2.12
# 2022-01-05  22.048494  30.907034  36.790001  10.226650  63.242928    2.10
# 2022-01-06  21.800436  31.439913  35.330002  10.540411  64.399170    2.07
# 2022-01-07  21.094427        NaN  37.139999  10.295285  63.887394     NaN
#
#                AEF.AX  CONCHATORO.SN   MOVI3.SA    FREY.PA  ...  \
# 2022-01-03  13.060879            NaN        NaN  27.812683  ...
# 2022-01-04  13.177150    1189.919678  13.564058  27.316029  ...
# 2022-01-05  12.382644    1220.491455  12.642315  27.316029  ...
# 2022-01-06  12.266376    1235.685791  12.597132  27.316029  ...
# 2022-01-07        NaN    1226.532715  12.353142        NaN  ...
#
#             KMD.NZ_currency     KMD.NZ_SO  AMAL_currency      AMAL_SO  \
# 2022-01-03              NZD  7.032944e+08            USD  30835095.12
# 2022-01-04              NZD  7.032944e+08            USD  30835095.12
# 2022-01-05              NZD  7.032944e+08            USD  30835095.12
# 2022-01-06              NZD  7.032944e+08            USD  30835095.12
# 2022-01-07              NZD  7.032944e+08            USD  30835095.12
#
#             SML.NZ_currency     SML.NZ_SO  IBAB.BR_currency   IBAB.BR_SO  \
# 2022-01-03              NZD  2.284059e+08               EUR  29456594.41
# 2022-01-04              NZD  2.284059e+08               EUR  29456594.41
# 2022-01-05              NZD  2.284059e+08               EUR  29456594.41
# 2022-01-06              NZD  2.284059e+08               EUR  29456594.41
# 2022-01-07              NZD  2.284059e+08               EUR  29456594.41
#
#             BFT.WA_currency   BFT.WA_SO
# 2022-01-03              PLN  2872615.51
# 2022-01-04              PLN  2872615.51
# 2022-01-05              PLN  2872615.51
# 2022-01-06              PLN  2872615.51
# 2022-01-07              PLN  2872615.51
#
# [5 rows x 60 columns]
#             NTCO3.SA    0973.HK       LMND  SOMA3.SA   ARZZ3.SA  MME.AX  \
# 2024-05-24     15.44        NaN  16.309999      6.07  50.959999     NaN
# 2024-05-26       NaN  31.850000        NaN       NaN        NaN   0.062
# 2024-05-27     15.28  31.850000        NaN      6.03  50.970001   0.065
# 2024-05-28     14.83  32.049999  16.450001      6.06  50.990002   0.069
# 2024-05-29     14.75        NaN  16.580000      5.93  50.180000     NaN
#
#             AEF.AX  CONCHATORO.SN  MOVI3.SA    FREY.PA  ...  KMD.NZ_currency  \
# 2024-05-24     NaN    1200.699951      6.45        NaN  ...              NZD
# 2024-05-26    4.70            NaN       NaN  28.799999  ...              NZD
# 2024-05-27    4.75    1199.300049      6.46  29.000000  ...              NZD
# 2024-05-28    4.56    1190.000000      6.65  29.000000  ...              NZD
# 2024-05-29     NaN    1172.400024      6.54        NaN  ...              NZD
#
#                KMD.NZ_SO  AMAL_currency      AMAL_SO  SML.NZ_currency  \
# 2024-05-24  7.032944e+08            USD  30835095.12              NZD
# 2024-05-26  7.032944e+08            USD  30835095.12              NZD
# 2024-05-27  7.032944e+08            USD  30835095.12              NZD
# 2024-05-28  7.032944e+08            USD  30835095.12              NZD
# 2024-05-29  7.032944e+08            USD  30835095.12              NZD
#
#                SML.NZ_SO  IBAB.BR_currency   IBAB.BR_SO  BFT.WA_currency  \
# 2024-05-24  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-26  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-27  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-28  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-29  2.284059e+08               EUR  29456594.41              PLN
#
#              BFT.WA_SO
# 2024-05-24  2872615.51
# 2024-05-26  2872615.51
# 2024-05-27  2872615.51
# 2024-05-28  2872615.51
# 2024-05-29  2872615.51
#
# [5 rows x 60 columns]

# %% [markdown]
# ### Get historical exchange rates

# %%
def load_historical_exchange ():
    daily_rates_df = pd.read_csv("updated_rates_05_20_24.csv")
    daily_rates_df.set_index("Date", inplace=True)
    daily_rates_df.index = pd.to_datetime(daily_rates_df.index).date
    return daily_rates_df

# %%
def get_historical_exchange (price_df, currencies):
    print("Price_df")
    print(price_df.index[0], type(price_df.index[0]))
    display(price_df.tail())
    print("Currencies")
    print(currencies)
    #currencies = list(set(currencies))
    
    querystring = {"base":"USD"}

    headers = {}
    try:
        with open('code.json') as file:
            headers = json.load(file)
    except FileNotFoundError:
        print("Couldn't load credentials")
    
    daily_rate_df = pd.DataFrame()
    
    for idx in price_df.index:
        try:
            loc = np.where(price_df.index == str(idx.date()))
            url = "https://currency-conversion-and-exchange-rates.p.rapidapi.com/" + str(idx.date())
            response = requests.get(url, headers=headers, params=querystring)
            response = response.json()
        except:
            loc = np.where(price_df.index == str(idx))
            url = "https://currency-conversion-and-exchange-rates.p.rapidapi.com/" + str(idx)
            response = requests.get(url, headers=headers, params=querystring)
            response = response.json()
        
        daily_df = pd.DataFrame(response)

        daily_df = daily_df[['date', 'rates']].reset_index()
        daily_df = daily_df.pivot(columns='index', index='date', values='rates')

        daily_rate_df = pd.concat([daily_rate_df, daily_df], axis=0)

        
    daily_rate_df.index = pd.to_datetime(daily_rate_df.index).date
    return daily_rate_df

# %% [markdown]
# # Decision:
# Upload stored data on exchange rates then update to current

# %%
display(price_and_info_df.head())
display(price_and_info_df.tail())
# Out:
# 2024-05-28  7.032944e+08            USD  30835095.12              NZD
# 2024-05-29  7.032944e+08            USD  30835095.12              NZD
#
#                SML.NZ_SO  IBAB.BR_currency   IBAB.BR_SO  BFT.WA_currency  \
# 2024-05-24  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-26  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-27  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-28  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-29  2.284059e+08               EUR  29456594.41              PLN
#
#              BFT.WA_SO
# 2024-05-24  2872615.51
# 2024-05-26  2872615.51
# 2024-05-27  2872615.51
# 2024-05-28  2872615.51
# 2024-05-29  2872615.51
#
# [5 rows x 60 columns]

# %%
run_api = False

# %%
# Load stored rates:
def load_rates():
    print("Running load_rates")
    daily_rates_df = load_historical_exchange()
       
    last_date = daily_rates_df.index[-1]
    next_date = last_date+timedelta(days=1)
    
    new_dates_df = price_and_info_df.loc[next_date:dt.today()]
    
    df2 = get_historical_exchange(new_dates_df, index_currencies)
    
    daily_rates_df = pd.concat([daily_rates_df,df2],join='inner')
    
    #display(daily_rates_df.head())
    #display(daily_rates_df.tail(30))
    
    return daily_rates_df, last_date

# %%
df_dates, ed = load_rates()

currency_start = ed+timedelta(days=1)
currency_end = e
# Out:
# Running load_rates
# Price_df
# 2024-05-19 00:00:00 <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#             NTCO3.SA    0973.HK       LMND  SOMA3.SA   ARZZ3.SA  MME.AX  \
# 2024-05-24     15.44        NaN  16.309999      6.07  50.959999     NaN
# 2024-05-26       NaN  31.850000        NaN       NaN        NaN   0.062
# 2024-05-27     15.28  31.850000        NaN      6.03  50.970001   0.065
# 2024-05-28     14.83  32.049999  16.450001      6.06  50.990002   0.069
# 2024-05-29     14.75        NaN  16.580000      5.93  50.180000     NaN
#
#             AEF.AX  CONCHATORO.SN  MOVI3.SA    FREY.PA  ...  KMD.NZ_currency  \
# 2024-05-24     NaN    1200.699951      6.45        NaN  ...              NZD
# 2024-05-26    4.70            NaN       NaN  28.799999  ...              NZD
# 2024-05-27    4.75    1199.300049      6.46  29.000000  ...              NZD
# 2024-05-28    4.56    1190.000000      6.65  29.000000  ...              NZD
# 2024-05-29     NaN    1172.400024      6.54        NaN  ...              NZD
#
#                KMD.NZ_SO  AMAL_currency      AMAL_SO  SML.NZ_currency  \
# 2024-05-24  7.032944e+08            USD  30835095.12              NZD
# 2024-05-26  7.032944e+08            USD  30835095.12              NZD
# 2024-05-27  7.032944e+08            USD  30835095.12              NZD
# 2024-05-28  7.032944e+08            USD  30835095.12              NZD
# 2024-05-29  7.032944e+08            USD  30835095.12              NZD
#
#                SML.NZ_SO  IBAB.BR_currency   IBAB.BR_SO  BFT.WA_currency  \
# 2024-05-24  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-26  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-27  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-28  2.284059e+08               EUR  29456594.41              PLN
# 2024-05-29  2.284059e+08               EUR  29456594.41              PLN
#
#              BFT.WA_SO
# 2024-05-24  2872615.51
# 2024-05-26  2872615.51
# 2024-05-27  2872615.51
# 2024-05-28  2872615.51
# 2024-05-29  2872615.51
#
# [5 rows x 60 columns]
# Currencies
# ['BRL', 'HKD', 'USD', 'BRL', 'BRL', 'AUD', 'AUD', 'CLP', 'BRL', 'EUR', 'AUD', 'AUD', 'HKD', 'USD', 'TWD', 'NZD', 'USD', 'NZD', 'EUR', 'PLN']

# %%
#hist_currency_df = df_dates.copy()
#hist_currency_df = df_dates.loc[currency_start:,:]
#display(hist_currency_df.head())

#get_historical_exchange(hist_currency_df, index_currencies)

# %%
import warnings
warnings.filterwarnings("ignore")

if run_api:
    # adjust dates to only get currency data after stored file
    hist_currency_df = price_and_info_df.copy()
    hist_currency_df = hist_currency_df.loc[currency_start:,:]
    display(hist_currency_df.head())
    
    daily_rates_df = get_historical_exchange(hist_currency_df, index_currencies)
    display(daily_rates_df.head())
    display(daily_rates_df.tail())
    daily_rates_df.to_csv(filename)

else:
    daily_rates_df = df_dates.copy()

# %%
daily_rates_df.head()
# Out:
#                  AED         AFN         ALL         AMD       ANG  \
# 2022-01-02  3.672980  103.749983  106.650326  480.234325  1.802591
# 2022-01-03  3.673103  103.750299  106.249880  481.590005  1.802973
# 2022-01-04  3.673096  104.899369  105.874950  482.301630  1.801500
# 2022-01-05  3.673102  105.250158  106.902530  483.164239  1.802797
# 2022-01-06  3.673102  104.999962  107.350118  483.038449  1.802366
#
#                    AOA         ARS       AUD     AWG       AZN  ...       XAU  \
# 2022-01-02  550.590435  102.664691  1.376179  1.8000  1.698647  ...  0.000547
# 2022-01-03  554.203977  102.958502  1.389502  1.8005  1.701522  ...  0.000554
# 2022-01-04  553.427992  103.104100  1.381105  1.8000  1.698131  ...  0.000551
# 2022-01-05  552.652983  103.102801  1.384754  1.8005  1.691373  ...  0.000552
# 2022-01-06  551.700853  103.228600  1.395982  1.8000  1.700773  ...  0.000558
#
#                 XCD       XDR         XOF         XPF         YER        ZAR  \
# 2022-01-02  2.70255  0.714652  579.499504  105.850128  250.249584  15.964896
# 2022-01-03  2.70255  0.714795  578.495079  106.250557  250.250269  15.874497
# 2022-01-04  2.70255  0.713539  580.492727  106.125034  250.249886  16.037760
# 2022-01-05  2.70255  0.716268  579.501261  105.550109  250.249682  15.893898
# 2022-01-06  2.70255  0.714658  580.493234  105.879870  249.999702  15.721510
#
#                     ZMK        ZMW         ZWL
# 2022-01-02  9001.202654  16.663427  321.999592
# 2022-01-03  9001.202677  16.674184  321.999592
# 2022-01-04  9001.200930  16.718437  321.999592
# 2022-01-05  9001.187415  16.770433  321.999592
# 2022-01-06  9001.191881  16.776058  321.999592
#
# [5 rows x 167 columns]

# %%
daily_price_and_info_df = price_and_info_df.join(daily_rates_df)
display(daily_price_and_info_df.head())
display(daily_price_and_info_df.tail())
# Out:
#              NTCO3.SA    0973.HK       LMND   SOMA3.SA   ARZZ3.SA  MME.AX  \
# 2024-05-27  9001.212449  26.775604  321.999592
# 2024-05-28  9001.201651  26.976744  321.999592
# 2024-05-29  9001.201691  27.202924  321.999592
#
# [5 rows x 227 columns]

# %%
def convert_price_mktcap_USD (px_info_df, stock_list):
    
    for stock in stock_list:
        col_name = stock+"_currency"
        col2_name = stock+"_SO"
        curr = px_info_df[col_name][0]
        shares_out = px_info_df[col2_name][0]
        new_col = stock + "_px_USD"
        new_col2 = stock + "_MktCap_USD"
        px_info_df[new_col] = px_info_df[stock] / px_info_df[curr]
        px_info_df[new_col2] = px_info_df[new_col] * shares_out
    
    return px_info_df

# %%
daily_price_MC_usd_all = convert_price_mktcap_USD(daily_price_and_info_df, stock_universe)

# %%
#if download:
#    daily_price_MC_usd_all.to_csv('price_MC_USD.csv')
display(daily_price_MC_usd_all.head())
display(daily_price_MC_usd_all.tail())
# Out:
#              NTCO3.SA    0973.HK       LMND   SOMA3.SA   ARZZ3.SA  MME.AX  \
# 2022-01-03        NaN  31.100807        NaN        NaN        NaN    2.12
# 2022-01-04  23.117048  31.003922  39.029999  11.305203  66.436813    2.12
# 2022-01-05  22.048494  30.907034  36.790001  10.226650  63.242928    2.10
# 2022-01-06  21.800436  31.439913  35.330002  10.540411  64.399170    2.07
# 2022-01-07  21.094427        NaN  37.139999  10.295285  63.887394     NaN
#
#                AEF.AX  CONCHATORO.SN   MOVI3.SA    FREY.PA  ...  \
# 2022-01-03  13.060879            NaN        NaN  27.812683  ...
# 2022-01-04  13.177150    1189.919678  13.564058  27.316029  ...
# 2022-01-05  12.382644    1220.491455  12.642315  27.316029  ...
# 2022-01-06  12.266376    1235.685791  12.597132  27.316029  ...
# 2022-01-07        NaN    1226.532715  12.353142        NaN  ...
#
#             KMD.NZ_px_USD  KMD.NZ_MktCap_USD  AMAL_px_USD  AMAL_MktCap_USD  \
# 2022-01-03            NaN                NaN          NaN              NaN
# 2022-01-04       0.911566       6.410994e+08    16.207991     4.997749e+08
# 2022-01-05       0.902952       6.350409e+08    16.236605     5.006573e+08
# 2022-01-06       0.895949       6.301158e+08    16.694508     5.147767e+08
# 2022-01-07            NaN                NaN    16.675432     5.141885e+08
#
#             SML.NZ_px_USD  SML.NZ_MktCap_USD  IBAB.BR_px_USD  \
# 2022-01-03            NaN                NaN       16.539564
# 2022-01-04       2.377765       5.430956e+08       16.449608
# 2022-01-05       2.364203       5.399979e+08       16.515430
# 2022-01-06       2.332385       5.327306e+08       16.227075
# 2022-01-07            NaN                NaN             NaN
#
#             IBAB.BR_MktCap_USD  BFT.WA_px_USD  BFT.WA_MktCap_USD
# 2022-01-03        4.871992e+08     155.352762       4.462688e+08
# 2022-01-04        4.845494e+08     155.528263       4.467729e+08
# 2022-01-05        4.864883e+08            NaN                NaN
# 2022-01-06        4.779944e+08     156.277040       4.489238e+08
# 2022-01-07                 NaN            NaN                NaN
#
# [5 rows x 267 columns]
#             NTCO3.SA    0973.HK       LMND  SOMA3.SA   ARZZ3.SA  MME.AX  \
# 2024-05-24     15.44        NaN  16.309999      6.07  50.959999     NaN
# 2024-05-26       NaN  31.850000        NaN       NaN        NaN   0.062
# 2024-05-27     15.28  31.850000        NaN      6.03  50.970001   0.065
# 2024-05-28     14.83  32.049999  16.450001      6.06  50.990002   0.069
# 2024-05-29     14.75        NaN  16.580000      5.93  50.180000     NaN
#
#             AEF.AX  CONCHATORO.SN  MOVI3.SA    FREY.PA  ...  KMD.NZ_px_USD  \
# 2024-05-24     NaN    1200.699951      6.45        NaN  ...            NaN
# 2024-05-26    4.70            NaN       NaN  28.799999  ...       0.263210
# 2024-05-27    4.75    1199.300049      6.46  29.000000  ...       0.270677
# 2024-05-28    4.56    1190.000000      6.65  29.000000  ...       0.260956
# 2024-05-29     NaN    1172.400024      6.54        NaN  ...            NaN
#
#             KMD.NZ_MktCap_USD  AMAL_px_USD  AMAL_MktCap_USD  SML.NZ_px_USD  \
# 2024-05-24                NaN    25.299999     7.801279e+08            NaN
# 2024-05-26       1.851143e+08          NaN              NaN       0.278513
# 2024-05-27       1.903655e+08          NaN              NaN       0.273753
# 2024-05-28       1.835291e+08    25.170000     7.761193e+08       0.273237
# 2024-05-29                NaN    25.020000     7.714941e+08            NaN
#
#             SML.NZ_MktCap_USD  IBAB.BR_px_USD  IBAB.BR_MktCap_USD  \
# 2024-05-24                NaN             NaN                 NaN
# 2024-05-26       6.361406e+07       15.186358        4.473384e+08
# 2024-05-27       6.252672e+07       15.488468        4.562375e+08
# 2024-05-28       6.240886e+07       15.539543        4.577420e+08
# 2024-05-29                NaN             NaN                 NaN
#
#             BFT.WA_px_USD  BFT.WA_MktCap_USD
# 2024-05-24            NaN                NaN
# 2024-05-26     768.626771       2.207969e+09
# 2024-05-27     748.187589       2.149255e+09
# 2024-05-28     727.237467       2.089074e+09
# 2024-05-29            NaN                NaN
#
# [5 rows x 267 columns]

# %% [markdown]
# ### Refine DF and calculate PW and MW indicies:

# %%
def get_df_in_USD(df_all):
    cols_to_keep = []
    for col in df_all:
        if "USD" in col:
            cols_to_keep.append(col)
    cols_to_keep.remove('USD')
    df_USD = df_all[cols_to_keep]
    
    px = []
    MC = []
    
    for col in cols_to_keep:
        if "_px" in col:
            px.append(col)
        if "_MktCap" in col:
            MC.append(col)

    df_USD_px = df_USD[px]
    df_MC_px = df_USD[MC]
    
    return df_USD, df_USD_px, df_MC_px

# %%
daily_info_usd, daily_px_USD, daily_MC_USD = get_df_in_USD(daily_price_MC_usd_all)

#QC:
#daily_px_USD.to_csv('daily_px_test.csv')

# %%
daily_px_USD.head()
#QC:
#daily_px_USD.to_csv('daily_px_test.csv')
# Out:
#             NTCO3.SA_px_USD  0973.HK_px_USD  LMND_px_USD  SOMA3.SA_px_USD  \
# 2022-01-03              NaN        3.988382          NaN              NaN
# 2022-01-04         4.071627        3.977998    39.029999         1.991196
# 2022-01-05         3.861943        3.964855    36.790001         1.791267
# 2022-01-06         3.835474        4.030334    35.330002         1.854434
# 2022-01-07         3.742931             NaN    37.139999         1.826764
#
#             ARZZ3.SA_px_USD  MME.AX_px_USD  AEF.AX_px_USD  \
# 2022-01-03              NaN       1.525726       9.399683
# 2022-01-04        11.701577       1.535003       9.541020
# 2022-01-05        11.077427       1.516515       8.942125
# 2022-01-06        11.330111       1.482827       8.786915
# 2022-01-07        11.335986            NaN            NaN
#
#             CONCHATORO.SN_px_USD  MOVI3.SA_px_USD  FREY.PA_px_USD  \
# 2022-01-03                   NaN              NaN       31.427826
# 2022-01-04              1.404151         2.389050       30.821861
# 2022-01-05              1.455531         2.214387       30.903876
# 2022-01-06              1.475234         2.216285       30.858700
# 2022-01-07              1.480765         2.191904             NaN
#
#             ABB.AX_px_USD  LFG.AX_px_USD  1112.HK_px_USD  VITL_px_USD  \
# 2022-01-03       3.411294       3.213859        1.331867          NaN
# 2022-01-04       3.330666       3.245157        1.341494    18.180000
# 2022-01-05       3.040251       3.224879        1.401610    17.570000
# 2022-01-06       3.194884       3.198941        1.371569    18.290001
# 2022-01-07            NaN            NaN             NaN    18.510000
#
#             2897.TW_px_USD  KMD.NZ_px_USD  AMAL_px_USD  SML.NZ_px_USD  \
# 2022-01-03        0.268322            NaN          NaN            NaN
# 2022-01-04        0.268931       0.911566    16.207991       2.377765
# 2022-01-05        0.269151       0.902952    16.236605       2.364203
# 2022-01-06        0.269355       0.895949    16.694508       2.332385
# 2022-01-07             NaN            NaN    16.675432            NaN
#
#             IBAB.BR_px_USD  BFT.WA_px_USD
# 2022-01-03       16.539564     155.352762
# 2022-01-04       16.449608     155.528263
# 2022-01-05       16.515430            NaN
# 2022-01-06       16.227075     156.277040
# 2022-01-07             NaN            NaN

# %%
def calc_px_weighted_index(df, divisor = 0, show_chart = True):
    # Fill in missing days:
    pw_index = df.ffill()
    
    n, m = pw_index.shape
    if divisor == 0:
        divisor = m
    pw_index['Index'] = (pw_index.iloc[:,0:m].sum(axis=1)) / divisor

    # Remove NaN rows:
    #QC:
    #pw_index.to_csv('PW_index_test.csv')
    pw_index.dropna(inplace=True)
    #pw_index.sort_index(axis=0, level=0, inplace=True)
    
    if show_chart:
        
        fig, ax = plt.subplots(figsize = (12,6))
        ax.plot(pw_index['Index'], color = 'seagreen', linewidth=2)
        plt.title('Price Weighted Index | '+ str(m) + ' stocks')
        plt.annotate("Stocks in Index:", (0,0), (0, -20), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.annotate(stock_universe[0:int(m/2)], (0,0), (0, -30), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.annotate(stock_universe[int(m/2):], (0,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.show()
        
    return pw_index

def calc_MC_weighted_index(df, divisor = 1000000000, show_chart = True):
    # Fill in missing days:
    mcw_index = df.ffill()
    n, m = mcw_index.shape
    mcw_index['Index'] = (mcw_index.iloc[:,0:m].sum(axis=1)) / divisor
    
    # Remove NaN rows:
    mcw_index.dropna(inplace=True)
    
    if show_chart:
        
        fig, ax = plt.subplots(figsize = (12,6))
        ax.plot(mcw_index['Index'], color = 'royalblue', linewidth=2)
        plt.title('MktCap Weighted Index | '+ str(m) + ' stocks')
        plt.annotate("Stocks in Index:", (0,0), (0, -20), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.annotate(stock_universe[0:int(m/2)], (0,0), (0, -30), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.annotate(stock_universe[int(m/2):], (0,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
        plt.show()    
        
    return mcw_index

# %% [markdown]
# ## First 20 stocks, no reweighting

# %%
price_wgt_index = calc_px_weighted_index(daily_px_USD, divisor = 1, show_chart=True)
mktcap_wgt_index = calc_MC_weighted_index (daily_MC_USD, divisor = 1000000000, show_chart=True)

display(price_wgt_index.head())
display(mktcap_wgt_index.head())
# Out:
#             NTCO3.SA_px_USD  0973.HK_px_USD  LMND_px_USD  SOMA3.SA_px_USD  \
# 2022-01-04         4.071627        3.977998    39.029999         1.991196
# 2022-01-05         3.861943        3.964855    36.790001         1.791267
# 2022-01-06         3.835474        4.030334    35.330002         1.854434
# 2022-01-07         3.742931        4.030334    37.139999         1.826764
# 2022-01-09         3.742931        4.168364    37.139999         1.826764
#
#             ARZZ3.SA_px_USD  MME.AX_px_USD  AEF.AX_px_USD  \
# 2022-01-04        11.701577       1.535003       9.541020
# 2022-01-05        11.077427       1.516515       8.942125
# 2022-01-06        11.330111       1.482827       8.786915
# 2022-01-07        11.335986       1.482827       8.786915
# 2022-01-09        11.335986       1.457235       8.603712
#
#             CONCHATORO.SN_px_USD  MOVI3.SA_px_USD  FREY.PA_px_USD  ...  \
# 2022-01-04              1.404151         2.389050       30.821861  ...
# 2022-01-05              1.455531         2.214387       30.903876  ...
# 2022-01-06              1.475234         2.216285       30.858700  ...
# 2022-01-07              1.480765         2.191904       30.858700  ...
# 2022-01-09              1.480765         2.191904       30.824614  ...
#
#             LFG.AX_px_USD  1112.HK_px_USD  VITL_px_USD  2897.TW_px_USD  \
# 2022-01-04       3.245157        1.341494    18.180000        0.268931
# 2022-01-05       3.224879        1.401610    17.570000        0.269151
# 2022-01-06       3.198941        1.371569    18.290001        0.269355
# 2022-01-07       3.198941        1.371569    18.510000        0.269355
# 2022-01-09       3.234819        1.396613    18.510000        0.270424
#
#             KMD.NZ_px_USD  AMAL_px_USD  SML.NZ_px_USD  IBAB.BR_px_USD  \
# 2022-01-04       0.911566    16.207991       2.377765       16.449608
# 2022-01-05       0.902952    16.236605       2.364203       16.515430
# 2022-01-06       0.895949    16.694508       2.332385       16.227075
# 2022-01-07       0.895949    16.675432       2.332385       16.227075
# 2022-01-09       0.876441    16.675432       2.323785       16.263733
#
#             BFT.WA_px_USD       Index
# 2022-01-04     155.528263  324.304923
# 2022-01-05     155.528263  319.571270
# 2022-01-06     156.277040  319.952021
# 2022-01-07     156.277040  321.829755
# 2022-01-09     156.419859  321.923455
#
# [5 rows x 21 columns]
#             NTCO3.SA_MktCap_USD  0973.HK_MktCap_USD  LMND_MktCap_USD  \
    #combined_df = pd.concat([px_df['Index'],mc_df['Index']], axis=1)
    #combined_df.columns = ['Price Weighted Index', "Mkt Cap Weighted Index"]
    combined_df = px_df['Index']
    combined_df.index = pd.to_datetime(combined_df.index).date
    combined_df.columns = ['Price Weighted Index']
    
    # Add S&P
    spx_object = yf.Ticker("^GSPC")
    spx = pd.DataFrame.from_dict(spx_object.history(start=s, end="2022-12-31", interval = "1d"))
    spx = spx[['Close']]
    spx.columns = ['SPX']
    spx.index = pd.to_datetime(spx.index).date
    
    # Add Russell 2000
    ru2000_object = yf.Ticker("^RUT")
    ru2000 = pd.DataFrame.from_dict(ru2000_object.history(start=s, end="2022-12-31", interval = "1d"))
    ru2000 = ru2000[['Close']]
    ru2000.columns = ['RU2000']
    ru2000.index = pd.to_datetime(ru2000.index).date
    
    
    #indicies = ['^GSPC', '^RUT', '^DJI', '^FTSE', '^DJUSS', 'FITLX', '^NYA', '^XAX', '^GDAXI', '^FCHI', '^N100' ]
    #indicies =  ['^RUT']# ['SMLE', 'FITLX']
    #indicies = ['^NYA', '^N100', '^FCHI']
    indicies = ['^DJUSS']
    dfs = []
    
    for idx in indicies:
        idx_object = yf.Ticker(idx)
        #idx_df = pd.DataFrame.from_dict(idx_object.history(start=s, end="2022-12-31", interval = "1d"))
        idx_df = pd.DataFrame.from_dict(idx_object.history(start=s, end="2022-12-31"))
        idx_df = idx_df[['Close']]
        idx_df.columns = [idx]
        idx_df.index = pd.to_datetime(idx_df.index).date
        dfs.append(idx_df)
    
    # Add DJ Sustainability
    #DJsus_object = pd.read_csv("DJSus_history.csv")
    #display(DJsus_object.head())
    #DJsus_object.index = pd.to_datetime(DJsus_object['Date'])
    #DJsus_object.drop(['Date'], axis=1, inplace=True)
    #DJsus_object.index = pd.to_datetime(DJsus_object.index).date
    #DJ_Sus = DJsus_object.copy()
    
    for idx in dfs:

        combined_df = pd.concat([combined_df, idx], axis=1)
    
    combined_df = combined_df.ffill()
    display(combined_df.head())

    combined_df = combined_df.div(combined_df.iloc[0])
    return combined_df

# %%
index_comparison_df = combine_norm_and_benchmark(price_wgt_index, mktcap_wgt_index)
# Out:
#                  Index       ^DJUSS
# 2022-01-04  324.304923  1567.109985
# 2022-01-05  319.571270  1524.060059
# 2022-01-06  319.952021  1529.500000
# 2022-01-07  321.829755  1517.329956
# 2022-01-09  321.923455  1517.329956

# %%
index_comparison_df.head(5)
# Out:
#                Index    ^DJUSS
# 2022-01-04  1.000000  1.000000
# 2022-01-05  0.985404  0.972529
# 2022-01-06  0.986578  0.976000
# 2022-01-07  0.992368  0.968235
# 2022-01-09  0.992657  0.968235

# %%
index_comparison_df.sort_index(inplace=True)

# %% [markdown]
# ## Preview and adjust dates if needed

# %%
display(index_comparison_df.head(5))
# Out:
#                Index    ^DJUSS
# 2022-01-04  1.000000  1.000000
# 2022-01-05  0.985404  0.972529
# 2022-01-06  0.986578  0.976000
# 2022-01-07  0.992368  0.968235
# 2022-01-09  0.992657  0.968235

# %%
adjust = 0

# %%
if adjust > 0:
    index_comparison_df = index_comparison_df.iloc[adjust:,:]
display(index_comparison_df.head(5))

if download:
    index_comparison_df.to_csv("Index_Comparison.csv")
# Out:
#                Index    ^DJUSS
# 2022-01-04  1.000000  1.000000
# 2022-01-05  0.985404  0.972529
# 2022-01-06  0.986578  0.976000
# 2022-01-07  0.992368  0.968235
# 2022-01-09  0.992657  0.968235

# %% [markdown]
# ### Graph Indices

# %%
## Graph Separately
fig, (ax0, ax1) = plt.subplots(2, 1, figsize = (20,18))
ax0.plot(price_wgt_index['Index'], color = 'seagreen', linewidth=2, label = 'Price Weighted')
ax0.legend(loc=2)
ax1.plot(mktcap_wgt_index['Index'], color = 'royalblue', linewidth=2,label='Market Cap Weighted')
ax1.legend(loc=2)
#ax2.plot(spx, color='darkorange', linewidth=2, label = 'SPX')
#ax2.legend(loc=2)
#plt.show()

# %%
## Graph Together
#fig, ax = plt.subplots(figsize = (12,6))
index_comparison_df.plot(figsize = (12,6),
                         color = ['seagreen',
                                 # 'royalblue',
                                 #  'lightslategray',
                                 # 'sienna',
                                #'darkorange', 
                                 # 'firebrick', 
                                  #'deepskyblue',
                                 # ,
                                  
                               #   'lightcoral',
                                 #'sienna', 'coral', 
                                #  'yellowgreen', 
                                #  'palevioletred', 
                                  'deepskyblue', 'darkslateblue'])
                                 #   'darkviolet',
                                #  'lightslategray' ])

plt.legend(loc=3)
plt.show()

# %%
# Export Index:
#index_comparison_df.to_csv("Index_Comparison.csv")

# %% [markdown]
# ### Visualize Characteristics

# %%
classify_all = stock_data_filtered.copy()
classify_index = stock_index.copy()
print(classify_all.shape, classify_index.shape)
# Out:
# (54, 13) (20, 14)

# %%
classify_index['country'].value_counts()
# Out:
# country
# Brazil           4
# Australia        4
# United States    3
# New Zealand      2
# Luxembourg       1
# Chile            1
# France           1
# Hong Kong        1
# Taiwan           1
# Belgium          1
# Poland           1
# Name: count, dtype: int64

# %%
classify_index
# Out:
#                                      shortName        country currency  \
# Ticker
# NTCO3.SA                GRUPO NATURAON      NM         Brazil      BRL
# 0973.HK                             L'OCCITANE     Luxembourg      HKD
# LMND                            Lemonade, Inc.  United States      USD
# SOMA3.SA                GRUPO SOMA  ON      NM         Brazil      BRL
# ARZZ3.SA                AREZZO CO   ON      NM         Brazil      BRL
# MME.AX                       MONEYME FPO [MME]      Australia      AUD
# AEF.AX                     A ETHICAL FPO [AEF]      Australia      AUD
# CONCHATORO.SN               VINA CONCHA Y TORO          Chile      CLP
# MOVI3.SA                MOVIDA      ON      NM         Brazil      BRL
# FREY.PA                                   FREY         France      EUR
# ABB.AX                    AUSSIEBAND FPO [ABB]      Australia      AUD
# LFG.AX                LIBERTY FG STAPLED [LFG]      Australia      AUD
# 1112.HK                          H&H INTL HLDG      Hong Kong      HKD
# VITL                         Vital Farms, Inc.  United States      USD
# 2897.TW                          O-BANK CO LTD         Taiwan      TWD
# KMD.NZ         KMD Brands Limited Ordinary Sha    New Zealand      NZD
# AMAL               Amalgamated Financial Corp.  United States      USD
# MOVI3.SA                   3.519493e+08                  4.923979
# FREY.PA                    3.130270e+07                  0.913960
# ABB.AX                     2.920311e+08                  1.478066
# LFG.AX                     2.982803e+08                  1.478066
# 1112.HK                    6.455610e+08                  7.815320
# VITL                       4.262527e+07                  1.000000
# 2897.TW                    2.713007e+09                 30.894018
# KMD.NZ                     7.032944e+08                  1.600140
# AMAL                       3.083510e+07                  1.000000
# SML.NZ                     2.284059e+08                  1.600140
# IBAB.BR                    2.945659e+07                  0.913960
# BFT.WA                     2.872616e+06                  3.991717
#
#                 2022-01-04  beginningCloseUSD  beginningMarketCapUSD  \
# Ticker
# NTCO3.SA         23.117048           4.694790           6.461091e+09
# 0973.HK          31.003922           3.967070           5.894867e+09
# LMND             39.029999          39.029999           2.761635e+09
# SOMA3.SA         11.305203           2.295949           1.763088e+09
# ARZZ3.SA         66.436813          13.492505           1.473319e+09
# MME.AX            2.120000           1.434307           1.147557e+09
# AEF.AX           13.177148           8.915128           1.003261e+09
# CONCHATORO.SN  1189.919800           1.345575           9.899831e+08
# MOVI3.SA         13.564058           2.754695           9.695129e+08
# FREY.PA          27.316031          29.887556           9.355612e+08
# ABB.AX            4.600000           3.112175           9.088518e+08
# LFG.AX            4.481903           3.032275           9.044679e+08
# 1112.HK          10.455404           1.337809           8.636372e+08
# VITL             18.180000          18.180000           7.749274e+08
# 2897.TW           7.403813           0.239652           6.501774e+08
# KMD.NZ            1.337965           0.836155           5.880631e+08
# AMAL             16.207987          16.207987           4.997748e+08
# SML.NZ            3.490000           2.181059           4.981668e+08
# IBAB.BR          14.578547          15.950969           4.698612e+08
# BFT.WA          629.166260         157.617952           4.527758e+08
#
#                trading_history
# Ticker
# NTCO3.SA                   747
# 0973.HK                   4259
# LMND                       550
# SOMA3.SA                   521
# ARZZ3.SA                  3988
# MME.AX                     754
# AEF.AX                    6959
# CONCHATORO.SN             8034
# MOVI3.SA                  1685
# FREY.PA                   5024
# ABB.AX                     445
# LFG.AX                     385
# 1112.HK                   4035
# VITL                       521
# 2897.TW                   5117
# KMD.NZ                    4528
# AMAL                      1243
# SML.NZ                    3087
# IBAB.BR                   8035
# BFT.WA                    3905

# %%
def visualize_groups (df_all, df_some):
    # by sector:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_all['sector'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("steelblue", n_slices, reverse=True)
    
    ax.pie(df_all['sector'].value_counts(), labels=df_all['sector'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Sectors in Public B-Corp Universe')
    plt.show()
    

    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_some['sector'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("steelblue", n_slices, reverse=True)
    
    ax.pie(df_some['sector'].value_counts(), labels=df_some['sector'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Sectors in Top 20 Index')
    plt.show()  
    

    # by industry:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_all['industry'].value_counts().index))
    cmap = sns.light_palette("maroon", n_slices, reverse=True)
    
    ax.pie(df_all['industry'].value_counts(), labels=df_all['industry'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'xx-small'}, colors = cmap)
    plt.title('Industries in Public B-Corp Universe')
    plt.show()
    


    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_some['industry'].value_counts().index))
    cmap = sns.light_palette("maroon", n_slices, reverse=True)
    
    ax.pie(df_some['industry'].value_counts(), labels=df_some['industry'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'xx-small'}, colors = cmap)
    plt.title('Industries in Top 20 Index')
    plt.show()   
  
    
    # by country:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_all['country'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("seagreen", n_slices, reverse=True)
    
    ax.pie(df_all['country'].value_counts(), labels=df_all['country'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Countries in Public B-Corp Universe')
    plt.show()
    
    # by country:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_some['country'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("seagreen", n_slices, reverse=True)
    
    ax.pie(df_some['country'].value_counts(), labels=df_some['country'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Countries in Top 20 Index')
    plt.show()


    
    # by currency:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_all['currency'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("goldenrod", n_slices, reverse=True)
    
    ax.pie(df_all['currency'].value_counts(), labels=df_all['currency'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Currencies in Public B-Corp Universe')
    plt.show()
    
    # by currency:
    fig, ax = plt.subplots(figsize = (8,6))
    
    n_slices = len(list(df_some['currency'].value_counts().index))
    #cmap = sns.color_palette("Blues", n_slices)
    cmap = sns.light_palette("goldenrod", n_slices, reverse=True)
    
    ax.pie(df_some['currency'].value_counts(), labels=df_some['currency'].value_counts().index, autopct='%1.1f%%',
          pctdistance=.8, textprops={'size': 'smaller'}, colors = cmap)
    plt.title('Currencies in Top 20 Index')
    plt.show()

# %%
visualize_groups(classify_all, classify_index)

# %%
print(stock_index.shape)
# Out:
# (20, 14)

# %%
print(price_wgt_index.shape)
display(price_wgt_index)
# Out:
# (748, 21)
#             NTCO3.SA_px_USD  0973.HK_px_USD  LMND_px_USD  SOMA3.SA_px_USD  \
# 2022-01-04         4.071627        3.977998    39.029999         1.991196
# ## Reconstitute:

# %%
df22 = stock_data_filtered.copy()

# %%
def reconstitute(df, recon_date):

    # Confirm Implied Shares Outstanding for Mkt Cap calculation:    
    df['impliedSharesOutstanding'] = df['marketCap'] / df['previousClose']
    
    reprice = get_starting_price(df, start = recon_date)
    
    recon_px = reprice.filter(like=recon_date, axis=0).T
    recon_px.columns = [str(recon_date)]
    
    exch_data_recast = get_rates(date=recon_date)
    currency_dict_recast = currency_dict.copy()
    
    # Revise currency translation:
    for symbol, rate in exch_data_recast['rates'].items():
        for key in currency_dict_recast.keys():
            if symbol == key:
                currency_dict_recast[key][1] = rate
                
    # Revise currency map:
    currency_map_rev = {symbol:rate
                       for symbol, name in currency_dict_recast.items()
                       for rate in name}
    
    col = 'USDExchRate'+str(recon_date)
    df[col] = df['currency'].map(currency_map_rev)
    df = df.join(recon_px)
    
    
    col2 = 'CloseUSD'+str(recon_date)
    df[col2] = df[recon_date] / df[col]
    
    col3='MarketCapUSD'+str(recon_date)
    df[col3] = df[col2] * df['impliedSharesOutstanding']
    
    
    return df

# %%
df23 = reconstitute(df22, recon_date = '2023-01-03') 
display(df23.head(20))

df24 = reconstitute(df23, recon_date = '2024-01-02') 
display(df24.head(20))
# Out:
# Running API 1
#                                      shortName        country currency  \
# Ticker
# 0973.HK                             L'OCCITANE     Luxembourg      HKD
# 1112.HK                          H&H INTL HLDG      Hong Kong      HKD
# 1346.HK                            LEVER STYLE      Hong Kong      HKD
# 1H2.SI                            $ Olive Tree      Singapore      SGD
# 2897.TW                          O-BANK CO LTD         Taiwan      TWD
# 6088.T                   SIGMAXYZ HOLDINGS INC          Japan      JPY
# ABB.AX                    AUSSIEBAND FPO [ABB]      Australia      AUD
# AEF.AX                     A ETHICAL FPO [AEF]      Australia      AUD
# ALQP.PA                               QUADPACK          Spain      EUR
# AMAL               Amalgamated Financial Corp.  United States      USD
# ARZZ3.SA                AREZZO CO   ON      NM         Brazil      BRL
# BFT.WA                                 BENEFIT         Poland      PLN
# BIO.AX                    BIOME AUST FPO [BIO]      Australia      AUD
# BIRD                            Allbirds, Inc.  United States      USD
# CLSA3.SA                CLEARSALE   ON      NM         Brazil      BRL
# COCO               The Vita Coco Company, Inc.  United States      USD
# CONCHATORO.SN               VINA CONCHA Y TORO          Chile      CLP
# COUR                            Coursera, Inc.  United States      USD
# CVT.NZ         Comvita Limited Ordinary Shares    New Zealand      NZD
# CWEB.TO            CHARLOTTES WEB HOLDINGS INC  United States      CAD
#
#                                                industry  \
# Ticker
# 0973.HK                   Household & Personal Products
# 1112.HK                                  Packaged Foods
# 1346.HK                           Apparel Manufacturing
# 1H2.SI                        Real Estate - Diversified
# 2897.TW                                Banks - Regional
# 6088.T                      Specialty Business Services
# ABB.AX                                 Telecom Services
# AEF.AX                                 Asset Management
# ALQP.PA                          Packaging & Containers
# AMAL                                   Banks - Regional
# ARZZ3.SA                         Footwear & Accessories
# BFT.WA                                          Leisure
# BIO.AX                                   Packaged Foods
# BIRD                                     Apparel Retail
# CLSA3.SA                      Software - Infrastructure
# AEF.AX         5.131581e+08              1.125347e+08
# ALQP.PA        6.060233e+07              4.391473e+06
# AMAL           7.714941e+08              3.083510e+07
# ARZZ3.SA       5.567873e+09              1.091954e+08
# BFT.WA         8.431127e+09              2.872616e+06
# BIO.AX         7.129738e+07              1.953353e+08
# BIRD           9.154159e+07              1.590092e+08
# CLSA3.SA       1.386894e+09              2.054658e+08
# COCO           1.582351e+09              5.821747e+07
# CONCHATORO.SN  8.625724e+11              7.357322e+08
# COUR           1.179426e+09              1.535711e+08
# CVT.NZ         1.053381e+08              5.693951e+07
# CWEB.TO        3.694858e+07              1.508105e+08
#
#                beginningUSDExchangeRate  ...  beginningCloseUSD  \
# Ticker                                   ...
# 0973.HK                        7.815320  ...           3.967070
# 1112.HK                        7.815320  ...           1.337809
# 1346.HK                        7.815320  ...           0.039081
# 1H2.SI                         1.326405  ...           0.082931
# 2897.TW                       30.894018  ...           0.239652
# 6088.T                       142.156502  ...           8.207986
# ABB.AX                         1.478066  ...           3.112175
# AEF.AX                         1.478066  ...           8.915128
# ALQP.PA                        0.913960  ...          26.040526
# AMAL                           1.000000  ...          16.207987
# ARZZ3.SA                       4.923979  ...          13.492505
# BFT.WA                         3.991717  ...         157.617952
# BIO.AX                         1.478066  ...           0.081187
# BIRD                           1.000000  ...          15.590000
# CLSA3.SA                       4.923979  ...           1.821698
# COCO                           1.000000  ...          12.000000
# CONCHATORO.SN                884.320491  ...           1.345575
# COUR                           1.000000  ...          25.000000
# CVT.NZ                         1.600140  ...           2.211005
# CWEB.TO                        1.332265  ...           1.020818
#
#                beginningMarketCapUSD  USDExchRate2023-01-03   2023-01-03  \
# Ticker
# 0973.HK                 5.894867e+09               7.813450    25.320807
# 1112.HK                 8.636372e+08               7.813450    15.002916
# 1346.HK                 2.550790e+07               7.813450     0.292466
# 1H2.SI                  9.607134e+06               1.345415     0.159000
# 2897.TW                 6.501774e+08              30.665300     8.040440
# 6088.T                  3.593645e+08             131.253499  1169.781372
# ABB.AX                  9.088518e+08               1.486768     2.690000
# AEF.AX                  1.003261e+09               1.486768     4.086268
# ALQP.PA                 1.143563e+08               0.948180    19.100000
# AMAL                    4.997748e+08               1.000000    22.468164
# ARZZ3.SA                1.473319e+09               5.480118    69.735306
# BFT.WA                  4.527758e+08               4.430857   767.895508
# BIO.AX                  1.585872e+07               1.486768     0.071000
# BIRD                    2.478953e+09               1.000000     2.240000
# CLSA3.SA                3.742965e+08               5.480118     4.890000
# COCO                    6.986096e+08               1.000000    13.500000
# CONCHATORO.SN           9.899831e+08             862.849697  1002.843689
# COUR                    3.839278e+09               1.000000    12.350000
# CVT.NZ                  1.258935e+08               1.600930     3.227505
# CWEB.TO                 1.539501e+08               1.367520     0.720000
#
#                CloseUSD2023-01-03  MarketCapUSD2023-01-03  \
# Ticker
# 0973.HK                  3.240669            4.815472e+09
# 1112.HK                  1.920140            1.239567e+09
# 1346.HK                  0.037431            2.443124e+07
# 1H2.SI                   0.118179            1.369046e+07
# 2897.TW                  0.262200            7.113501e+08
# 6088.T                   8.912382            3.902046e+08
# ABB.AX                   1.809294            5.283700e+08
# AEF.AX                   2.748423            3.092929e+08
# ALQP.PA                 20.143855            8.846120e+07
# AMAL                    22.468164            6.928080e+08
# ARZZ3.SA                12.725147            1.389527e+09
# BFT.WA                 173.306317            4.978424e+08
# BIO.AX                   0.047755            9.328158e+06
# BIRD                     2.240000            3.561806e+08
# CLSA3.SA                 0.892317            1.833405e+08
# COCO                    13.500000            7.859359e+08
# CONCHATORO.SN            1.162246            8.551019e+08
# COUR                    12.350000            1.896603e+09
# CVT.NZ                   2.016019            1.147911e+08
# CWEB.TO                  0.526501            7.940183e+07
#
#                USDExchRate2024-01-02   2024-01-02  CloseUSD2024-01-02  \
# Ticker
# 0973.HK                     7.815320    21.850000            2.795791
# 1112.HK                     7.815320    12.040072            1.540573
# 1346.HK                     7.815320     0.806804            0.103234
# 1H2.SI                      1.326405     0.076000            0.057298
# 2897.TW                    30.894018     9.920000            0.321098
# 6088.T                    142.156502          NaN                 NaN
# ABB.AX                      1.478066     3.790000            2.564162
# AEF.AX                      1.478066     5.189354            3.510908
# ALQP.PA                     0.913960    19.900000           21.773381
# AMAL                        1.000000    26.321466           26.321466
# ARZZ3.SA                    4.923979    62.270000           12.646277
# BFT.WA                      3.991717  2020.000000          506.047899
# BIO.AX                      1.478066     0.250000            0.169140
# BIRD                        1.000000     1.300000            1.300000
# CLSA3.SA                    4.923979     3.550000            0.720962
# COCO                        1.000000    26.180000           26.180000
# CONCHATORO.SN             884.320491  1016.156677            1.149082
# COUR                        1.000000    19.290001           19.290001
# CVT.NZ                      1.600140     2.289252            1.430657
# CWEB.TO                     1.332265     0.270000            0.202662
#
#                MarketCapUSD2024-01-02
# Ticker
# 0973.HK                  4.154405e+09
# 1112.HK                  9.945340e+08
# 1346.HK                  6.738039e+07
# 1H2.SI                   6.637656e+06
# 2897.TW                  8.711403e+08
# 6088.T                            NaN
# ABB.AX                   7.488148e+08
# AEF.AX                   3.950989e+08
# ALQP.PA                  9.561722e+07
# AMAL                     8.116249e+08
# ARZZ3.SA                 1.380915e+09
# BFT.WA                   1.453681e+09
# BIO.AX                   3.303900e+07
# BIRD                     2.067119e+08
# CLSA3.SA                 1.481329e+08
# COCO                     1.524133e+09
# CONCHATORO.SN            8.454166e+08
# COUR                     2.962387e+09
# CVT.NZ                   8.146094e+07
# CWEB.TO                  3.056362e+07
#
# [20 rows x 21 columns]

# %%
df23.shape
# Out:
# (54, 18)

# %%
#df24.to_csv('reconst_test.csv')

# %%
run_new = False
bring_current = True

# %%
def construct_index_with_recon (df, cutoff=20, start_date = '2022-01-04', end_date = '2022-12-31', pw_divisor = 1, mw_divisor=1000000000):
    today = str(dt.today())
    if today >'2024-12-31':
        print("Add a Year!")
    
    # Clean up errant stock:
    if 'MLMFI.PA' in df.index:
        df.drop('MLMFI.PA', axis=0, inplace=True)

    
    if str(start_date[0:4]) == "2022":
        col = 'beginningMarketCapUSD'
    else:
        col = 'MarketCapUSD' + start_date
    
    index = filter_index(df, size=False, num=True, history = True, start = start_date, num_thresh=cutoff, col = col)
    
    #display(index.head())
    
    assert index.shape[0] == cutoff
    
    prices = get_price_history(index, start_date, end= end_date)
    price_and_info, index_currencies = get_country_info(prices, index)
    
    
    # Set stock universe
    stock_universe = list(index.T.columns)
    #print("stock universe", stock_universe)
    
    #Get historical exchange rates
    
    ### CHANGE 24.05.22- - 
    #filename = "daily_rates_" + str(start_date[0:4] + ".csv")
    #daily_rates_df, _ = load_rates(filename)

    if str(start_date[0:4]) == '2022' or str(start_date[0:4]) == '2023':
        daily_rates_df = load_historical_exchange()
        sd = pd.to_datetime(start_date).date()
        ed = pd.to_datetime(end_date).date()
        daily_rates_df = daily_rates_df.loc[sd:ed]

    #### ADD LOGIC FOR IS YEAR = 2024    
    if str(start_date[0:4]) == '2024':
        daily_rates_df = get_historical_exchange(price_and_info, index_currencies)
        sd = pd.to_datetime(start_date).date()
        ed = pd.to_datetime(end_date).date()
        daily_rates_df = daily_rates_df.loc[sd:ed]
        

    daily_price_and_info_df = price_and_info.join(daily_rates_df)
    
    # Add marketcap:
    daily_price_MC_usd_all = convert_price_mktcap_USD(daily_price_and_info_df, stock_universe) 
    
    # Refine DF INTO USD and calculate PW and MW indicies:
    daily_info_usd, daily_px_USD, daily_MC_USD = get_df_in_USD(daily_price_MC_usd_all)
    
  
    price_wgt_index = calc_px_weighted_index(daily_px_USD, divisor = pw_divisor, show_chart=False)
    
    #display(price_wgt_index['Index'].head())
    #display(price_wgt_index['Index'].tail())
    
    
    mktcap_wgt_index = calc_MC_weighted_index (daily_MC_USD, divisor = mw_divisor, show_chart=False)
    

    #filename2 = 'px_weighted_idx_details'+ str(start_date[0:4]) + ".csv"
    #price_wgt_index.to_csv(filename2)

    ending_index_pw = price_wgt_index.iloc[-1,-1]
    ending_index_mkt = mktcap_wgt_index.iloc[-1,-1]
    
    return price_wgt_index, ending_index_pw, mktcap_wgt_index, ending_index_mkt

# %%
def set_divisor (df0, df1, s0 = '2022-01-04', e0 = '2022-12-31', s1 = '2023-01-03', e1='2023-12-31', divisor=1):
    _, end0_pw, _, end0_mkt = construct_index_with_recon(df0, start_date = s0, end_date = e0, pw_divisor = divisor, mw_divisor = divisor)
    print("end year 0", end0_pw)
    px_wgt_1, _, mkt_cap1, _ = construct_index_with_recon(df1, start_date = s1, end_date = e1, pw_divisor = divisor, mw_divisor = divisor)
        
    
    beg1_pw = px_wgt_1.iloc[0,-1]
    print("PW beg year 1", beg1_pw)
    
    divisor1_pw = divisor * (beg1_pw/end0_pw)
    print("PW Divisor = ", divisor1_pw)
    
    beg1_mkt = mkt_cap1.iloc[0,-1]
    print("MCW beg year 1", beg1_mkt)
    
    divisor1_mkt = divisor * (beg1_mkt/end0_mkt)
    print("MCW Divisor = ", divisor1_mkt)
    
    return divisor1_pw, divisor1_mkt

# %% [markdown]
# ### COMPILE PX WEIGHTED INDEX and GRAPH PERFORMANCE

# %%
price_wgt_index_22, _, _, _ = construct_index_with_recon(df22, pw_divisor = 1)
div1, _ = set_divisor(df22, df23, s0 = '2022-01-04', e0 = '2022-12-31', s1 = '2023-01-03', e1='2023-12-31', divisor=1)

price_wgt_index_23, _, _, _ = construct_index_with_recon(df23, start_date = '2023-01-03', end_date = '2023-12-31', pw_divisor = div1)
div2, _ = set_divisor(df23, df24, s0 = '2023-01-03', e0 = '2023-12-31', s1 = '2024-01-02', e1=e, divisor = div1)

price_wgt_index_24, _, _, _ = construct_index_with_recon(df24, start_date = '2024-01-02', end_date = e, pw_divisor = div2)
# Out:
# end year 0 300.7271721900446
# PW beg year 1 343.70746194772886
# PW Divisor =  1.1429212047740165
# MCW beg year 1 23618570903.027824
# MCW Divisor =  1.1398373286240477
# end year 0 601.6299890580641
# Price_df
# 2024-01-01 <class 'datetime.date'>
#             NTCO3.SA    0973.HK  COUR       WRBY       COCO  BFT.WA  \
# 2024-05-24     15.44        NaN  7.69  17.250000  26.240000     NaN
# 2024-05-26       NaN  31.850000   NaN        NaN        NaN  3015.0
# 2024-05-27     15.28  31.850000   NaN        NaN        NaN  2935.0
# 2024-05-28     14.83  32.049999  7.85  17.139999  26.950001  2850.0
# 2024-05-29     14.75        NaN  7.68  16.770000  27.180000     NaN
#
#              ARZZ3.SA       LMND  SOMA3.SA  1112.HK  ...  MOVI3.SA_currency  \
# 2024-05-24  50.959999  16.309999      6.07      NaN  ...                BRL
# 2024-05-26        NaN        NaN       NaN    10.32  ...                BRL
# 2024-05-27  50.970001        NaN      6.03    10.32  ...                BRL
# 2024-05-28  50.990002  16.450001      6.06    10.40  ...                BRL
# 2024-05-29  50.180000  16.580000      5.93      NaN  ...                BRL
#
#              MOVI3.SA_SO  ABB.AX_currency     ABB.AX_SO  VITL_currency  \
# 2024-05-24  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-26  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-27  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-28  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-29  3.519493e+08              AUD  2.920311e+08            USD
#
#                  VITL_SO  AEF.AX_currency     AEF.AX_SO  IBAB.BR_currency  \
# 2024-05-24  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-26  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-27  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-28  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-29  4.262527e+07              AUD  1.125347e+08               EUR
#
#               IBAB.BR_SO
# 2024-05-24  2.945659e+07
# 2024-05-26  2.945659e+07
# 2024-05-27  2.945659e+07
# 2024-05-28  2.945659e+07
# 2024-05-29  2.945659e+07
#
# [5 rows x 60 columns]
# Currencies
# ['BRL', 'HKD', 'USD', 'USD', 'USD', 'PLN', 'BRL', 'USD', 'BRL', 'HKD', 'TWD', 'CLP', 'EUR', 'AUD', 'USD', 'BRL', 'AUD', 'USD', 'AUD', 'EUR']
# PW beg year 1 611.1829634075723
# PW Divisor =  1.1610690650058666
# MCW beg year 1 24719734156.321613
# MCW Divisor =  1.1415301811446423
# Price_df
# 2024-01-01 <class 'datetime.date'>
#             NTCO3.SA    0973.HK  COUR       WRBY       COCO  BFT.WA  \
# 2024-05-24     15.44        NaN  7.69  17.250000  26.240000     NaN
# 2024-05-26       NaN  31.850000   NaN        NaN        NaN  3015.0
# 2024-05-27     15.28  31.850000   NaN        NaN        NaN  2935.0
# 2024-05-28     14.83  32.049999  7.85  17.139999  26.950001  2850.0
# 2024-05-29     14.75        NaN  7.68  16.770000  27.180000     NaN
#
#              ARZZ3.SA       LMND  SOMA3.SA  1112.HK  ...  MOVI3.SA_currency  \
# 2024-05-24  50.959999  16.309999      6.07      NaN  ...                BRL
# 2024-05-26        NaN        NaN       NaN    10.32  ...                BRL
# 2024-05-27  50.970001        NaN      6.03    10.32  ...                BRL
# 2024-05-28  50.990002  16.450001      6.06    10.40  ...                BRL
# 2024-05-29  50.180000  16.580000      5.93      NaN  ...                BRL
#
#              MOVI3.SA_SO  ABB.AX_currency     ABB.AX_SO  VITL_currency  \
# 2024-05-24  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-26  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-27  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-28  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-29  3.519493e+08              AUD  2.920311e+08            USD
#
#                  VITL_SO  AEF.AX_currency     AEF.AX_SO  IBAB.BR_currency  \
# 2024-05-24  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-26  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-27  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-28  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-29  4.262527e+07              AUD  1.125347e+08               EUR
#
#               IBAB.BR_SO
# 2024-05-24  2.945659e+07
# 2024-05-26  2.945659e+07
# 2024-05-27  2.945659e+07
# 2024-05-28  2.945659e+07
# 2024-05-29  2.945659e+07
#
# [5 rows x 60 columns]
# Currencies
# ['BRL', 'HKD', 'USD', 'USD', 'USD', 'PLN', 'BRL', 'USD', 'BRL', 'HKD', 'TWD', 'CLP', 'EUR', 'AUD', 'USD', 'BRL', 'AUD', 'USD', 'AUD', 'EUR']

# %%
price_wgt_index_22.tail()
# Out:
#             NTCO3.SA_px_USD  0973.HK_px_USD  LMND_px_USD  SOMA3.SA_px_USD  \
# 2022-12-26         2.067492        3.007040        14.40         1.930785
# 2022-12-27         1.936739        3.055792        13.41         1.825134
# 2022-12-28         2.086422        3.058085        12.91         1.918353
# 2022-12-29         2.108454        3.089908        13.84         1.895074
# 2022-12-30         2.108454        3.089908        13.68         1.895074
#
#             ARZZ3.SA_px_USD  MME.AX_px_USD  AEF.AX_px_USD  \
# 2022-12-26        14.617724       0.176914       2.630098
# 2022-12-27        14.046211       0.171561       2.551886
# 2022-12-28        14.503129       0.165301       2.539338
# 2022-12-29        14.375304       0.165742       2.572574
# 2022-12-30        14.375304       0.165742       2.572574
#
#             CONCHATORO.SN_px_USD  MOVI3.SA_px_USD  FREY.PA_px_USD  ...  \
# 2022-12-26              1.151132         1.492457       31.617491  ...
# 2022-12-27              1.177357         1.367390       31.608410  ...
# 2022-12-28              1.184260         1.475093       31.584222  ...
# 2022-12-29              1.165938         1.425351       31.681875  ...
# 2022-12-30              1.182449         1.425351       31.681875  ...
#
#             LFG.AX_px_USD  1112.HK_px_USD  VITL_px_USD  2897.TW_px_USD  \
# 2022-12-26       2.325910        2.104610        15.48        0.261927
# 2022-12-27       2.411662        1.778401        15.71        0.260648
# 2022-12-28       2.375317        1.901347        15.91        0.259742
# 2022-12-29       2.468267        1.948183        15.27        0.263200
# 2022-12-30       2.468267        1.948183        14.92        0.263200
#
#             KMD.NZ_px_USD  AMAL_px_USD  SML.NZ_px_USD  IBAB.BR_px_USD  \
# 2022-12-26       0.615357    22.429340       2.187938       16.020112
# 2022-12-27       0.617453    22.739916       2.220480       16.162442
# 2022-12-28       0.615989    22.642860       2.217561       16.506634
# 2022-12-29       0.612712    22.186703       2.239869       16.368320
# 2022-12-30       0.612712    22.361403       2.239869       16.368320
#
#             BFT.WA_px_USD       Index
# 2022-12-26     157.592027  293.844113
# 2022-12-27     158.077862  292.858412
# 2022-12-28     160.635134  296.209267
# 2022-12-29     165.602823  301.045962
# 2022-12-30     165.602823  300.727172
#
# [5 rows x 21 columns]

# %%
index_df = pd.concat([price_wgt_index_22.iloc[:,-1], price_wgt_index_23.iloc[:,-1]])
index_df = pd.concat([index_df, price_wgt_index_24.iloc[:,-1]])

#index_df

m = 20
fig, ax = plt.subplots(figsize = (12,6))
ax.plot(index_df, color = 'seagreen', linewidth=2)
plt.title('Price Weighted Index | '+ str(m) + ' stocks')
#plt.annotate("Stocks in Index:", (0,0), (0, -20), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
#plt.annotate(stock_universe[0:int(m/2)], (0,0), (0, -30), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
#plt.annotate(stock_universe[int(m/2):], (0,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
plt.show()

# %%
dfs = [df22, df23, df24]
px_indexs = [price_wgt_index_22, price_wgt_index_23, price_wgt_index_24]

for i in range(len(dfs)):
    tickers = [col[:-7] for col in px_indexs[i].columns][:-1]
    info = dfs[i].loc[dfs[i].index.isin(tickers)]

    visualize_groups(classify_all, info)

# %% [markdown]
# ### COMPILE Market WEIGHTED INDEX and GRAPH PERFORMANCE

# %%
if run_new:

    _,_,mkt_wgt_index_22,_ = construct_index_with_recon(df22, mw_divisor = 1000000000)
    _, div1 = set_divisor(df22, df23, s0 = '2022-01-04', e0 = '2022-12-31', s1 = '2023-01-03', e1='2023-12-31', divisor=1000000000)

    _, _, mkt_wgt_index_23, _ = construct_index_with_recon(df23, start_date = '2023-01-03', end_date = '2023-12-31', pw_divisor = div1)
    _, div2 = set_divisor(df23, df24, s0 = '2023-01-03', e0 = '2023-12-31', s1 = '2024-01-02', e1=e, divisor = div1)

    _, _, mkt_wgt_index_24, _ = construct_index_with_recon(df24, start_date = '2024-01-02', end_date = e, pw_divisor = div2)

if bring_current:
    mkt_wgt_index_22 = pd.read_csv("mkt_weighted_idx_details_2022.csv")
    mkt_wgt_index_22.set_index("Date", inplace=True)
    mkt_wgt_index_23 = pd.read_csv("mkt_weighted_idx_details_2023.csv")
    mkt_wgt_index_23.set_index("Date", inplace=True)
    _, _, mkt_wgt_index_24, _ = construct_index_with_recon(df24, start_date = '2024-01-02', end_date = e, pw_divisor = div2)
# Out:
# Price_df
# 2024-01-01 <class 'datetime.date'>
#             NTCO3.SA    0973.HK  COUR       WRBY       COCO  BFT.WA  \
# 2024-05-24     15.44        NaN  7.69  17.250000  26.240000     NaN
# 2024-05-26       NaN  31.850000   NaN        NaN        NaN  3015.0
# 2024-05-27     15.28  31.850000   NaN        NaN        NaN  2935.0
# 2024-05-28     14.83  32.049999  7.85  17.139999  26.950001  2850.0
# 2024-05-29     14.75        NaN  7.68  16.770000  27.180000     NaN
#
#              ARZZ3.SA       LMND  SOMA3.SA  1112.HK  ...  MOVI3.SA_currency  \
# 2024-05-24  50.959999  16.309999      6.07      NaN  ...                BRL
# 2024-05-26        NaN        NaN       NaN    10.32  ...                BRL
# 2024-05-27  50.970001        NaN      6.03    10.32  ...                BRL
# 2024-05-28  50.990002  16.450001      6.06    10.40  ...                BRL
# 2024-05-29  50.180000  16.580000      5.93      NaN  ...                BRL
#
#              MOVI3.SA_SO  ABB.AX_currency     ABB.AX_SO  VITL_currency  \
# 2024-05-24  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-26  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-27  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-28  3.519493e+08              AUD  2.920311e+08            USD
# 2024-05-29  3.519493e+08              AUD  2.920311e+08            USD
#
#                  VITL_SO  AEF.AX_currency     AEF.AX_SO  IBAB.BR_currency  \
# 2024-05-24  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-26  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-27  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-28  4.262527e+07              AUD  1.125347e+08               EUR
# 2024-05-29  4.262527e+07              AUD  1.125347e+08               EUR
#
#               IBAB.BR_SO
# 2024-05-24  2.945659e+07
# 2024-05-26  2.945659e+07
# 2024-05-27  2.945659e+07
# 2024-05-28  2.945659e+07
# 2024-05-29  2.945659e+07
#
# [5 rows x 60 columns]
# Currencies
# ['BRL', 'HKD', 'USD', 'USD', 'USD', 'PLN', 'BRL', 'USD', 'BRL', 'HKD', 'TWD', 'CLP', 'EUR', 'AUD', 'USD', 'BRL', 'AUD', 'USD', 'AUD', 'EUR']

# %%
mkt_index_df = pd.concat([mkt_wgt_index_22.iloc[:,-1], mkt_wgt_index_23.iloc[:,-1]])
mkt_index_df = pd.concat([mkt_index_df, mkt_wgt_index_24.iloc[:,-1]])

display(mkt_index_df.head())
display(mkt_index_df)

#index_df

m = 20
fig, ax = plt.subplots(figsize = (12,6))
ax.plot(mkt_index_df, color = 'royalblue', linewidth=2)
plt.title('Market Weighted Index | '+ str(m) + ' stocks')
#plt.annotate("Stocks in Index:", (0,0), (0, -20), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
#plt.annotate(stock_universe[0:int(m/2)], (0,0), (0, -30), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
#plt.annotate(stock_universe[int(m/2):], (0,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
plt.show()
# Out:
# 2022-01-04    29.063591
# 2022-01-05    28.187638
# 2022-01-06    28.244687
# 2022-01-07    28.223016
# 2022-01-09    28.398516
# Name: Index, dtype: float64
# 2022-01-04    29.063591
# 2022-01-05    28.187638
# 2022-01-06    28.244687
# 2022-01-07    28.223016
# 2022-01-09    28.398516
#                 ...
# 2024-05-24    29.164309
# 2024-05-26    29.244743
# 2024-05-27    29.155589
# 2024-05-28    29.042816
# 2024-05-29    28.886780
# Name: Index, Length: 745, dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/p5/k8h2_yjj0nncvy0f82hy1xvc0000gn/T/ipykernel_95924/1625647046.py in <module>
#       9 m = 20
#      10 fig, ax = plt.subplots(figsize = (12,6))
# ---> 11 ax.plot(mkt_index_df, color = 'royalblue', linewidth=2)
#      12 plt.title('Market Weighted Index | '+ str(m) + ' stocks')
#      13 #plt.annotate("Stocks in Index:", (0,0), (0, -20), xycoords='axes fraction', textcoords='offset points', va='top', color = '#666666', fontsize=9)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1660         """
#    1661         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663         for line in lines:
#    1664             self.add_line(line)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     497
#     498         if self.axes.xaxis is not None:
# --> 499             self.axes.xaxis.update_units(x)
#     500         if self.axes.yaxis is not None:
#     501             self.axes.yaxis.update_units(y)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in update_units(self, data)
#    1606         neednew = self.converter != converter
#    1607         self.converter = converter
# -> 1608         default = self.converter.default_units(data, self)
#    1609         if default is not None and self.units is None:
#    1610             self.set_units(default)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/category.py in default_units(data, axis)
#     114         # the conversion call stack is default_units -> axis_info -> convert
#     115         if axis.units is None:
# --> 116             axis.set_units(UnitData(data))
#     117         else:
#     118             axis.units.update(data)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/category.py in __init__(self, data)
#     190         self._counter = itertools.count()
#     191         if data is not None:
# --> 192             self.update(data)
#     193
#     194     @staticmethod
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/category.py in update(self, data)
#     225         for val in OrderedDict.fromkeys(data):
#     226             # OrderedDict just iterates over unique values in data.
# --> 227             _api.check_isinstance((str, bytes), value=val)
#     228             if convertible:
#     229                 # this will only be called so long as convertible is True.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/_api/__init__.py in check_isinstance(_types, **kwargs)
#      91                 names.remove("None")
#      92                 names.append("None")
# ---> 93             raise TypeError(
#      94                 "{!r} must be an instance of {}, not a {}".format(
#      95                     k,
#
# TypeError: 'value' must be an instance of str or bytes, not a datetime.date

# %%
if download:
    price_wgt_index_22.to_csv("px_weighted_idx_details_2022.csv")
    price_wgt_index_23.to_csv("px_weighted_idx_details_2023.csv")
    price_wgt_index_24.to_csv("px_weighted_idx_details_2024.csv")
    
    mkt_wgt_index_22.to_csv("mkt_weighted_idx_details_2022.csv")
    mkt_wgt_index_23.to_csv("mkt_weighted_idx_details_2023.csv")
    mkt_wgt_index_24.to_csv("mkt_weighted_idx_details_2024.csv")

# %%
def combine_norm_and_benchmark_full(index_df):

    combined_df = index_df['Index']
    combined_df.columns = ['Price Weighted Index']
    
    # Add S&P
    spx_object = yf.Ticker("^GSPC")
    spx = pd.DataFrame.from_dict(spx_object.history(start=s, end=e, interval = "1d"))
    spx = spx[['Close']]
    spx.columns = ['SPX']
    spx.index = pd.to_datetime(spx.index).date
    
    # Add Russell 2000
    ru2000_object = yf.Ticker("^RUT")
    ru2000 = pd.DataFrame.from_dict(ru2000_object.history(start=s, end=e, interval = "1d"))
    ru2000 = ru2000[['Close']]
    ru2000.columns = ['RU2000']
    ru2000.index = pd.to_datetime(ru2000.index).date
    
    
    #indicies = ['^GSPC', '^RUT', '^DJI', '^FTSE', '^DJUSS', 'FITLX', '^NYA', '^XAX', '^GDAXI', '^FCHI', '^N100' ]
    indicies = ['^GSPC', '^DJUSS']

    dfs = []
    
    for idx in indicies:
        idx_object = yf.Ticker(idx)
        #idx_df = pd.DataFrame.from_dict(idx_object.history(start=s, end="2022-12-31", interval = "1d"))
        idx_df = pd.DataFrame.from_dict(idx_object.history(start=s, end=e))
        idx_df = idx_df[['Close']]
        idx_df.columns = [idx]
        idx_df.index = pd.to_datetime(idx_df.index).date
        dfs.append(idx_df)
    
    
    for idx in dfs:

        combined_df = pd.concat([combined_df, idx], axis=1)
    
    combined_df = combined_df.ffill()
    display(combined_df.head())

    combined_df = combined_df.div(combined_df.iloc[0])
    return combined_df

# %%
pw_index_df = pd.DataFrame(index_df, columns = ['Index'])
mkt_index_df = pd.DataFrame(mkt_index_df, columns = ['Index'])
index_pw = combine_norm_and_benchmark_full(pw_index_df)
index_mw = combine_norm_and_benchmark_full(mkt_index_df)

# %%
index_pw.plot(figsize = (12,6),
                         color = ['seagreen',
                                 # 'royalblue',
                                 #  'lightslategray',
                                #'darkorange', 
                                 # 'firebrick', 
                                  #'deepskyblue',
                                 # 'sienna',
                                  
                                 # 'lightcoral',
                                 #'sienna', 'coral', 
                                 # 'yellowgreen', 
                                 # 'palevioletred', 
                                 # 'deepskyblue', 
                                  #'darkslateblue',
                                  #  'darkviolet',
                                  'lightslategray' ])


plt.title('Price Weighted Index | '+ str(m) + ' stocks')
plt.legend(loc=3)
plt.show()

# %%
index_mw.plot(figsize = (12,6),
                         color = [#'seagreen',
                                  'royalblue',
                                 #  'lightslategray',
                                'darkorange', 
                                  'firebrick', 
                                  'deepskyblue',
                                 # 'sienna',
                                  
                                 # 'lightcoral',
                                 #'sienna', 'coral', 
                                 # 'yellowgreen', 
                                 # 'palevioletred', 
                                 # 'deepskyblue', 
                             #'darkslateblue',
                              #      'darkviolet',
                             'lightslategray' ])


plt.title('Market Weighted Index | '+ str(m) + ' stocks')
plt.legend(loc=3)
plt.show()
